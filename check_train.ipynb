# %% [markdown]
# # Node Classification

# %%
import argparse
from types import SimpleNamespace
import sys
sys.path.append('/data/lige/HKN')# Please change accordingly!

from __future__ import division
from __future__ import print_function

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter

import datetime
import json
import logging
from optim import RiemannianAdam, RiemannianSGD
import os
import pickle
import time

import numpy as np
import torch
from config import parser
from models.base_models import NCModel, LPModel, GCModel
from utils.data_utils import load_data, get_nei, GCDataset, split_batch
from utils.train_utils import get_dir_name, format_metrics
from utils.eval_utils import acc_f1

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter


os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:128'
torch.cuda.empty_cache()



config_args = {
    'training_config': {
        'lr': (1e-3, 'learning rate'),
        'dropout': (0.3, 'dropout probability'),
        'cuda': (1, 'which cuda device to use (-1 for cpu training)'),
        'epochs': (1000, 'maximum number of epochs to train for'),
        'weight_decay': (1e-3, 'l2 regularization strength'),
        'optimizer': ('radam', 'which optimizer to use, can be any of [rsgd, radam]'),
        'momentum': (0.999, 'momentum in optimizer'),
        'patience': (15, 'patience for early stopping'),
        'seed': (8, 'seed for training'),
        'log_freq': (1, 'how often to compute print train/val metrics (in epochs)'),
        'eval_freq': (1, 'how often to compute val metrics (in epochs)'),
        'save': (0, '1 to save model and logs and 0 otherwise'),
        'save_dir': (None, 'path to save training logs and model weights (defaults to logs/task/date/run/)'),
        'sweep_c': (0, ''),
        'lr_reduce_freq': (None, 'reduce lr every lr-reduce-freq or None to keep lr constant'),
        'gamma': (0.5, 'gamma for lr scheduler'),
        'print_epoch': (True, ''),
        'grad_clip': (None, 'max norm for gradient clipping, or None for no gradient clipping'),
        'min_epochs': (300, 'do not early stop before min-epochs')
    },
    'model_config': {
        'use_geoopt': (False, "which manifold class to use, if false then use basd.manifold"),
        'AggKlein':(True, "if false, then use hyperboloid centorid for aggregation"),
        'corr': (1,'0: d(x_i ominus x, x_k), 1: d(x_ik,x_k)'),
        'task': ('nc', 'which tasks to train on, can be any of [lp, nc]'),
        'model': ('BKNet', 'which encoder to use, can be any of [Shallow, MLP, HNN, GCN, GAT, HyperGCN, HyboNet,BKNet,BMLP]'),
        'dim': (32, 'embedding dimension'), #The final dimension as the embedded vector
        #'dim': (64, 'embedding dimension'),
        'manifold': ('PoincareBall', 'which manifold to use, can be any of [Euclidean, Hyperboloid, PoincareBall, Lorentz]'),
        'c': (1.0, 'hyperbolic radius, set to None for trainable curvature'),
        'r': (2., 'fermi-dirac decoder parameter for lp'),
        't': (1., 'fermi-dirac decoder parameter for lp'),
        'margin': (2., 'margin of MarginLoss'),
        'pretrained_embeddings': (None, 'path to pretrained embeddings (.npy file) for Shallow node classification'),
        'pos_weight': (0, 'whether to upweight positive class in node classification tasks'),
        'num_layers': (2, 'number of hidden layers in encoder'),
        'bias': (1, 'whether to use bias (1) or not (0)'),
        'act': ('relu', 'which activation function to use (or None for no activation)'),
        'n_heads': (4, 'number of attention heads for graph attention networks, must be a divisor dim'),
        'alpha': (0.2, 'alpha for leakyrelu in graph attention networks'),
        'double_precision': ('1', 'whether to use double precision'),
        'use_att': (0, 'whether to use hyperbolic attention or not'),
        'local_agg': (0, 'whether to local tangent space aggregation or not'),
        'kernel_size': (6, 'number of kernels'),
        'KP_extent': (0.66, 'influence radius of each kernel point'),
        'radius': (1, 'radius used for kernel point init'),
        'deformable': (False, 'deformable kernel'),
        #'linear_before': (64, 'dim of linear before gcn')#The dimension after linear_before(dimensionality reduction if you would)
        'linear_before': (32, 'dim of linear before gcn')#64
    },
    'data_config': {
        'dataset': ('cornell', 'which dataset to use(cornell,wisconsin,texas,squirrel,cora)'),
        #'dataset': ('film', 'which dataset to use(cornell,wisconsin,texas,squirrel,cora)'),
        'batch_size': (32, 'batch size for gc'),
        'val_prop': (0.05, 'proportion of validation edges for link prediction'),
        'test_prop': (0.1, 'proportion of test edges for link prediction'),
        'use_feats': (1, 'whether to use node features or not'),
        'normalize_feats': (1, 'whether to normalize input node features'),
        'normalize_adj': (1, 'whether to row-normalize the adjacency matrix'),
        'split_seed': (8, 'seed for data splits (train/test/val)'),
        'split_graph': (False, 'whether to split the graph')
    }
}

# 将所有参数转换为 SimpleNamespace
args = SimpleNamespace(
    **{k: v[0] for config in config_args.values() for k, v in config.items()}
)

#choose which manifold class to follow 
if args.use_geoopt == False:
    ManifoldParameter = base_ManifoldParameter
else:
    ManifoldParameter = geoopt_ManifoldParameter
np.random.seed(args.seed)#args.seed
torch.manual_seed(args.seed)#args.seed
if int(args.cuda):#args.double_precision
    torch.set_default_dtype(torch.float64)
if int(args.cuda) >= 0:#args.cuda
    torch.cuda.manual_seed(args.seed)#args.seed
args.device = 'cuda:' + str(args.cuda) if int(args.cuda) >= 0 else 'cpu' #args.device actually,<-args.cuda
args.patience = args.epochs if not args.patience else args.patience #args.patience<-args.epochs|args.patience

print(f'Using: {args.device}')
print("Using seed {}.".format(args.seed))
print(f"Dataset: {args.dataset}")

# Load data
data = load_data(args, os.path.join('data', args.dataset))
if args.task == 'gc':
    args.n_nodes, args.feat_dim = data['features'][0].shape
else:
    args.n_nodes, args.feat_dim = data['features'].shape
if args.task == 'nc':
    Model = NCModel
    args.n_classes = int(data['labels'].max() + 1)
    args.data = data
    print(f'Num classes: {args.n_classes}')
elif args.task == 'gc':
    Model = GCModel
    args.n_classes = int(data['labels'].max() + 1)
    print(f'Num classes: {args.n_classes}')
else:
    args.nb_false_edges = len(data['train_edges_false'])
    args.nb_edges = len(data['train_edges'])
    if args.task == 'lp':
        Model = LPModel
        args.n_classes = 2

if not args.lr_reduce_freq:
    args.lr_reduce_freq = args.epochs


###A simple check on data
print(data.keys())
print(data['adj_train'].todense().shape)
print(data['features'].shape)
###A simple check on data

# Model and optimizer
model = Model(args)
print(str(model))
no_decay = ['bias', 'scale']
optimizer_grouped_parameters = [{
    'params': [
        p for n, p in model.named_parameters()
        if p.requires_grad and not any(
            nd in n
            for nd in no_decay) and not isinstance(p, ManifoldParameter)
    ],
    'weight_decay':
    args.weight_decay
}, {
    'params': [
        p for n, p in model.named_parameters() if p.requires_grad and any(
            nd in n
            for nd in no_decay) or isinstance(p, ManifoldParameter)
    ],
    'weight_descay':
    0.0
}]
if args.optimizer == 'radam':
    optimizer = RiemannianAdam(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
elif args.optimizer == 'rsgd':
    optimizer = RiemannianSGD(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=int(
                                                args.lr_reduce_freq),
                                                gamma=float(args.gamma))
tot_params = sum([np.prod(p.size()) for p in model.parameters()])
model = model.to(args.device)
for x, val in data.items():
    if torch.is_tensor(data[x]):
        data[x] = data[x].to(args.device)
print(f"Total number of parameters: {tot_params}")

# Train model for nc:
t_total = time.time()
counter = 0
best_val_metrics = model.init_metric_dict()
best_test_metrics = None
best_emb = None
if args.n_classes > 2:
    f1_average = 'micro'
else:
    f1_average = 'binary'

if args.model == 'HKPNet':
    nei, nei_mask = get_nei(data['adj_train'])
    nei = nei.to(args.device)
    nei_mask = nei_mask.to(args.device)
elif args.model == 'BKNet':
    nei, nei_mask = get_nei(data['adj_train'])
    nei = nei.to(args.device)
    nei_mask = nei_mask.to(args.device) #nei/nei_mask on cuda now


print(f"Memory allocated: {torch.cuda.memory_allocated() / 1024 ** 2:.2f} MB")  # 打印当前分配的显存
# Out:
# Using: cuda:1
# Using seed 8.
# Dataset: cornell
# Num classes: 5
# dict_keys(['adj_train', 'features', 'labels', 'idx_train', 'idx_val', 'idx_test', 'adj_train_norm'])
# (183, 183)
# torch.Size([183, 1703])
# NCModel(
#   (encoder): BKNet(
#     (linear_before): BLinear(
#       in_features=1703, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#       (dropout): Dropout(p=0.3, inplace=False)
#       (E_linear): Linear(in_features=1703, out_features=32, bias=False)
#     )
#     (layers): Sequential(
#       (0): KPGraphConvolution(
#         (net): KernelPointAggregation(
#           (linears): ModuleList(
#             (0): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (1): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (2): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (3): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (4): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (5): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#           )
#           (act): BAct(c=tensor([1.], device='cuda:1'), act=<function relu at 0x7fbb6c477490>)
#         )
#       )
#     )
#   )
#   (decoder): PoincareDecoder()
# )
# Total number of parameters: 61253
# Memory allocated: 0.00 MB
# /data/lige/HKN/utils/data_utils.py:347: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj = nx.adjacency_matrix(G, sorted(G.nodes()))

# %%
decoded_values=[]
embedded_values=[]
model_linear_weight=[]

# 检查权重更新
def check_weights(model, epoch):
    print(f"Epoch {epoch + 1} - Model Linear Weight:")
    for name, param in model.named_parameters():
        if 'weight' in name:
            print(f"{name}: {param.data}")

for epoch in range(args.epochs):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    if args.model == 'HKPNet':
        embeddings = model.encode(data['features'], (nei, nei_mask))
    elif args.model == 'BKNet':
        embeddings = model.encode(data['features'], (nei, nei_mask))
    else:
        embeddings = model.encode(data['features'], data['adj_train_norm'])

    idx=data[f'idx_train']
    output=model.decode(embeddings, data['adj_train_norm'], idx)
    train_metrics = model.compute_metrics(embeddings, data, 'train')
    
    # 检查 decoded_values 和 embeddings
    embedded_values.append(embeddings)
    decoded_values.append(output)
    model_linear_weight.append(model.encoder.layers[0].net.linears[0].E_linear.weight.clone())
    
    # 检查梯度是否被正确计算
    train_metrics['loss'].backward()
    #loss = F.cross_entropy(output, data['labels'][idx])
    #loss.backward()

    for name, param in model.named_parameters():
        if param.grad is not None:
            print(f"Grad of {name}: {param.grad.abs().mean()}")
        else:
            print(f"Grad of {name}: None")  # 检查梯度是否为 None
    
    if args.grad_clip is not None:
        torch.nn.utils.clip_grad_norm_(model.parameters(), args.grad_clip)
        
    optimizer.step()
    lr_scheduler.step()

    #torch.cuda.empty_cache()# try this

    # 打印和检查权重是否被更新
    check_weights(model, epoch)
    
    if (epoch + 1) % args.log_freq == 0:
        print(" ".join([
            'Epoch: {:04d}'.format(epoch + 1),
            'lr: {}'.format(lr_scheduler.get_last_lr()),
            format_metrics(train_metrics, 'train'),
            'time: {:.4f}s'.format(time.time() - t)
        ]))
    
    with torch.no_grad():
        if (epoch + 1) % args.eval_freq == 0:
            model.eval()
            if args.model == 'HKPNet':
                embeddings = model.encode(data['features'], (nei, nei_mask))
            elif args.model == 'BKNet':
                embeddings = model.encode(data['features'], (nei, nei_mask))
            else:
                embeddings = model.encode(data['features'],
                                        data['adj_train_norm'])
            val_metrics = model.compute_metrics(embeddings, data, 'val')
            if (epoch + 1) % args.log_freq == 0:
                print(" ".join([
                    'Epoch: {:04d}'.format(epoch + 1),
                    format_metrics(val_metrics, 'val')
                ]))
            if model.has_improved(best_val_metrics, val_metrics):
                best_test_metrics = model.compute_metrics(
                    embeddings, data, 'test')
                best_emb = embeddings.cpu()
                if args.save:
                    np.save(os.path.join(save_dir, 'embeddings.npy'),
                            best_emb.detach().numpy())
                best_val_metrics = val_metrics
                counter = 0
            else:
                counter += 1
                if counter == args.patience and epoch > args.min_epochs:
                    print("Early stopping")
                    break

print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
if not best_test_metrics:
    model.eval()
    best_emb = model.encode(data['features'], data['adj_train_norm'])
    best_test_metrics = model.compute_metrics(best_emb, data, 'test')
print(" ".join(
    ["Val set results:",
    format_metrics(best_val_metrics, 'val')]))
print(" ".join(
    ["Test set results:",
    format_metrics(best_test_metrics, 'test')]))
if args.save:
    np.save(os.path.join(save_dir, 'embeddings.npy'),
            best_emb.cpu().detach().numpy())
    if hasattr(model.encoder, 'att_adj'):
        filename = os.path.join(save_dir, args.dataset + '_att_adj.p')
        pickle.dump(model.encoder.att_adj.cpu().to_dense(),
                    open(filename, 'wb'))
        print('Dumped attention adj: ' + filename)

    torch.save(model.state_dict(), os.path.join(save_dir, 'model.pth'))
    json.dump(vars(args), open(os.path.join(save_dir, 'config.json'), 'w'))
    logging.info(f"Saved model in {save_dir}")
# Out:
# Grad of encoder.linear_before.bias: 0.0002022553734748681
# Grad of encoder.linear_before.E_linear.weight: 3.129911243123036e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.012537851451877087
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 6.814103620544218e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.012693009705470756
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 6.883713246534268e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.012769003769573505
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 6.93420192868335e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.012914989417280576
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 7.041185894399841e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.012828450289756422
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 6.980162139222898e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.012742821509821093
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 6.930428108605307e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.10358583609261263
# Grad of decoder.bias: 0.1551865335679323
# Epoch 1 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0468,  0.0216,  ..., -0.0827, -0.0605,  0.0225],
#         [ 0.0329, -0.0427,  0.0338,  ..., -0.0400,  0.0427,  0.0154],
#         [-0.0225, -0.0585,  0.0693,  ..., -0.0380,  0.0514,  0.0146],
#         ...,
#         [ 0.0012, -0.0389, -0.0201,  ..., -0.0520,  0.0014,  0.0258],
#         [-0.0517,  0.0729,  0.0039,  ..., -0.0489,  0.0440, -0.0423],
#         [ 0.0585,  0.0688,  0.0197,  ..., -0.0669, -0.0210,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1786, -0.1098, -0.1405,  ..., -0.4007,  0.1374,  0.3470],
#         [ 0.2864,  0.1852,  0.2016,  ...,  0.3333, -0.1323, -0.0566],
#         [-0.1206, -0.1818,  0.1060,  ..., -0.0416, -0.2759, -0.0752],
#         ...,
#         [ 0.4183,  0.0611,  0.1199,  ..., -0.2624,  0.1382, -0.3701],
#         [-0.1088, -0.3861, -0.0689,  ...,  0.2014, -0.0709, -0.0247],
#         [-0.1374, -0.1122,  0.0709,  ...,  0.3634, -0.4174,  0.1023]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3508,  0.2408, -0.4104,  ...,  0.3452,  0.3573, -0.1666],
#         [-0.3667,  0.4100,  0.2657,  ..., -0.1945,  0.0131, -0.3461],
#         [ 0.3601,  0.2193,  0.1438,  ..., -0.4080,  0.0428,  0.3920],
#         ...,
#         [-0.2989, -0.3229,  0.3124,  ..., -0.4140,  0.1717, -0.2685],
#         [-0.2218,  0.1788, -0.1887,  ...,  0.3413, -0.2878, -0.0795],
#         [-0.0611,  0.3380, -0.1960,  ...,  0.0306,  0.2952,  0.4127]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.2029, -0.1322, -0.1732,  ..., -0.1119,  0.2187,  0.1301],
#         [ 0.0044,  0.3788, -0.1740,  ...,  0.2807,  0.0354,  0.0303],
#         [ 0.0910, -0.2291, -0.1826,  ..., -0.3425, -0.2590, -0.3930],
#         ...,
#         [-0.0491, -0.0108,  0.2396,  ..., -0.0132,  0.2744, -0.0272],
#         [ 0.2490, -0.0372, -0.0816,  ..., -0.0487, -0.3264, -0.0709],
#         [ 0.3517, -0.4103, -0.2723,  ...,  0.3303, -0.2261, -0.1556]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3440,  0.0955, -0.3050,  ...,  0.1615, -0.1399, -0.0017],
#         [-0.3176,  0.3400, -0.0140,  ...,  0.4296,  0.0077, -0.1753],
#         [-0.0016, -0.1374, -0.3957,  ..., -0.1283, -0.0709,  0.2359],
#         ...,
#         [ 0.3914, -0.0627,  0.0826,  ...,  0.2588,  0.1867, -0.1784],
#         [-0.0510, -0.3513, -0.2373,  ...,  0.0264,  0.3930,  0.2447],
#         [-0.1986,  0.0639,  0.1461,  ...,  0.1822,  0.3245,  0.2917]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.3006,  0.0813, -0.1592,  ...,  0.0449, -0.4254, -0.3417],
#         [ 0.1590,  0.2572,  0.3771,  ...,  0.2385,  0.0807, -0.1630],
#         [ 0.1157,  0.2364, -0.1380,  ..., -0.1779,  0.0435, -0.2595],
#         ...,
#         [ 0.0420, -0.0715,  0.2713,  ..., -0.2681,  0.0251,  0.3500],
#         [-0.3481, -0.1078, -0.3318,  ...,  0.1335,  0.3968,  0.1750],
#         [-0.3570, -0.4103,  0.1307,  ...,  0.3222, -0.0690, -0.0478]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2592, -0.3177, -0.1523,  ...,  0.1053, -0.3072, -0.3620],
#         [ 0.1266,  0.0921, -0.1545,  ..., -0.0980, -0.2991, -0.1214],
#         [ 0.1852, -0.0703,  0.0432,  ..., -0.1357, -0.1325,  0.1549],
#         ...,
#         [ 0.0560,  0.2238, -0.3357,  ..., -0.0479, -0.1711,  0.1848],
#         [ 0.2528, -0.3288,  0.2512,  ..., -0.1454,  0.3024,  0.2197],
#         [ 0.1632,  0.0989,  0.1381,  ..., -0.1737,  0.0747, -0.1316]],
#        device='cuda:1')
# Epoch: 0001 lr: [0.001, 0.001] train_loss: 1.611188 train_acc: 0.069672 train_f1: 0.069672 time: 0.0777s
# Epoch: 0001 val_loss: 1.590594 val_acc: 0.613636 val_f1: 0.613636
# Grad of encoder.linear_before.bias: 0.00012621879498773576
# Grad of encoder.linear_before.E_linear.weight: 2.5627107566514483e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.010980781580488673
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 6.200295084917206e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.01110262331452366
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 6.271951223376912e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.011194490982198949
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 6.329153419678529e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.011312337755721786
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 6.439694687099078e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.011178735437264402
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 6.351206526245085e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.011146238724039246
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 6.305473313568595e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.10066300048943791
# Grad of decoder.bias: 0.15074805080103998
# Epoch 2 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0458,  0.0220,  ..., -0.0821, -0.0615,  0.0225],
#         [ 0.0329, -0.0422,  0.0330,  ..., -0.0393,  0.0425,  0.0154],
#         [-0.0225, -0.0590,  0.0683,  ..., -0.0383,  0.0522,  0.0146],
#         ...,
#         [ 0.0012, -0.0379, -0.0192,  ..., -0.0528,  0.0021,  0.0258],
#         [-0.0517,  0.0739,  0.0032,  ..., -0.0495,  0.0450, -0.0423],
#         [ 0.0585,  0.0682,  0.0205,  ..., -0.0676, -0.0203,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1795, -0.1089, -0.1395,  ..., -0.4000,  0.1383,  0.3471],
#         [ 0.2854,  0.1842,  0.2006,  ...,  0.3326, -0.1333, -0.0576],
#         [-0.1197, -0.1808,  0.1070,  ..., -0.0407, -0.2752, -0.0742],
#         ...,
#         [ 0.4177,  0.0604,  0.1192,  ..., -0.2618,  0.1375, -0.3708],
#         [-0.1086, -0.3856, -0.0679,  ...,  0.2016, -0.0702, -0.0254],
#         [-0.1383, -0.1129,  0.0701,  ...,  0.3638, -0.4167,  0.1014]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3517,  0.2412, -0.4096,  ...,  0.3458,  0.3580, -0.1662],
#         [-0.3677,  0.4090,  0.2647,  ..., -0.1953,  0.0121, -0.3471],
#         [ 0.3611,  0.2203,  0.1448,  ..., -0.4071,  0.0435,  0.3930],
#         ...,
#         [-0.2996, -0.3237,  0.3118,  ..., -0.4134,  0.1710, -0.2693],
#         [-0.2215,  0.1794, -0.1877,  ...,  0.3414, -0.2871, -0.0802],
#         [-0.0604,  0.3385, -0.1954,  ...,  0.0300,  0.2958,  0.4129]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.2022, -0.1315, -0.1726,  ..., -0.1126,  0.2191,  0.1304],
#         [ 0.0034,  0.3778, -0.1750,  ...,  0.2800,  0.0344,  0.0293],
#         [ 0.0919, -0.2281, -0.1816,  ..., -0.3416, -0.2582, -0.3920],
#         ...,
#         [-0.0497, -0.0114,  0.2390,  ..., -0.0125,  0.2737, -0.0277],
#         [ 0.2490, -0.0368, -0.0810,  ..., -0.0485, -0.3257, -0.0716],
#         [ 0.3507, -0.4111, -0.2733,  ...,  0.3296, -0.2254, -0.1563]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3449,  0.0946, -0.3059,  ...,  0.1608, -0.1407, -0.0026],
#         [-0.3186,  0.3390, -0.0150,  ...,  0.4289,  0.0067, -0.1763],
#         [-0.0006, -0.1364, -0.3947,  ..., -0.1274, -0.0702,  0.2368],
#         ...,
#         [ 0.3908, -0.0632,  0.0820,  ...,  0.2596,  0.1860, -0.1790],
#         [-0.0508, -0.3509, -0.2364,  ...,  0.0265,  0.3938,  0.2441],
#         [-0.1990,  0.0631,  0.1463,  ...,  0.1815,  0.3251,  0.2910]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.2997,  0.0818, -0.1584,  ...,  0.0454, -0.4248, -0.3410],
#         [ 0.1580,  0.2562,  0.3761,  ...,  0.2378,  0.0797, -0.1640],
#         [ 0.1166,  0.2374, -0.1370,  ..., -0.1770,  0.0443, -0.2586],
#         ...,
#         [ 0.0414, -0.0721,  0.2707,  ..., -0.2674,  0.0244,  0.3494],
#         [-0.3480, -0.1072, -0.3308,  ...,  0.1337,  0.3976,  0.1744],
#         [-0.3562, -0.4108,  0.1316,  ...,  0.3228, -0.0684, -0.0482]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2593, -0.3181, -0.1529,  ...,  0.1047, -0.3069, -0.3620],
#         [ 0.1256,  0.0911, -0.1555,  ..., -0.0988, -0.3000, -0.1224],
#         [ 0.1861, -0.0693,  0.0442,  ..., -0.1347, -0.1317,  0.1559],
#         ...,
#         [ 0.0552,  0.2230, -0.3365,  ..., -0.0473, -0.1718,  0.1840],
#         [ 0.2530, -0.3283,  0.2521,  ..., -0.1452,  0.3031,  0.2190],
#         [ 0.1636,  0.0986,  0.1380,  ..., -0.1742,  0.0753, -0.1313]],
#        device='cuda:1')
# Epoch: 0002 lr: [0.001, 0.001] train_loss: 1.593132 train_acc: 0.385246 train_f1: 0.385246 time: 0.0596s
# Epoch: 0002 val_loss: 1.568493 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.00010875466324136695
# Grad of encoder.linear_before.E_linear.weight: 3.149252264105098e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.010677991308283941
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 5.3994415312376576e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.010782651241578138
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 5.460276553285925e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.010765294634096399
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 5.446794416983622e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.010898341312108324
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 5.481397072577269e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.010868588602789355
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 5.513966763160375e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.010727449605389652
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 5.4221975271809934e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.09913204807457857
# Grad of decoder.bias: 0.14813351184630383
# Epoch 3 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0449,  0.0223,  ..., -0.0826, -0.0620,  0.0225],
#         [ 0.0329, -0.0420,  0.0324,  ..., -0.0385,  0.0421,  0.0154],
#         [-0.0225, -0.0596,  0.0676,  ..., -0.0385,  0.0527,  0.0146],
#         ...,
#         [ 0.0012, -0.0385, -0.0185,  ..., -0.0536,  0.0014,  0.0258],
#         [-0.0517,  0.0749,  0.0027,  ..., -0.0500,  0.0460, -0.0423],
#         [ 0.0585,  0.0675,  0.0208,  ..., -0.0673, -0.0198,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1804, -0.1081, -0.1386,  ..., -0.3993,  0.1392,  0.3472],
#         [ 0.2844,  0.1832,  0.1996,  ...,  0.3318, -0.1343, -0.0586],
#         [-0.1187, -0.1798,  0.1080,  ..., -0.0400, -0.2744, -0.0733],
#         ...,
#         [ 0.4176,  0.0610,  0.1188,  ..., -0.2610,  0.1370, -0.3716],
#         [-0.1079, -0.3849, -0.0672,  ...,  0.2023, -0.0694, -0.0248],
#         [-0.1377, -0.1126,  0.0707,  ...,  0.3645, -0.4159,  0.1009]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3526,  0.2419, -0.4088,  ...,  0.3465,  0.3589, -0.1660],
#         [-0.3687,  0.4081,  0.2637,  ..., -0.1960,  0.0111, -0.3481],
#         [ 0.3621,  0.2213,  0.1458,  ..., -0.4064,  0.0443,  0.3939],
#         ...,
#         [-0.2995, -0.3231,  0.3113,  ..., -0.4126,  0.1705, -0.2700],
#         [-0.2208,  0.1801, -0.1869,  ...,  0.3420, -0.2863, -0.0796],
#         [-0.0598,  0.3392, -0.1948,  ...,  0.0306,  0.2965,  0.4133]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.2016, -0.1309, -0.1722,  ..., -0.1130,  0.2195,  0.1307],
#         [ 0.0024,  0.3768, -0.1760,  ...,  0.2792,  0.0334,  0.0284],
#         [ 0.0929, -0.2272, -0.1806,  ..., -0.3408, -0.2574, -0.3911],
#         ...,
#         [-0.0497, -0.0108,  0.2387,  ..., -0.0116,  0.2732, -0.0284],
#         [ 0.2496, -0.0361, -0.0803,  ..., -0.0478, -0.3249, -0.0711],
#         [ 0.3501, -0.4109, -0.2735,  ...,  0.3302, -0.2247, -0.1566]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-3.4575e-01,  9.3772e-02, -3.0677e-01,  ...,  1.5995e-01,
#          -1.4141e-01, -3.4232e-03],
#         [-3.1958e-01,  3.3802e-01, -1.5981e-02,  ...,  4.2811e-01,
#           5.7144e-03, -1.7724e-01],
#         [ 3.2327e-04, -1.3541e-01, -3.9368e-01,  ..., -1.2660e-01,
#          -6.9416e-02,  2.3776e-01],
#         ...,
#         [ 3.9113e-01, -6.2621e-02,  8.1673e-02,  ...,  2.6043e-01,
#           1.8551e-01, -1.7967e-01],
#         [-5.0097e-02, -3.5019e-01, -2.3562e-01,  ...,  2.7147e-02,
#           3.9458e-01,  2.4467e-01],
#         [-1.9897e-01,  6.3357e-02,  1.4675e-01,  ...,  1.8214e-01,
#           3.2585e-01,  2.9039e-01]], device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.2988,  0.0824, -0.1576,  ...,  0.0461, -0.4245, -0.3405],
#         [ 0.1570,  0.2552,  0.3751,  ...,  0.2370,  0.0787, -0.1650],
#         [ 0.1176,  0.2384, -0.1360,  ..., -0.1762,  0.0451, -0.2576],
#         ...,
#         [ 0.0414, -0.0715,  0.2703,  ..., -0.2666,  0.0239,  0.3486],
#         [-0.3473, -0.1065, -0.3301,  ...,  0.1344,  0.3984,  0.1750],
#         [-0.3553, -0.4104,  0.1325,  ...,  0.3234, -0.0676, -0.0485]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2594, -0.3184, -0.1535,  ...,  0.1048, -0.3066, -0.3620],
#         [ 0.1246,  0.0902, -0.1565,  ..., -0.0996, -0.3010, -0.1234],
#         [ 0.1871, -0.0684,  0.0452,  ..., -0.1340, -0.1310,  0.1568],
#         ...,
#         [ 0.0553,  0.2235, -0.3370,  ..., -0.0465, -0.1723,  0.1831],
#         [ 0.2537, -0.3276,  0.2529,  ..., -0.1445,  0.3039,  0.2195],
#         [ 0.1640,  0.0991,  0.1381,  ..., -0.1737,  0.0760, -0.1309]],
#        device='cuda:1')
# Epoch: 0003 lr: [0.001, 0.001] train_loss: 1.573854 train_acc: 0.569672 train_f1: 0.569672 time: 0.0591s
# Epoch: 0003 val_loss: 1.545445 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.0001188787636548695
# Grad of encoder.linear_before.E_linear.weight: 3.167452784055403e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.00946660882664294
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 4.7369335568318135e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.00954520309812692
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 4.7590926893371724e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.009484609476600195
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 4.7440929383770457e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.009631071209930842
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 4.809739070941213e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.00966322581613888
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 4.832978283723126e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.009521256817030133
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 4.745415888139102e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.09699761606752742
# Grad of decoder.bias: 0.1445752565025812
# Epoch 4 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0439,  0.0222,  ..., -0.0832, -0.0623,  0.0225],
#         [ 0.0329, -0.0418,  0.0319,  ..., -0.0381,  0.0416,  0.0154],
#         [-0.0225, -0.0604,  0.0668,  ..., -0.0391,  0.0531,  0.0146],
#         ...,
#         [ 0.0012, -0.0390, -0.0178,  ..., -0.0543,  0.0009,  0.0258],
#         [-0.0517,  0.0758,  0.0023,  ..., -0.0505,  0.0467, -0.0423],
#         [ 0.0585,  0.0667,  0.0210,  ..., -0.0668, -0.0193,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1801, -0.1082, -0.1382,  ..., -0.3987,  0.1399,  0.3468],
#         [ 0.2835,  0.1824,  0.1987,  ...,  0.3312, -0.1351, -0.0595],
#         [-0.1177, -0.1790,  0.1090,  ..., -0.0392, -0.2736, -0.0724],
#         ...,
#         [ 0.4180,  0.0614,  0.1190,  ..., -0.2608,  0.1364, -0.3724],
#         [-0.1074, -0.3844, -0.0665,  ...,  0.2028, -0.0687, -0.0244],
#         [-0.1383, -0.1126,  0.0701,  ...,  0.3642, -0.4158,  0.1003]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3522,  0.2416, -0.4084,  ...,  0.3471,  0.3596, -0.1658],
#         [-0.3695,  0.4073,  0.2628,  ..., -0.1967,  0.0103, -0.3490],
#         [ 0.3630,  0.2221,  0.1468,  ..., -0.4056,  0.0451,  0.3948],
#         ...,
#         [-0.2991, -0.3225,  0.3114,  ..., -0.4125,  0.1699, -0.2709],
#         [-0.2202,  0.1806, -0.1862,  ...,  0.3426, -0.2856, -0.0792],
#         [-0.0603,  0.3392, -0.1954,  ...,  0.0302,  0.2966,  0.4130]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.2014, -0.1305, -0.1718,  ..., -0.1135,  0.2198,  0.1306],
#         [ 0.0016,  0.3760, -0.1768,  ...,  0.2785,  0.0326,  0.0275],
#         [ 0.0939, -0.2264, -0.1796,  ..., -0.3401, -0.2566, -0.3902],
#         ...,
#         [-0.0494, -0.0103,  0.2387,  ..., -0.0114,  0.2726, -0.0292],
#         [ 0.2500, -0.0356, -0.0797,  ..., -0.0473, -0.3242, -0.0708],
#         [ 0.3495, -0.4113, -0.2741,  ...,  0.3297, -0.2248, -0.1572]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3466,  0.0930, -0.3075,  ...,  0.1593, -0.1420, -0.0041],
#         [-0.3204,  0.3372, -0.0169,  ...,  0.4275,  0.0049, -0.1781],
#         [ 0.0013, -0.1346, -0.3927,  ..., -0.1259, -0.0686,  0.2387],
#         ...,
#         [ 0.3917, -0.0621,  0.0819,  ...,  0.2606,  0.1849, -0.1805],
#         [-0.0496, -0.3497, -0.2349,  ...,  0.0277,  0.3953,  0.2450],
#         [-0.1995,  0.0630,  0.1462,  ...,  0.1817,  0.3258,  0.2897]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.2993,  0.0822, -0.1577,  ...,  0.0462, -0.4249, -0.3406],
#         [ 0.1562,  0.2545,  0.3742,  ...,  0.2364,  0.0779, -0.1659],
#         [ 0.1186,  0.2392, -0.1350,  ..., -0.1755,  0.0459, -0.2567],
#         ...,
#         [ 0.0418, -0.0710,  0.2705,  ..., -0.2663,  0.0233,  0.3478],
#         [-0.3469, -0.1060, -0.3294,  ...,  0.1349,  0.3990,  0.1753],
#         [-0.3559, -0.4106,  0.1319,  ...,  0.3230, -0.0677, -0.0490]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2594, -0.3188, -0.1538,  ...,  0.1050, -0.3062, -0.3620],
#         [ 0.1238,  0.0894, -0.1574,  ..., -0.1002, -0.3018, -0.1243],
#         [ 0.1880, -0.0676,  0.0462,  ..., -0.1333, -0.1301,  0.1577],
#         ...,
#         [ 0.0558,  0.2240, -0.3370,  ..., -0.0464, -0.1729,  0.1822],
#         [ 0.2542, -0.3271,  0.2536,  ..., -0.1440,  0.3046,  0.2199],
#         [ 0.1635,  0.0990,  0.1376,  ..., -0.1741,  0.0760, -0.1307]],
#        device='cuda:1')
# Epoch: 0004 lr: [0.001, 0.001] train_loss: 1.552142 train_acc: 0.581967 train_f1: 0.581967 time: 0.0611s
# Epoch: 0004 val_loss: 1.522023 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.00015605461767100108
# Grad of encoder.linear_before.E_linear.weight: 3.218723951405977e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.008872550339935944
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 5.31217770950966e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.008935964855157876
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 5.321253424810124e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.008925105014091685
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 5.3358848052565875e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.009076272731579231
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 5.424190211776606e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.009068991416475467
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 5.43307534065355e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.008890724757878428
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 5.294956867014015e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.09498892564066938
# Grad of decoder.bias: 0.14116908420432212
# Epoch 5 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0429,  0.0221,  ..., -0.0838, -0.0629,  0.0225],
#         [ 0.0329, -0.0418,  0.0316,  ..., -0.0381,  0.0409,  0.0154],
#         [-0.0225, -0.0612,  0.0659,  ..., -0.0398,  0.0534,  0.0146],
#         ...,
#         [ 0.0012, -0.0397, -0.0172,  ..., -0.0549,  0.0005,  0.0258],
#         [-0.0517,  0.0768,  0.0017,  ..., -0.0509,  0.0466, -0.0423],
#         [ 0.0585,  0.0659,  0.0211,  ..., -0.0662, -0.0189,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1798, -0.1083, -0.1379,  ..., -0.3983,  0.1403,  0.3467],
#         [ 0.2828,  0.1817,  0.1979,  ...,  0.3306, -0.1358, -0.0602],
#         [-0.1167, -0.1782,  0.1099,  ..., -0.0386, -0.2727, -0.0716],
#         ...,
#         [ 0.4185,  0.0621,  0.1195,  ..., -0.2606,  0.1359, -0.3733],
#         [-0.1068, -0.3838, -0.0659,  ...,  0.2032, -0.0680, -0.0241],
#         [-0.1387, -0.1124,  0.0697,  ...,  0.3639, -0.4158,  0.0998]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3519,  0.2415, -0.4080,  ...,  0.3476,  0.3604, -0.1655],
#         [-0.3702,  0.4066,  0.2620,  ..., -0.1972,  0.0096, -0.3497],
#         [ 0.3640,  0.2229,  0.1477,  ..., -0.4050,  0.0460,  0.3956],
#         ...,
#         [-0.2985, -0.3218,  0.3118,  ..., -0.4123,  0.1693, -0.2717],
#         [-0.2196,  0.1812, -0.1856,  ...,  0.3430, -0.2849, -0.0790],
#         [-0.0607,  0.3394, -0.1958,  ...,  0.0298,  0.2966,  0.4128]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.2009, -0.1299, -0.1713,  ..., -0.1138,  0.2201,  0.1307],
#         [ 0.0008,  0.3754, -0.1776,  ...,  0.2780,  0.0319,  0.0268],
#         [ 0.0949, -0.2256, -0.1787,  ..., -0.3394, -0.2557, -0.3894],
#         ...,
#         [-0.0490, -0.0096,  0.2390,  ..., -0.0112,  0.2720, -0.0300],
#         [ 0.2505, -0.0350, -0.0791,  ..., -0.0468, -0.3235, -0.0706],
#         [ 0.3490, -0.4115, -0.2746,  ...,  0.3293, -0.2249, -0.1577]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3475,  0.0922, -0.3082,  ...,  0.1587, -0.1426, -0.0047],
#         [-0.3212,  0.3366, -0.0176,  ...,  0.4269,  0.0042, -0.1789],
#         [ 0.0023, -0.1338, -0.3917,  ..., -0.1252, -0.0677,  0.2395],
#         ...,
#         [ 0.3924, -0.0614,  0.0823,  ...,  0.2608,  0.1843, -0.1813],
#         [-0.0490, -0.3491, -0.2343,  ...,  0.0281,  0.3960,  0.2453],
#         [-0.2000,  0.0630,  0.1458,  ...,  0.1814,  0.3258,  0.2891]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.2998,  0.0819, -0.1579,  ...,  0.0463, -0.4255, -0.3408],
#         [ 0.1555,  0.2538,  0.3735,  ...,  0.2358,  0.0772, -0.1667],
#         [ 0.1196,  0.2400, -0.1341,  ..., -0.1749,  0.0468, -0.2559],
#         ...,
#         [ 0.0424, -0.0703,  0.2709,  ..., -0.2661,  0.0227,  0.3469],
#         [-0.3463, -0.1054, -0.3288,  ...,  0.1354,  0.3998,  0.1756],
#         [-0.3563, -0.4106,  0.1315,  ...,  0.3226, -0.0678, -0.0494]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2592, -0.3188, -0.1539,  ...,  0.1052, -0.3056, -0.3618],
#         [ 0.1231,  0.0887, -0.1581,  ..., -0.1007, -0.3026, -0.1250],
#         [ 0.1890, -0.0668,  0.0471,  ..., -0.1326, -0.1293,  0.1585],
#         ...,
#         [ 0.0564,  0.2246, -0.3366,  ..., -0.0463, -0.1735,  0.1813],
#         [ 0.2548, -0.3265,  0.2543,  ..., -0.1435,  0.3053,  0.2201],
#         [ 0.1631,  0.0990,  0.1371,  ..., -0.1744,  0.0760, -0.1304]],
#        device='cuda:1')
# Epoch: 0005 lr: [0.001, 0.001] train_loss: 1.533583 train_acc: 0.581967 train_f1: 0.581967 time: 0.0611s
# Epoch: 0005 val_loss: 1.498663 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.0001377576344707862
# Grad of encoder.linear_before.E_linear.weight: 3.141780377881237e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.008075939768405085
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 4.2420823290501315e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.008206426234780538
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 4.308286343622076e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.008090616992754106
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 4.243721471839847e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.008279013424268336
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 4.337011332511794e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.008265116219546044
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 4.324736449734603e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.008144423322880618
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 4.2694030124310864e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.09301382280458331
# Grad of decoder.bias: 0.13784865942836697
# Epoch 6 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0419,  0.0221,  ..., -0.0846, -0.0637,  0.0225],
#         [ 0.0329, -0.0423,  0.0317,  ..., -0.0384,  0.0402,  0.0154],
#         [-0.0225, -0.0621,  0.0651,  ..., -0.0406,  0.0536,  0.0146],
#         ...,
#         [ 0.0012, -0.0405, -0.0166,  ..., -0.0556, -0.0001,  0.0258],
#         [-0.0517,  0.0777,  0.0012,  ..., -0.0513,  0.0466, -0.0423],
#         [ 0.0585,  0.0650,  0.0211,  ..., -0.0655, -0.0186,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1793, -0.1088, -0.1378,  ..., -0.3986,  0.1401,  0.3463],
#         [ 0.2822,  0.1812,  0.1973,  ...,  0.3301, -0.1365, -0.0609],
#         [-0.1157, -0.1774,  0.1109,  ..., -0.0378, -0.2718, -0.0709],
#         ...,
#         [ 0.4191,  0.0629,  0.1201,  ..., -0.2606,  0.1353, -0.3740],
#         [-0.1061, -0.3831, -0.0651,  ...,  0.2038, -0.0672, -0.0237],
#         [-0.1390, -0.1121,  0.0694,  ...,  0.3637, -0.4156,  0.0994]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3514,  0.2409, -0.4078,  ...,  0.3472,  0.3603, -0.1655],
#         [-0.3708,  0.4060,  0.2614,  ..., -0.1977,  0.0090, -0.3504],
#         [ 0.3650,  0.2237,  0.1487,  ..., -0.4042,  0.0469,  0.3964],
#         ...,
#         [-0.2978, -0.3210,  0.3124,  ..., -0.4124,  0.1687, -0.2724],
#         [-0.2189,  0.1819, -0.1848,  ...,  0.3436, -0.2841, -0.0788],
#         [-0.0610,  0.3399, -0.1961,  ...,  0.0295,  0.2968,  0.4127]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-2.0054e-01, -1.2963e-01, -1.7085e-01,  ..., -1.1430e-01,
#           2.2028e-01,  1.3083e-01],
#         [ 2.3041e-04,  3.7480e-01, -1.7823e-01,  ...,  2.7751e-01,
#           3.1278e-02,  2.6147e-02],
#         [ 9.5827e-02, -2.2483e-01, -1.7772e-01,  ..., -3.3868e-01,
#          -2.5476e-01, -3.8857e-01],
#         ...,
#         [-4.8354e-02, -8.8474e-03,  2.3961e-01,  ..., -1.1299e-02,
#           2.7140e-01, -3.0630e-02],
#         [ 2.5116e-01, -3.4321e-02, -7.8350e-02,  ..., -4.6294e-02,
#          -3.2265e-01, -7.0400e-02],
#         [ 3.4856e-01, -4.1136e-01, -2.7498e-01,  ...,  3.2892e-01,
#          -2.2494e-01, -1.5820e-01]], device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3483,  0.0913, -0.3087,  ...,  0.1580, -0.1432, -0.0051],
#         [-0.3218,  0.3360, -0.0183,  ...,  0.4264,  0.0036, -0.1795],
#         [ 0.0033, -0.1330, -0.3908,  ..., -0.1245, -0.0668,  0.2403],
#         ...,
#         [ 0.3932, -0.0606,  0.0829,  ...,  0.2609,  0.1837, -0.1820],
#         [-0.0483, -0.3484, -0.2335,  ...,  0.0287,  0.3968,  0.2455],
#         [-0.2004,  0.0631,  0.1454,  ...,  0.1811,  0.3258,  0.2885]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.3004,  0.0814, -0.1584,  ...,  0.0458, -0.4262, -0.3411],
#         [ 0.1548,  0.2532,  0.3729,  ...,  0.2353,  0.0766, -0.1673],
#         [ 0.1205,  0.2408, -0.1331,  ..., -0.1741,  0.0477, -0.2551],
#         ...,
#         [ 0.0430, -0.0695,  0.2715,  ..., -0.2661,  0.0221,  0.3462],
#         [-0.3457, -0.1047, -0.3280,  ...,  0.1359,  0.4006,  0.1758],
#         [-0.3567, -0.4103,  0.1311,  ...,  0.3223, -0.0678, -0.0498]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2589, -0.3188, -0.1539,  ...,  0.1050, -0.3049, -0.3616],
#         [ 0.1224,  0.0881, -0.1587,  ..., -0.1012, -0.3032, -0.1257],
#         [ 0.1900, -0.0660,  0.0481,  ..., -0.1319, -0.1284,  0.1593],
#         ...,
#         [ 0.0571,  0.2254, -0.3361,  ..., -0.0465, -0.1742,  0.1805],
#         [ 0.2555, -0.3258,  0.2551,  ..., -0.1430,  0.3061,  0.2203],
#         [ 0.1628,  0.0994,  0.1368,  ..., -0.1746,  0.0760, -0.1301]],
#        device='cuda:1')
# Epoch: 0006 lr: [0.001, 0.001] train_loss: 1.516562 train_acc: 0.581967 train_f1: 0.581967 time: 0.0590s
# Epoch: 0006 val_loss: 1.475425 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.0001404394028853791
# Grad of encoder.linear_before.E_linear.weight: 2.6599485181867604e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.008106508672941068
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 3.781694947185287e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.008181422658508762
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 3.8212535541790716e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.00814111462817783
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 3.8145455575686355e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.00835154185338214
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 3.898518248935202e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.008251780751889615
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 3.835434813456443e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.008171319607904928
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 3.797673420773575e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.09107895325310274
# Grad of decoder.bias: 0.13437095722492498
# Epoch 7 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0410,  0.0220,  ..., -0.0854, -0.0645,  0.0225],
#         [ 0.0329, -0.0428,  0.0319,  ..., -0.0390,  0.0395,  0.0154],
#         [-0.0225, -0.0630,  0.0643,  ..., -0.0415,  0.0539,  0.0146],
#         ...,
#         [ 0.0012, -0.0413, -0.0160,  ..., -0.0562, -0.0006,  0.0258],
#         [-0.0517,  0.0787,  0.0007,  ..., -0.0518,  0.0465, -0.0423],
#         [ 0.0585,  0.0641,  0.0210,  ..., -0.0647, -0.0183,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1788, -0.1093, -0.1378,  ..., -0.3989,  0.1398,  0.3459],
#         [ 0.2816,  0.1807,  0.1967,  ...,  0.3297, -0.1370, -0.0614],
#         [-0.1148, -0.1766,  0.1118,  ..., -0.0371, -0.2709, -0.0701],
#         ...,
#         [ 0.4193,  0.0635,  0.1206,  ..., -0.2605,  0.1347, -0.3743],
#         [-0.1054, -0.3823, -0.0643,  ...,  0.2043, -0.0663, -0.0233],
#         [-0.1391, -0.1119,  0.0691,  ...,  0.3636, -0.4154,  0.0996]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3509,  0.2404, -0.4077,  ...,  0.3468,  0.3601, -0.1653],
#         [-0.3714,  0.4055,  0.2608,  ..., -0.1981,  0.0084, -0.3510],
#         [ 0.3660,  0.2245,  0.1496,  ..., -0.4035,  0.0478,  0.3972],
#         ...,
#         [-0.2974, -0.3204,  0.3129,  ..., -0.4122,  0.1681, -0.2727],
#         [-0.2182,  0.1827, -0.1840,  ...,  0.3441, -0.2832, -0.0784],
#         [-0.0612,  0.3403, -0.1964,  ...,  0.0293,  0.2969,  0.4130]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-2.0007e-01, -1.2931e-01, -1.7037e-01,  ..., -1.1479e-01,
#           2.2045e-01,  1.3105e-01],
#         [-3.2438e-04,  3.7429e-01, -1.7880e-01,  ...,  2.7707e-01,
#           3.0703e-02,  2.5579e-02],
#         [ 9.6802e-02, -2.2416e-01, -1.7684e-01,  ..., -3.3790e-01,
#          -2.5383e-01, -3.8777e-01],
#         ...,
#         [-4.8152e-02, -8.2094e-03,  2.4003e-01,  ..., -1.1134e-02,
#           2.7079e-01, -3.0863e-02],
#         [ 2.5187e-01, -3.3585e-02, -7.7576e-02,  ..., -4.5789e-02,
#          -3.2179e-01, -7.0059e-02],
#         [ 3.4822e-01, -4.1132e-01, -2.7533e-01,  ...,  3.2859e-01,
#          -2.2498e-01, -1.5813e-01]], device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3491,  0.0905, -0.3092,  ...,  0.1574, -0.1437, -0.0057],
#         [-0.3223,  0.3355, -0.0188,  ...,  0.4260,  0.0030, -0.1801],
#         [ 0.0043, -0.1322, -0.3899,  ..., -0.1237, -0.0659,  0.2411],
#         ...,
#         [ 0.3936, -0.0600,  0.0834,  ...,  0.2612,  0.1830, -0.1824],
#         [-0.0475, -0.3476, -0.2327,  ...,  0.0292,  0.3977,  0.2458],
#         [-0.2006,  0.0632,  0.1450,  ...,  0.1809,  0.3259,  0.2887]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.3010,  0.0808, -0.1588,  ...,  0.0454, -0.4269, -0.3414],
#         [ 0.1543,  0.2527,  0.3723,  ...,  0.2349,  0.0760, -0.1679],
#         [ 0.1215,  0.2416, -0.1322,  ..., -0.1733,  0.0486, -0.2542],
#         ...,
#         [ 0.0433, -0.0689,  0.2720,  ..., -0.2659,  0.0214,  0.3459],
#         [-0.3449, -0.1039, -0.3273,  ...,  0.1364,  0.4014,  0.1761],
#         [-0.3569, -0.4102,  0.1308,  ...,  0.3220, -0.0678, -0.0495]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2585, -0.3188, -0.1539,  ...,  0.1050, -0.3042, -0.3613],
#         [ 0.1219,  0.0876, -0.1593,  ..., -0.1017, -0.3038, -0.1263],
#         [ 0.1910, -0.0652,  0.0490,  ..., -0.1311, -0.1275,  0.1601],
#         ...,
#         [ 0.0575,  0.2260, -0.3357,  ..., -0.0465, -0.1748,  0.1801],
#         [ 0.2563, -0.3250,  0.2559,  ..., -0.1424,  0.3070,  0.2207],
#         [ 0.1626,  0.0996,  0.1364,  ..., -0.1748,  0.0761, -0.1295]],
#        device='cuda:1')
# Epoch: 0007 lr: [0.001, 0.001] train_loss: 1.499921 train_acc: 0.581967 train_f1: 0.581967 time: 0.0608s
# Epoch: 0007 val_loss: 1.452474 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.00018215930755020106
# Grad of encoder.linear_before.E_linear.weight: 2.5798272559632083e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.007397750888344633
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 4.154793848168795e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.007537317220707313
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 4.2215430973580447e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.00745980655093486
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 4.1704555704513824e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.007623949505122958
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 4.272516599329736e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.007615893189558391
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 4.257070612239712e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.007526631929253487
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 4.204591634369509e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.08883156461087656
# Grad of decoder.bias: 0.13034753362982907
# Epoch 8 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0401,  0.0217,  ..., -0.0863, -0.0654,  0.0225],
#         [ 0.0329, -0.0431,  0.0317,  ..., -0.0396,  0.0387,  0.0154],
#         [-0.0225, -0.0639,  0.0636,  ..., -0.0424,  0.0544,  0.0146],
#         ...,
#         [ 0.0012, -0.0422, -0.0156,  ..., -0.0568, -0.0011,  0.0258],
#         [-0.0517,  0.0796,  0.0003,  ..., -0.0523,  0.0464, -0.0423],
#         [ 0.0585,  0.0632,  0.0210,  ..., -0.0639, -0.0180,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1783, -0.1098, -0.1379,  ..., -0.3992,  0.1395,  0.3456],
#         [ 0.2811,  0.1802,  0.1962,  ...,  0.3293, -0.1376, -0.0619],
#         [-0.1138, -0.1760,  0.1127,  ..., -0.0362, -0.2700, -0.0695],
#         ...,
#         [ 0.4197,  0.0642,  0.1211,  ..., -0.2609,  0.1340, -0.3746],
#         [-0.1045, -0.3817, -0.0634,  ...,  0.2048, -0.0656, -0.0230],
#         [-0.1392, -0.1116,  0.0688,  ...,  0.3635, -0.4152,  0.0999]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3504,  0.2400, -0.4075,  ...,  0.3464,  0.3599, -0.1651],
#         [-0.3719,  0.4051,  0.2603,  ..., -0.1985,  0.0079, -0.3515],
#         [ 0.3670,  0.2251,  0.1505,  ..., -0.4026,  0.0488,  0.3979],
#         ...,
#         [-0.2970, -0.3196,  0.3134,  ..., -0.4125,  0.1674, -0.2731],
#         [-0.2173,  0.1833, -0.1831,  ...,  0.3446, -0.2825, -0.0782],
#         [-0.0613,  0.3408, -0.1967,  ...,  0.0291,  0.2971,  0.4134]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.1995, -0.1289, -0.1698,  ..., -0.1151,  0.2207,  0.1313],
#         [-0.0008,  0.3738, -0.1793,  ...,  0.2767,  0.0302,  0.0251],
#         [ 0.0978, -0.2236, -0.1760,  ..., -0.3371, -0.2529, -0.3870],
#         ...,
#         [-0.0478, -0.0075,  0.2405,  ..., -0.0115,  0.2701, -0.0311],
#         [ 0.2527, -0.0329, -0.0767,  ..., -0.0453, -0.3211, -0.0699],
#         [ 0.3479, -0.4113, -0.2756,  ...,  0.3283, -0.2250, -0.1581]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3498,  0.0898, -0.3096,  ...,  0.1568, -0.1441, -0.0061],
#         [-0.3228,  0.3350, -0.0193,  ...,  0.4256,  0.0025, -0.1806],
#         [ 0.0053, -0.1315, -0.3890,  ..., -0.1229, -0.0649,  0.2419],
#         ...,
#         [ 0.3941, -0.0592,  0.0839,  ...,  0.2609,  0.1823, -0.1826],
#         [-0.0467, -0.3470, -0.2318,  ...,  0.0297,  0.3984,  0.2460],
#         [-0.2009,  0.0633,  0.1447,  ...,  0.1807,  0.3259,  0.2889]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.3017,  0.0803, -0.1593,  ...,  0.0449, -0.4276, -0.3417],
#         [ 0.1538,  0.2523,  0.3718,  ...,  0.2345,  0.0755, -0.1684],
#         [ 0.1225,  0.2422, -0.1313,  ..., -0.1725,  0.0495, -0.2535],
#         ...,
#         [ 0.0438, -0.0681,  0.2725,  ..., -0.2662,  0.0207,  0.3455],
#         [-0.3442, -0.1032, -0.3264,  ...,  0.1369,  0.4022,  0.1764],
#         [-0.3571, -0.4100,  0.1305,  ...,  0.3218, -0.0678, -0.0493]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2580, -0.3187, -0.1538,  ...,  0.1052, -0.3036, -0.3610],
#         [ 0.1214,  0.0872, -0.1598,  ..., -0.1020, -0.3043, -0.1268],
#         [ 0.1920, -0.0646,  0.0499,  ..., -0.1303, -0.1266,  0.1608],
#         ...,
#         [ 0.0580,  0.2268, -0.3352,  ..., -0.0469, -0.1756,  0.1797],
#         [ 0.2571, -0.3243,  0.2568,  ..., -0.1420,  0.3077,  0.2209],
#         [ 0.1624,  0.0999,  0.1361,  ..., -0.1750,  0.0762, -0.1290]],
#        device='cuda:1')
# Epoch: 0008 lr: [0.001, 0.001] train_loss: 1.480934 train_acc: 0.581967 train_f1: 0.581967 time: 0.0618s
# Epoch: 0008 val_loss: 1.429977 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.0002304149501591493
# Grad of encoder.linear_before.E_linear.weight: 2.7239180905193777e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.007466190870927684
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 4.2859666375877964e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.007637960254151086
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 4.352743162662061e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.007541977064499896
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 4.329488056159431e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.0077428972576931996
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 4.446889967860381e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.007626522009044963
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 4.3597321370793424e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.007544286036079191
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 4.3197771144127734e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.08695495915398031
# Grad of decoder.bias: 0.1268709203908478
# Epoch 9 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0392,  0.0213,  ..., -0.0872, -0.0663,  0.0225],
#         [ 0.0329, -0.0435,  0.0316,  ..., -0.0403,  0.0379,  0.0154],
#         [-0.0225, -0.0647,  0.0629,  ..., -0.0433,  0.0548,  0.0146],
#         ...,
#         [ 0.0012, -0.0430, -0.0160,  ..., -0.0576, -0.0016,  0.0258],
#         [-0.0517,  0.0805, -0.0003,  ..., -0.0528,  0.0464, -0.0423],
#         [ 0.0585,  0.0624,  0.0212,  ..., -0.0632, -0.0178,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1777, -0.1102, -0.1381,  ..., -0.3995,  0.1390,  0.3453],
#         [ 0.2807,  0.1798,  0.1957,  ...,  0.3289, -0.1380, -0.0624],
#         [-0.1128, -0.1755,  0.1136,  ..., -0.0354, -0.2690, -0.0689],
#         ...,
#         [ 0.4202,  0.0650,  0.1217,  ..., -0.2614,  0.1332, -0.3744],
#         [-0.1036, -0.3810, -0.0625,  ...,  0.2053, -0.0648, -0.0226],
#         [-0.1393, -0.1114,  0.0686,  ...,  0.3635, -0.4149,  0.1001]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3498,  0.2395, -0.4075,  ...,  0.3461,  0.3595, -0.1647],
#         [-0.3723,  0.4047,  0.2598,  ..., -0.1989,  0.0074, -0.3519],
#         [ 0.3679,  0.2255,  0.1513,  ..., -0.4018,  0.0497,  0.3987],
#         ...,
#         [-0.2964, -0.3189,  0.3140,  ..., -0.4129,  0.1665, -0.2728],
#         [-0.2164,  0.1840, -0.1822,  ...,  0.3451, -0.2817, -0.0781],
#         [-0.0614,  0.3412, -0.1969,  ...,  0.0290,  0.2972,  0.4137]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.1988, -0.1285, -0.1692,  ..., -0.1154,  0.2209,  0.1315],
#         [-0.0013,  0.3734, -0.1798,  ...,  0.2763,  0.0297,  0.0246],
#         [ 0.0988, -0.2233, -0.1751,  ..., -0.3362, -0.2519, -0.3863],
#         ...,
#         [-0.0473, -0.0067,  0.2410,  ..., -0.0119,  0.2693, -0.0307],
#         [ 0.2535, -0.0323, -0.0759,  ..., -0.0448, -0.3203, -0.0698],
#         [ 0.3476, -0.4113, -0.2759,  ...,  0.3280, -0.2251, -0.1580]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3505,  0.0892, -0.3100,  ...,  0.1563, -0.1444, -0.0065],
#         [-0.3233,  0.3346, -0.0198,  ...,  0.4252,  0.0020, -0.1811],
#         [ 0.0062, -0.1311, -0.3881,  ..., -0.1220, -0.0640,  0.2426],
#         ...,
#         [ 0.3947, -0.0585,  0.0844,  ...,  0.2605,  0.1815, -0.1823],
#         [-0.0458, -0.3463, -0.2309,  ...,  0.0303,  0.3991,  0.2461],
#         [-0.2011,  0.0634,  0.1445,  ...,  0.1805,  0.3259,  0.2890]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.3023,  0.0798, -0.1599,  ...,  0.0445, -0.4284, -0.3420],
#         [ 0.1533,  0.2519,  0.3713,  ...,  0.2341,  0.0750, -0.1688],
#         [ 0.1235,  0.2427, -0.1304,  ..., -0.1717,  0.0504, -0.2528],
#         ...,
#         [ 0.0444, -0.0674,  0.2731,  ..., -0.2666,  0.0199,  0.3458],
#         [-0.3433, -0.1025, -0.3255,  ...,  0.1375,  0.4029,  0.1764],
#         [-0.3573, -0.4099,  0.1302,  ...,  0.3216, -0.0678, -0.0491]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.2574, -0.3185, -0.1536,  ...,  0.1056, -0.3028, -0.3607],
#         [ 0.1210,  0.0868, -0.1603,  ..., -0.1024, -0.3047, -0.1272],
#         [ 0.1930, -0.0641,  0.0508,  ..., -0.1295, -0.1256,  0.1615],
#         ...,
#         [ 0.0585,  0.2275, -0.3346,  ..., -0.0473, -0.1764,  0.1799],
#         [ 0.2579, -0.3236,  0.2577,  ..., -0.1414,  0.3084,  0.2211],
#         [ 0.1622,  0.1001,  0.1359,  ..., -0.1751,  0.0763, -0.1284]],
#        device='cuda:1')
# Epoch: 0009 lr: [0.001, 0.001] train_loss: 1.464566 train_acc: 0.581967 train_f1: 0.581967 time: 0.0619s
# Epoch: 0009 val_loss: 1.408075 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.0002880587575735317
# Grad of encoder.linear_before.E_linear.weight: 2.717118829705405e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.00760577970417004
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 5.182767144036957e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.007849236159568106
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 5.3521503733635355e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.007690621074938578
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 5.24769218885463e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.008008385599929543
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 5.520729010092462e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.007912984017408663
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 5.398665980024271e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.00779979136249544
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 5.3173699670058816e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.085164561215369
# Grad of decoder.bias: 0.12336935875318432
# Epoch 10 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642,  0.0385,  0.0209,  ..., -0.0881, -0.0672,  0.0225],
#         [ 0.0329, -0.0437,  0.0316,  ..., -0.0411,  0.0370,  0.0154],
#         [-0.0225, -0.0655,  0.0622,  ..., -0.0442,  0.0548,  0.0146],
#         ...,
#         [ 0.0012, -0.0437, -0.0164,  ..., -0.0585, -0.0020,  0.0258],
#         [-0.0517,  0.0812, -0.0010,  ..., -0.0534,  0.0460, -0.0423],
#         [ 0.0585,  0.0617,  0.0212,  ..., -0.0624, -0.0176,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1770, -0.1107, -0.1386,  ..., -0.3998,  0.1384,  0.3449],
#         [ 0.2803,  0.1795,  0.1953,  ...,  0.3286, -0.1385, -0.0628],
#         [-0.1118, -0.1751,  0.1145,  ..., -0.0346, -0.2681, -0.0683],
#         ...,
#         [ 0.4208,  0.0657,  0.1224,  ..., -0.2620,  0.1331, -0.3743],
#         [-0.1027, -0.3802, -0.0616,  ...,  0.2059, -0.0641, -0.0222],
#         [-0.1392, -0.1111,  0.0685,  ...,  0.3635, -0.4143,  0.1004]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.3491,  0.2389, -0.4079,  ...,  0.3458,  0.3590, -0.1646],
#         [-0.3727,  0.4043,  0.2594,  ..., -0.1992,  0.0070, -0.3523],
#         [ 0.3689,  0.2259,  0.1522,  ..., -0.4010,  0.0506,  0.3993],
#         ...,
#         [-0.2957, -0.3181,  0.3147,  ..., -0.4135,  0.1665, -0.2725],
#         [-0.2155,  0.1848, -0.1812,  ...,  0.3457, -0.2810, -0.0780],
#         [-0.0614,  0.3416, -0.1971,  ...,  0.0289,  0.2972,  0.4140]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.1980, -0.1279, -0.1685,  ..., -0.1155,  0.2215,  0.1317],
#         [-0.0016,  0.3731, -0.1802,  ...,  0.2760,  0.0293,  0.0242],
#         [ 0.0997, -0.2231, -0.1742,  ..., -0.3354, -0.2510, -0.3857],
#         ...,
#         [-0.0467, -0.0059,  0.2417,  ..., -0.0125,  0.2692, -0.0304],
#         [ 0.2544, -0.0315, -0.0749,  ..., -0.0442, -0.3196, -0.0697],
#         [ 0.3472, -0.4114, -0.2762,  ...,  0.3277, -0.2253, -0.1581]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.3510,  0.0887, -0.3100,  ...,  0.1559, -0.1443, -0.0066],
#         [-0.3237,  0.3343, -0.0202,  ...,  0.4248,  0.0016, -0.1815],
# ...
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1740, -0.1926, -0.0813,  ...,  0.1432, -0.1912, -0.3953],
#         [ 0.1838,  0.1992, -0.1136,  ...,  0.0151, -0.1981, -0.0658],
#         [ 0.2031, -0.0928,  0.1017,  ..., -0.0666, -0.0555,  0.0788],
#         ...,
#         [ 0.0229,  0.2016, -0.2706,  ..., -0.1932, -0.1630,  0.1616],
#         [ 0.2729, -0.1518,  0.3062,  ..., -0.0512,  0.3977,  0.3020],
#         [ 0.1962,  0.1042,  0.1558,  ..., -0.1937,  0.0685,  0.0025]],
#        device='cuda:1')
# Epoch: 0122 lr: [0.001, 0.001] train_loss: 0.885258 train_acc: 0.581967 train_f1: 0.581967 time: 0.0590s
# Epoch: 0122 val_loss: 0.787362 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.004164631236631219
# Grad of encoder.linear_before.E_linear.weight: 3.6493758348622753e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.0008858409459102841
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 0.00014754261676559852
# Grad of encoder.layers.0.net.linears.1.bias: 0.0009021364017252307
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 0.00021150283053661121
# Grad of encoder.layers.0.net.linears.2.bias: 0.0010663218176019153
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 0.00019858762786850048
# Grad of encoder.layers.0.net.linears.3.bias: 0.0008585613329674078
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 0.00018275610248288563
# Grad of encoder.layers.0.net.linears.4.bias: 0.0009386154885965915
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 0.00022710492143715653
# Grad of encoder.layers.0.net.linears.5.bias: 0.0009635730276502965
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 0.00017650748395070125
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.012475569958655293
# Grad of decoder.bias: 0.010212100693824068
# Epoch 123 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642, -0.0049,  0.0550,  ..., -0.1338, -0.0395,  0.0225],
#         [ 0.0329, -0.0563,  0.0390,  ..., -0.0454, -0.0420,  0.0154],
#         [-0.0225, -0.1259,  0.0311,  ..., -0.1206,  0.1104,  0.0146],
#         ...,
#         [ 0.0012, -0.1007,  0.0469,  ..., -0.1302,  0.0075,  0.0258],
#         [-0.0516,  0.0190, -0.0060,  ..., -0.1274,  0.0970, -0.0423],
#         [ 0.0585,  0.0352, -0.0031,  ..., -0.0501, -0.0544,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1657, -0.0692, -0.0644,  ..., -0.2561,  0.1176,  0.2706],
#         [ 0.2890,  0.2457,  0.1734,  ...,  0.3363, -0.1525,  0.0016],
#         [-0.1244, -0.2646,  0.1146,  ..., -0.0145, -0.2238, -0.1769],
#         ...,
#         [ 0.3692,  0.0103,  0.1504,  ..., -0.4133,  0.1113, -0.3929],
#         [-0.0703, -0.2174, -0.0085,  ...,  0.2477,  0.0111,  0.0647],
#         [-0.0261, -0.0634,  0.1912,  ...,  0.3419, -0.2778,  0.2300]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.2602,  0.1341, -0.3792,  ...,  0.2033,  0.2502, -0.1219],
#         [-0.3308,  0.4971,  0.2497,  ..., -0.1211,  0.0482, -0.2930],
#         [ 0.3093,  0.0983,  0.1277,  ..., -0.3842,  0.0280,  0.2979],
#         ...,
#         [-0.3134, -0.3019,  0.3846,  ..., -0.5311,  0.1969, -0.2264],
#         [-0.1516,  0.3534, -0.0954,  ...,  0.4191, -0.1658,  0.0020],
#         [ 0.0076,  0.3370, -0.1099,  ..., -0.0090,  0.3240,  0.5489]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.1103, -0.0347, -0.1367,  ..., -0.0347,  0.1522,  0.0109],
#         [ 0.0202,  0.4589, -0.1894,  ...,  0.3016,  0.0456,  0.0887],
#         [ 0.0830, -0.2542, -0.1602,  ..., -0.2786, -0.2136, -0.4153],
#         ...,
#         [-0.0801, -0.0419,  0.2828,  ..., -0.1581,  0.2630, -0.0658],
#         [ 0.3198,  0.1381,  0.0112,  ...,  0.0763, -0.1915,  0.0037],
#         [ 0.3040, -0.4341, -0.2700,  ...,  0.2048, -0.2710, -0.0336]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.2462,  0.0892, -0.1891,  ...,  0.1580, -0.0257, -0.0489],
#         [-0.2842,  0.4273, -0.0142,  ...,  0.4732,  0.0574, -0.1152],
#         [ 0.0227, -0.1262, -0.3390,  ..., -0.0692, -0.0231,  0.1838],
#         ...,
#         [ 0.3497, -0.1027,  0.1348,  ...,  0.1057,  0.1724, -0.1681],
#         [ 0.0257, -0.1773, -0.1469,  ...,  0.1521,  0.5028,  0.3237],
#         [-0.2203, -0.0322,  0.1028,  ...,  0.0443,  0.2238,  0.4173]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.1929,  0.0556, -0.1039,  ...,  0.0928, -0.3075, -0.2526],
#         [ 0.1297,  0.2856,  0.3078,  ...,  0.1947, -0.0153, -0.1072],
#         [ 0.1750,  0.2612, -0.0489,  ..., -0.0881,  0.1343, -0.2803],
#         ...,
#         [ 0.0190, -0.0891,  0.3411,  ..., -0.3993,  0.0438,  0.3297],
#         [-0.2878,  0.0587, -0.2593,  ...,  0.2108,  0.4766,  0.2475],
#         [-0.3009, -0.4095,  0.1731,  ...,  0.2179, -0.0617,  0.0825]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1735, -0.1905, -0.0804,  ...,  0.1432, -0.1895, -0.3934],
#         [ 0.1846,  0.2012, -0.1134,  ...,  0.0169, -0.1976, -0.0637],
#         [ 0.2038, -0.0917,  0.1024,  ..., -0.0650, -0.0543,  0.0781],
#         ...,
#         [ 0.0223,  0.2008, -0.2701,  ..., -0.1938, -0.1625,  0.1595],
#         [ 0.2730, -0.1499,  0.3065,  ..., -0.0497,  0.3987,  0.3041],
#         [ 0.1963,  0.1064,  0.1552,  ..., -0.1926,  0.0668,  0.0047]],
#        device='cuda:1')
# Epoch: 0123 lr: [0.001, 0.001] train_loss: 0.879590 train_acc: 0.581967 train_f1: 0.581967 time: 0.0595s
# Epoch: 0123 val_loss: 0.782784 val_acc: 0.704545 val_f1: 0.704545
# Grad of encoder.linear_before.bias: 0.006077128733948743
# Grad of encoder.linear_before.E_linear.weight: 4.436405189242415e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.0010566310249529912
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 0.0001455297800561219
# Grad of encoder.layers.0.net.linears.1.bias: 0.0011233935036186673
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 0.0002130591073875074
# Grad of encoder.layers.0.net.linears.2.bias: 0.0012382496430882735
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 0.00019949469283434305
# Grad of encoder.layers.0.net.linears.3.bias: 0.0010133917119317629
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 0.00017583833175058002
# Grad of encoder.layers.0.net.linears.4.bias: 0.0010423744778792574
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 0.00021886279307964515
# Grad of encoder.layers.0.net.linears.5.bias: 0.0011315861520368922
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 0.0001719186476102731
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.013332765807737812
# Grad of decoder.bias: 0.011183294632724466
# Epoch 124 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0642, -0.0053,  0.0550,  ..., -0.1344, -0.0389,  0.0225],
#         [ 0.0329, -0.0564,  0.0391,  ..., -0.0451, -0.0430,  0.0154],
#         [-0.0225, -0.1265,  0.0310,  ..., -0.1215,  0.1106,  0.0146],
#         ...,
#         [ 0.0012, -0.1008,  0.0475,  ..., -0.1307,  0.0074,  0.0258],
#         [-0.0516,  0.0184, -0.0052,  ..., -0.1281,  0.0978, -0.0423],
#         [ 0.0585,  0.0356, -0.0029,  ..., -0.0492, -0.0552,  0.0071]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.1660, -0.0694, -0.0638,  ..., -0.2545,  0.1172,  0.2692],
#         [ 0.2897,  0.2475,  0.1735,  ...,  0.3377, -0.1523,  0.0036],
#         [-0.1239, -0.2652,  0.1149,  ..., -0.0132, -0.2224, -0.1786],
#         ...,
#         [ 0.3686,  0.0094,  0.1504,  ..., -0.4138,  0.1111, -0.3943],
#         [-0.0704, -0.2157, -0.0085,  ...,  0.2480,  0.0112,  0.0667],
#         [-0.0259, -0.0632,  0.1920,  ...,  0.3408, -0.2772,  0.2321]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[ 0.2588,  0.1324, -0.3787,  ...,  0.2013,  0.2482, -0.1207],
#         [-0.3302,  0.4990,  0.2490,  ..., -0.1196,  0.0478, -0.2910],
#         [ 0.3092,  0.0965,  0.1280,  ..., -0.3825,  0.0285,  0.2961],
#         ...,
#         [-0.3135, -0.3009,  0.3852,  ..., -0.5307,  0.1976, -0.2257],
#         [-0.1515,  0.3551, -0.0948,  ...,  0.4196, -0.1650,  0.0041],
#         [ 0.0075,  0.3378, -0.1088,  ..., -0.0092,  0.3231,  0.5511]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.1096, -0.0343, -0.1362,  ..., -0.0335,  0.1516,  0.0087],
#         [ 0.0206,  0.4609, -0.1899,  ...,  0.3026,  0.0452,  0.0908],
#         [ 0.0831, -0.2527, -0.1606,  ..., -0.2770, -0.2135, -0.4133],
#         ...,
#         [-0.0806, -0.0429,  0.2826,  ..., -0.1586,  0.2628, -0.0679],
#         [ 0.3208,  0.1399,  0.0124,  ...,  0.0783, -0.1898,  0.0056],
#         [ 0.3029, -0.4322, -0.2706,  ...,  0.2036, -0.2724, -0.0318]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.2452,  0.0885, -0.1880,  ...,  0.1573, -0.0246, -0.0487],
#         [-0.2838,  0.4291, -0.0147,  ...,  0.4738,  0.0569, -0.1131],
#         [ 0.0223, -0.1244, -0.3395,  ..., -0.0692, -0.0240,  0.1852],
#         ...,
#         [ 0.3491, -0.1036,  0.1351,  ...,  0.1049,  0.1723, -0.1687],
#         [ 0.0259, -0.1757, -0.1467,  ...,  0.1534,  0.5030,  0.3256],
#         [-0.2214, -0.0316,  0.1018,  ...,  0.0430,  0.2220,  0.4194]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[-0.1916,  0.0541, -0.1030,  ...,  0.0933, -0.3060, -0.2514],
#         [ 0.1301,  0.2875,  0.3074,  ...,  0.1957, -0.0157, -0.1051],
#         [ 0.1750,  0.2621, -0.0490,  ..., -0.0877,  0.1342, -0.2784],
#         ...,
#         [ 0.0185, -0.0896,  0.3415,  ..., -0.3994,  0.0443,  0.3280],
#         [-0.2875,  0.0602, -0.2591,  ...,  0.2117,  0.4766,  0.2493],
#         [-0.3010, -0.4075,  0.1736,  ...,  0.2167, -0.0628,  0.0846]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1730, -0.1885, -0.0796,  ...,  0.1430, -0.1880, -0.3916],
#         [ 0.1854,  0.2033, -0.1131,  ...,  0.0187, -0.1970, -0.0617],
#         [ 0.2044, -0.0906,  0.1032,  ..., -0.0636, -0.0531,  0.0773],
#         ...,
#         [ 0.0217,  0.2000, -0.2696,  ..., -0.1944, -0.1620,  0.1575],
#         [ 0.2731, -0.1481,  0.3069,  ..., -0.0480,  0.3998,  0.3060],
#         [ 0.1963,  0.1085,  0.1546,  ..., -0.1914,  0.0651,  0.0068]],
#        device='cuda:1')
# Epoch: 0124 lr: [0.001, 0.001] train_loss: 0.876683 train_acc: 0.581967 train_f1: 0.581967 time: 0.0601s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 68
#      66     embeddings = model.encode(data['features'], (nei, nei_mask))
#      67 elif args.model == 'BKNet':
# ---> 68     embeddings = model.encode(data['features'], (nei, nei_mask))
#      69 else:
#      70     embeddings = model.encode(data['features'],
#      71                             data['adj_train_norm'])
#
# File /data/lige/HKN/models/base_models.py:52, in BaseModel.encode(self, x, adj)
#      50 elif self.manifold.name in ['PoincareBall']:
#      51     x = self.manifold.expmap0(x,c=self.c)#Using manifold.base
# ---> 52 h = self.encoder.encode(x, adj)
#      53 #Note: h is the updated feature points matrix of shape (n,d')
#      54 return h
#
# File /data/lige/HKN/models/encoders.py:415, in BKNet.encode(self, x, adj)
#     413     x_hyp = self.linear_before(x_hyp)
#     414 #print(f"adj: {adj}")
# --> 415 return super(BKNet, self).encode(x_hyp, adj)
#
# File /data/lige/HKN/models/encoders.py:35, in Encoder.encode(self, x, adj)
#      33     nei, nei_mask = adj
#      34     input = (x, nei, nei_mask)
# ---> 35     output, _, __ = self.layers.forward(input)
#      36     #Actually corresponds to (h, nei, nei_mask), but we only need h as output
#      37 elif self.encode_graph:
#      38     #Not sure what this means
#
# File /data/lige/miniconda3/envs/HKNet/lib/python3.10/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File /data/lige/miniconda3/envs/HKNet/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /data/lige/HKN/layers/B_layers.py:608, in KPGraphConvolution.forward(self, input)
#     606 def forward(self, input):
#     607     x, nei, nei_mask = input
# --> 608     h = self.net(x, nei, nei_mask)
#     609     output = h, nei, nei_mask
#     610     return output
#
# File /data/lige/miniconda3/envs/HKNet/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /data/lige/HKN/layers/B_layers.py:561, in KernelPointAggregation.forward(self, x, nei, nei_mask, transp, sample, sample_num)
#     558     x_nei_transform = self.apply_kernel_transform(x_nei) #(n,K,nei_num,d)
#     559 else:
#     560     #print('corr == 1') #Use d(xik, xk)
# --> 561     x_nei_transform = self.apply_kernel_transform(x_nei) #(n,K,nei_num,d)
#     562     if x_nei.shape[-1] != x_nei_transform.shape[-1]:
#     563         raise ValueError("Don't change dimension in linear transformation step if use corr==1")
#
# File /data/lige/HKN/layers/B_layers.py:496, in KernelPointAggregation.apply_kernel_transform(self, x_nei)
#     494 res = []
#     495 for k in range(self.K):
# --> 496     res.append(self.linears[k](x_nei).unsqueeze(1))
#     497 return torch.concat(res, dim = 1)
#
# File /data/lige/miniconda3/envs/HKNet/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /data/lige/HKN/layers/B_layers.py:271, in BLinear.forward(self, x)
#     268 if self.use_bias:
#     269     bias = self.manifold.proj_tan0(self.bias.view(1, -1), self.c)
#     270     res = self.manifold.proj(self.manifold.mobius_add(res, #then mobius addition
# --> 271                             self.manifold.expmap0(bias, self.c), self.c), # a bias on manifold
#     272                             self.c)
#     273 return res
#
# File /data/lige/HKN/manifolds/poincare.py:87, in PoincareBall.expmap0(self, u, c)
#      85 def expmap0(self, u, c):
#      86     sqrt_c = c ** 0.5
# ---> 87     u_norm = torch.clamp_min(u.norm(dim=-1, p=2, keepdim=True), self.min_norm)
#      88     #gamma_1 = tanh((sqrt_c * u_norm).clamp(-self.max_tanh, self.max_tanh)) * u / (sqrt_c * u_norm)
#      89     #return self.proj(gamma_1, c)
#      90     return self.proj(tanh((sqrt_c * u_norm).clamp(-self.max_tanh, self.max_tanh)) * u / (sqrt_c * u_norm),c)
#
# KeyboardInterrupt:

# %% [markdown]
# # Graph Classification

# %%
import argparse
from types import SimpleNamespace
import sys
sys.path.append('/data/lige/HKN')# Please change accordingly!

from __future__ import division
from __future__ import print_function

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter

import datetime
import json
import logging
from optim import RiemannianAdam, RiemannianSGD
import os
import pickle
import time

import numpy as np
import torch
from config import parser
from models.base_models import NCModel, LPModel, GCModel
from utils.data_utils import load_data, get_nei, GCDataset, split_batch
from utils.train_utils import get_dir_name, format_metrics
from utils.eval_utils import acc_f1

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter


os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:128'
torch.cuda.empty_cache()



config_args = {
    'training_config': {
        'lr': (1e-3, 'learning rate'),
        'dropout': (0.3, 'dropout probability'),
        'cuda': (1, 'which cuda device to use (-1 for cpu training)'),
        'epochs': (1000, 'maximum number of epochs to train for'),
        'weight_decay': (1e-3, 'l2 regularization strength'),
        'optimizer': ('radam', 'which optimizer to use, can be any of [rsgd, radam]'),
        'momentum': (0.999, 'momentum in optimizer'),
        'patience': (15, 'patience for early stopping'),
        'seed': (7, 'seed for training'),
        'log_freq': (1, 'how often to compute print train/val metrics (in epochs)'),
        'eval_freq': (1, 'how often to compute val metrics (in epochs)'),
        'save': (0, '1 to save model and logs and 0 otherwise'),
        'save_dir': (None, 'path to save training logs and model weights (defaults to logs/task/date/run/)'),
        'sweep_c': (0, ''),
        'lr_reduce_freq': (None, 'reduce lr every lr-reduce-freq or None to keep lr constant'),
        'gamma': (0.5, 'gamma for lr scheduler'),
        'print_epoch': (True, ''),
        'grad_clip': (None, 'max norm for gradient clipping, or None for no gradient clipping'),
        'min_epochs': (300, 'do not early stop before min-epochs')
    },
    'model_config': {
        'use_geoopt': (False, "which manifold class to use, if false then use basd.manifold"),
        'AggKlein':(True, "if false, then use hyperboloid centorid for aggregation"),
        'corr': (1,'0: d(x_i ominus x, x_k), 1: d(x_ik,x_k)'),
        'task': ('gc', 'which tasks to train on, can be any of [lp, nc]'),
        'model': ('BKNet', 'which encoder to use, can be any of [Shallow, MLP, HNN, GCN, GAT, HyperGCN, HyboNet,BKNet,BMLP]'),
        'dim': (32, 'embedding dimension'), #The final dimension as the embedded vector
        #'dim': (64, 'embedding dimension'),
        'manifold': ('PoincareBall', 'which manifold to use, can be any of [Euclidean, Hyperboloid, PoincareBall, Lorentz]'),
        'c': (1.0, 'hyperbolic radius, set to None for trainable curvature'),
        'r': (2., 'fermi-dirac decoder parameter for lp'),
        't': (1., 'fermi-dirac decoder parameter for lp'),
        'margin': (2., 'margin of MarginLoss'),
        'pretrained_embeddings': (None, 'path to pretrained embeddings (.npy file) for Shallow node classification'),
        'pos_weight': (0, 'whether to upweight positive class in node classification tasks'),
        'num_layers': (2, 'number of hidden layers in encoder'),
        'bias': (1, 'whether to use bias (1) or not (0)'),
        'act': ('relu', 'which activation function to use (or None for no activation)'),
        'n_heads': (4, 'number of attention heads for graph attention networks, must be a divisor dim'),
        'alpha': (0.2, 'alpha for leakyrelu in graph attention networks'),
        'double_precision': ('1', 'whether to use double precision'),
        'use_att': (0, 'whether to use hyperbolic attention or not'),
        'local_agg': (0, 'whether to local tangent space aggregation or not'),
        'kernel_size': (6, 'number of kernels'),
        'KP_extent': (0.66, 'influence radius of each kernel point'),
        'radius': (1, 'radius used for kernel point init'),
        'deformable': (False, 'deformable kernel'),
        #'linear_before': (64, 'dim of linear before gcn')#The dimension after linear_before(dimensionality reduction if you would)
        'linear_before': (32, 'dim of linear before gcn')#64
    },
    'data_config': {
        #'dataset': ('pubmed', 'which dataset to use(cornell,wisconsin,texas,squirrel,cora)'),
        'dataset': ('PTC', 'which dataset to use(cornell,wisconsin,texas,squirrel,cora)'),
        'batch_size': (64, 'batch size for gc'),
        'val_prop': (0.05, 'proportion of validation edges for link prediction'),
        'test_prop': (0.1, 'proportion of test edges for link prediction'),
        'use_feats': (1, 'whether to use node features or not'),
        'normalize_feats': (1, 'whether to normalize input node features'),
        'normalize_adj': (1, 'whether to row-normalize the adjacency matrix'),
        'split_seed': (7, 'seed for data splits (train/test/val)'),
        'split_graph': (False, 'whether to split the graph')
    }
}

# 将所有参数转换为 SimpleNamespace
args = SimpleNamespace(
    **{k: v[0] for config in config_args.values() for k, v in config.items()}
)

#choose which manifold class to follow 
if args.use_geoopt == False:
    ManifoldParameter = base_ManifoldParameter
else:
    ManifoldParameter = geoopt_ManifoldParameter
np.random.seed(args.seed)#args.seed
torch.manual_seed(args.seed)#args.seed
if int(args.cuda):#args.double_precision
    torch.set_default_dtype(torch.float64)
if int(args.cuda) >= 0:#args.cuda
    torch.cuda.manual_seed(args.seed)#args.seed
args.device = 'cuda:' + str(args.cuda) if int(args.cuda) >= 0 else 'cpu' #args.device actually,<-args.cuda
args.patience = args.epochs if not args.patience else args.patience #args.patience<-args.epochs|args.patience

print(f'Using: {args.device}')
print("Using seed {}.".format(args.seed))
print(f"Dataset: {args.dataset}")

# Load data
data = load_data(args, os.path.join('data', args.dataset))
if args.task == 'gc':
    args.n_nodes, args.feat_dim = data['features'][0].shape
else:
    args.n_nodes, args.feat_dim = data['features'].shape
if args.task == 'nc':
    Model = NCModel
    args.n_classes = int(data['labels'].max() + 1)
    args.data = data
    print(f'Num classes: {args.n_classes}')
elif args.task == 'gc':
    Model = GCModel
    args.n_classes = int(data['labels'].max() + 1)
    print(f'Num classes: {args.n_classes}')
else:
    args.nb_false_edges = len(data['train_edges_false'])
    args.nb_edges = len(data['train_edges'])
    if args.task == 'lp':
        Model = LPModel
        args.n_classes = 2

if not args.lr_reduce_freq:
    args.lr_reduce_freq = args.epochs


###A simple check on data
print(data.keys())
###A simple check on data

# Model and optimizer
model = Model(args)
print(str(model))
no_decay = ['bias', 'scale']
optimizer_grouped_parameters = [{
    'params': [
        p for n, p in model.named_parameters()
        if p.requires_grad and not any(
            nd in n
            for nd in no_decay) and not isinstance(p, ManifoldParameter)
    ],
    'weight_decay':
    args.weight_decay
}, {
    'params': [
        p for n, p in model.named_parameters() if p.requires_grad and any(
            nd in n
            for nd in no_decay) or isinstance(p, ManifoldParameter)
    ],
    'weight_descay':
    0.0
}]
if args.optimizer == 'radam':
    optimizer = RiemannianAdam(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
elif args.optimizer == 'rsgd':
    optimizer = RiemannianSGD(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=int(
                                                args.lr_reduce_freq),
                                                gamma=float(args.gamma))
tot_params = sum([np.prod(p.size()) for p in model.parameters()])
model = model.to(args.device)
for x, val in data.items():
    if torch.is_tensor(data[x]):
        data[x] = data[x].to(args.device)
print(f"Total number of parameters: {tot_params}")

# Train model for nc:
t_total = time.time()
counter = 0
best_val_metrics = model.init_metric_dict()
best_test_metrics = None
best_emb = None
if args.n_classes > 2:
    f1_average = 'micro'
else:
    f1_average = 'binary'

print(f"Memory allocated: {torch.cuda.memory_allocated() / 1024 ** 2:.2f} MB")  # 打印当前分配的显存
# Out:
# Using: cuda:1
# Using seed 7.
# Dataset: PTC
# loading data
# # classes: 2
# # maximum node tag: 19
# # data: 344
# Num classes: 2
# dict_keys(['adj_train', 'features', 'labels', 'idx_train', 'idx_val', 'idx_test'])
# GCModel(
#   (encoder): BKNet(
#     (linear_before): BLinear(
#       in_features=19, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#       (dropout): Dropout(p=0.3, inplace=False)
#       (E_linear): Linear(in_features=19, out_features=32, bias=False)
#     )
#     (layers): Sequential(
#       (0): KPGraphConvolution(
#         (net): KernelPointAggregation(
#           (linears): ModuleList(
#             (0): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (1): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (2): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (3): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (4): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#             (5): BLinear(
#               in_features=32, out_features=32, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=32, out_features=32, bias=False)
#             )
#           )
#           (act): BAct(c=tensor([1.], device='cuda:1'), act=<function relu at 0x7f5ef63a7490>)
#         )
#       )
#     )
#   )
#   (decoder): PoincarePoolDecoder()
# )
# Total number of parameters: 7234
# Memory allocated: 0.00 MB
# /data/lige/HKN/utils/data_utils.py:613: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adjs.append(sp.csr_matrix(nx.adjacency_matrix(g.g)))

# %%
if args.task == 'gc':
    dataset = GCDataset((data['adj_train'], data['features'], data['labels']), KP=(args.model == 'HKPNet' or args.model == 'BKNet'),
                            normlize=args.normalize_adj, device=args.device)
for epoch in range(args.epochs):
    t = time.time()
    model.train()
    tot_metrics = {'loss': 0, 'acc': 0, 'f1': 0}
    outs = None
    labs = None
    bats = 0
    for i in range(0, len(data['idx_train']), args.batch_size):
        optimizer.zero_grad()
        selected_idx = data['idx_train'][i : i + args.batch_size]
        if len(selected_idx) == 0:
            continue
        if args.model == 'HKPNet':
            # Note ed_idx seems to be the index of graphs
            nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, (nei, nei_mask))
        elif args.model == 'BKNet':
            # shape(nei/nei_mask)=(sum(n),max_nei_num), like concat all graph neibor together
            # It works if every node on every graph is represented by different numbers yeah
            nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, (nei, nei_mask))
        else:
            adj, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, adj)
        # print(embeddings.shape,labels.shape,ed_idx.shape,len(ed_idx))
        train_metrics = model.compute_metrics(embeddings, labels, ed_idx, type=2)
        tot_metrics['loss'] += train_metrics['loss'].detach().cpu().numpy()
        bats += 1
        train_metrics['loss'].backward()
        
        # Print gradients of each trainable parameter
        print(f"Epoch {epoch + 1}, Batch {i//args.batch_size + 1}:")
        for name, param in model.named_parameters():
            if param.grad is not None:
                print(f"Parameter: {name}, Gradient: {param.grad.norm().item()}")

        if args.grad_clip is not None:
            max_norm = float(args.grad_clip)
            all_params = list(model.parameters())
            for param in all_params:
                torch.nn.utils.clip_grad_norm_(param, max_norm)
        optimizer.step()

        if outs is None:
            outs = train_metrics['output']
        else:
            outs = torch.cat([outs, train_metrics['output']], 0)
        if labs is None:
            labs = labels
        else:
            labs = torch.cat([labs, labels], 0)
    lr_scheduler.step()
    tot_metrics['acc'], tot_metrics['f1'] = acc_f1((outs), (labs), f1_average)
    tot_metrics['loss'] /= bats

    if (epoch + 1) % args.log_freq == 0:
        print(" ".join(['Epoch: {:04d}'.format(epoch + 1),
                        'lr: {}'.format(lr_scheduler.get_last_lr()),
                        format_metrics(tot_metrics, 'train'),
                        'time: {:.4f}s'.format(time.time() - t)
                        ]))
    if (epoch + 1) % args.eval_freq == 0:
        model.eval()
        tot_metrics = {'loss': 0, 'acc': 0, 'f1': 0}
        minibatch = args.batch_size
        outs = None
        labs = None
        bats = 0
        for i in range(0, len(data['idx_val']), minibatch):
            selected_idx = data['idx_val'][i : i + minibatch]
            if len(selected_idx) == 0:
                continue
            if args.model == 'HKPNet':
                nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
                embeddings = model.encode(features, (nei, nei_mask))
            elif args.model == 'BKNet':
                nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
                embeddings = model.encode(features, (nei, nei_mask))
            else:
                adj, features, labels, ed_idx = dataset[selected_idx]
                embeddings = model.encode(features, adj)
            val_metrics = model.compute_metrics(embeddings, labels, ed_idx, type=2)
            tot_metrics['loss'] += val_metrics['loss'].detach().cpu().numpy()
            bats += 1
            if outs is None:
                outs = val_metrics['output']
            else:
                outs = torch.cat([outs, val_metrics['output']], 0)
            if labs is None:
                labs = labels
            else:
                labs = torch.cat([labs, labels], 0)
        tot_metrics['acc'], tot_metrics['f1'] = acc_f1((outs), (labs), f1_average)
        tot_metrics['loss'] /= bats
        if (epoch + 1) % args.log_freq == 0:
            print(" ".join(['Epoch: {:04d}'.format(epoch + 1), format_metrics(tot_metrics, 'val')]))
        if model.has_improved(best_val_metrics, tot_metrics):
            best_val_metrics = tot_metrics
            best_test_metrics = {'loss': 0, 'acc': 0, 'f1': 0}
            minibatch = args.batch_size
            outs = None
            labs = None
            bats = 0
            for i in range(0, len(data['idx_test']), minibatch):
                selected_idx = data['idx_test'][i : i + minibatch]
                if len(selected_idx) == 0:
                    continue
                if args.model == 'HKPNet':
                    nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
                    embeddings = model.encode(features, (nei, nei_mask))
                elif args.model == 'BKNet':
                    nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
                    embeddings = model.encode(features, (nei, nei_mask))
                else:
                    adj, features, labels, ed_idx = dataset[selected_idx]
                    embeddings = model.encode(features, adj)
                test_metrics = model.compute_metrics(embeddings, labels, ed_idx, type=2)

                bats += 1
                tot_metrics['loss'] += test_metrics['loss'].detach().cpu().numpy()
                if outs is None:
                    outs = test_metrics['output']
                else:
                    outs = torch.cat([outs, test_metrics['output']], 0)
                if labs is None:
                    labs = labels
                else:
                    labs = torch.cat([labs, labels], 0)
            if outs is None:
                best_test_metrics = best_val_metrics
            else:
                best_val_metrics = tot_metrics
                best_test_metrics['acc'], best_test_metrics['f1'] = acc_f1((outs), (labs), f1_average)
                best_test_metrics['loss'] /= bats
            counter = 0
        else:
            counter += 1
            if counter == args.patience and epoch > args.min_epochs:
                print("Early stopping")
                break
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
if not best_test_metrics:
    model.eval()
    best_test_metrics = {'loss': 0, 'acc': 0, 'f1': 0}
    tot_metrics = {'loss': 0, 'acc': 0, 'f1': 0}
    minibatch = args.batch_size
    outs = None
    labs = None
    bats = 0
    for i in range(0, len(data['idx_test']), minibatch):
        selected_idx = data['idx_test'][i : i + minibatch]
        if len(selected_idx) == 0:
            continue
        if args.model == 'HKPNet':
            nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, (nei, nei_mask))
        elif args.model == 'BKNet':
            nei, nei_mask, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, (nei, nei_mask))
        else:
            adj, features, labels, ed_idx = dataset[selected_idx]
            embeddings = model.encode(features, adj)
        test_metrics = model.compute_metrics(embeddings, labels, ed_idx, type=2)

        bats += 1
        tot_metrics['loss'] += test_metrics['loss'].detach().cpu().numpy()
        if outs is None:
            outs = test_metrics['output']
        else:
            outs = torch.cat([outs, test_metrics['output']], 0)
        if labs is None:
            labs = labels
        else:
            labs = torch.cat([labs, labels], 0)
    if outs is None:
        best_test_metrics = best_val_metrics
    else:
        best_val_metrics = tot_metrics
        best_test_metrics['acc'], best_test_metrics['f1'] = acc_f1((outs), (labs), f1_average)
        best_test_metrics['loss'] /= bats

print(" ".join(["Val set results:", format_metrics(best_val_metrics, 'val')]))
print(" ".join(["Test set results:", format_metrics(best_test_metrics, 'test')]))
# Out:
# Epoch 1, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.04524230079746863
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.034235659348670434
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.03750118232430893
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02455389514768198
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.04940969750513675
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.024966072284692196
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.04939223847408134
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02729405681693661
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.04939173500170816
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.026540679848846803
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.04937516510902727
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02578393804564914
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.04936609933591162
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.021662595475554356
# Parameter: decoder.cls, Gradient: 3.4086827268864215
# Parameter: decoder.bias, Gradient: 0.7158100912371524
# Epoch 1, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.11830563391124076
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.0516596683566363
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.024842770911829265
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.022825043407512534
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03523203624526738
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.022031554847051105
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.034942682767453735
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02701241551735257
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.034930695708199254
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.024369478228401936
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03502875091841383
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.023712467595051977
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.034916915405763735
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.021136326793231557
# Parameter: decoder.cls, Gradient: 3.2982711629754085
# Parameter: decoder.bias, Gradient: 0.692130439419272
# Epoch 1, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.03432724974894206
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.01887492593933638
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.006813411250774085
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.005398624258786167
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.009557185159661795
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.005542304629826558
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.009447929578649844
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.0062739661594368645
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.009421695364352776
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.006536036374173965
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.00944519649404365
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.0054190826594491355
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.009426533359525611
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.004909762467406818
# Parameter: decoder.cls, Gradient: 0.7859316398093165
# Parameter: decoder.bias, Gradient: 0.16462652704458355
# Epoch 1, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.10225189726387147
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04617092318746827
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.018259133404475873
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.031710287962761374
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03029813971443688
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.030253018065131358
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03018890866071585
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.033510514733843484
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.030241975598027805
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.033968663016055126
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.030276095239086764
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03228412208592192
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.030168055534102404
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.027350006871567648
# Parameter: decoder.cls, Gradient: 3.617693609464372
# Parameter: decoder.bias, Gradient: 0.7560096891565758
# Epoch 1, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.06334383503357642
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03758859775280632
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.016938302933710066
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02889354852093047
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.02958070482007687
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.029187370794420204
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.029453131764114116
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.030669937260879496
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.029525782060193434
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.032601609916862985
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.029616344986479564
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.030669710381776964
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.029451442893018064
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.026681299500988045
# Parameter: decoder.cls, Gradient: 3.614963817380625
# Parameter: decoder.bias, Gradient: 0.7551075987718394
# Epoch: 0001 lr: [0.001, 0.001] train_loss: 0.717306 train_acc: 0.348993 train_f1: 0.517413 time: 1.2615s
# Epoch: 0001 val_loss: 0.696859 val_acc: 0.500000 val_f1: 0.666667
# Epoch 2, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.020537000846360235
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.029179428552836013
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.028522999470883062
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021670350689375135
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03863959472524708
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.021878042557533398
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03852307896688057
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02383223348736367
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.0385648467764262
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.024171807219511413
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.038579610428871786
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02281525803938812
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03850498812411526
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.01946006269682599
# Parameter: decoder.cls, Gradient: 3.1474058751712426
# Parameter: decoder.bias, Gradient: 0.6579576050507531
# Epoch 2, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.07903409342461112
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.032073021948727354
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02337613952729265
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021624020504606115
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03304376084415485
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.01995493400181915
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03269885193033333
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02360155833496287
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.032737324661691214
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.02250887366947099
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03275570030863503
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02177799051774516
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03270831500817572
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.01920490580345535
# Parameter: decoder.cls, Gradient: 3.120375027438903
# Parameter: decoder.bias, Gradient: 0.6521999130612129
# Epoch 2, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.045192148685335394
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03618578422695659
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.00636980560100873
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.004688126800441903
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.008676857887512518
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.004321173134047279
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.008519854574789784
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.004913299811809276
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.008536532348897587
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.005327196999991792
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.008551799643256046
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.004374150029485976
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.00857932054503299
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.004436734769243071
# Parameter: decoder.cls, Gradient: 0.66563288323138
# Parameter: decoder.bias, Gradient: 0.13896640398659266
# Epoch 2, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.10378707849778088
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04099001342190767
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.019867374455769794
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.03159349446852833
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03255152418802579
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.03087648864870135
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03242062822937168
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.0340312445513855
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03242749613229431
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.033430910285740176
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03246581432761395
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03253352011754429
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03235714070817726
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.027767486641196687
# Parameter: decoder.cls, Gradient: 3.6874847243491606
# Parameter: decoder.bias, Gradient: 0.769279590807202
# Epoch 2, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.10044483020575763
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.0496627436150897
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.017902069033828422
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02870263734331745
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.030703562844475698
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.02984422136594645
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.030573807213097035
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.031152074081824698
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.030622210266919768
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.03254690789138761
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.030670854449399022
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03091380454863645
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.030494954052770355
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.027162817350762203
# Parameter: decoder.cls, Gradient: 3.674583052668991
# Parameter: decoder.bias, Gradient: 0.766600826792697
# Epoch: 0002 lr: [0.001, 0.001] train_loss: 0.696555 train_acc: 0.567114 train_f1: 0.723769 time: 1.0991s
# Epoch: 0002 val_loss: 0.698039 val_acc: 0.500000 val_f1: 0.666667
# Epoch 3, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.06537039705289394
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.029046923373365043
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02469661361213232
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.020739315926609304
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03437554766554074
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.01967462380399109
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03405983127814284
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.022549533578170872
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03406982921102331
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.021625920880388946
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03408552911923615
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.021201221266752047
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03403404577273117
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.018948533403625137
# Parameter: decoder.cls, Gradient: 3.079100426190898
# Parameter: decoder.bias, Gradient: 0.6428848743075792
# Epoch 3, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.08432813728007703
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.032761745555274224
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02296329760948483
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.020777476600244586
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.031826539204643955
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.021364756621286583
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03143938886028934
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023364108389110586
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.031363624895520026
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.021559566423401958
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03143997553359182
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.020843735813294254
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03139443374830196
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.018758159302352338
# Parameter: decoder.cls, Gradient: 3.0706806617373803
# Parameter: decoder.bias, Gradient: 0.6412249790636206
# Epoch 3, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.1273381258274672
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03900600734486473
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.004985705469705182
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.005158048108010617
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.007520248292064874
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.005586752829306658
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.007499032273196333
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.006235236373094874
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.007514193643527258
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.005742377448295599
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.007497550979691526
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.006196868793395486
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.007485614950653473
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.005111434232466048
# Parameter: decoder.cls, Gradient: 0.6515362373686807
# Parameter: decoder.bias, Gradient: 0.13595853311164596
# Epoch 3, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.06055975057430987
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.0368544650212513
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.034912439189647884
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.025218252504310708
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.04640816810917692
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.02601377794318863
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.04622676437046917
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02745695501049214
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.04626775284259974
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.02731605667445766
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.04624353996997586
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.026585557184635067
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.046151178093180846
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02317754876601165
# Parameter: decoder.cls, Gradient: 3.705905297630857
# Parameter: decoder.bias, Gradient: 0.7729798978892924
# Epoch 3, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.07862098903048696
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03889684183579007
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.018200343905071165
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.029226620241260992
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.030902029872629733
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.02994013795762288
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03075523018071539
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03108084334096451
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.030777459277674057
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.03299574558089888
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.030790877519783072
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03129982242063531
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.030576494961128707
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.026795981670269496
# Parameter: decoder.cls, Gradient: 3.6813137916278085
# Parameter: decoder.bias, Gradient: 0.7679858297917483
# Epoch: 0003 lr: [0.001, 0.001] train_loss: 0.691429 train_acc: 0.567114 train_f1: 0.723769 time: 1.1109s
# Epoch: 0003 val_loss: 0.698390 val_acc: 0.500000 val_f1: 0.666667
# Epoch 4, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.061603601754653854
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03446716840997672
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02908063062625069
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02118666591589379
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03915328005541684
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.021939991667281594
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03904589134688713
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02286985034077443
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03905298855323038
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.022813940138020895
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03904731458567562
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02244126197907733
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.038917879794959614
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.018857827723245468
# Parameter: decoder.cls, Gradient: 3.086825276982141
# Parameter: decoder.bias, Gradient: 0.6444796833847586
# Epoch 4, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.06395845515907168
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.0333864275437748
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.024536122412268647
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.020548342223687007
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03371008757764054
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.019825665572112013
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.0334158451204358
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023088253758122547
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03342896933126424
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.021941909180403132
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.033456894502545166
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.020840418339801037
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03334493657635108
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.018965917630276732
# Parameter: decoder.cls, Gradient: 3.0608653918460065
# Parameter: decoder.bias, Gradient: 0.6391837986826016
# Epoch 4, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.01721487084626773
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.008711136415681718
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.006567461094146664
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.003917798703179968
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.009229909030674428
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.0035925831527705886
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.009201618833933188
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.004834596979832355
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.009172621025667743
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.004388994331722386
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.009188229657579134
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.004389368271595502
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.009161054170721918
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.0033761183433213353
# Parameter: decoder.cls, Gradient: 0.6208918469449359
# Parameter: decoder.bias, Gradient: 0.1296029206331619
# Epoch 4, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.10071912142076557
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04345785261519892
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02054921701893328
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.03165984678082592
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03292775578404073
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.030779533875481015
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03273620812084495
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.033954315120801055
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03278483011258229
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.032953661052763934
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03275472115316566
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03256755405474947
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03266638012936373
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02739764211923401
# Parameter: decoder.cls, Gradient: 3.7024709913155274
# Parameter: decoder.bias, Gradient: 0.7725836092326258
# Epoch 4, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.06945827483550827
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.038912557694682305
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.018430813411486776
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02960631700864997
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.030783970255097014
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.02978892255471989
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.030637046756577493
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03179848168472913
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.030678181721161466
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.03202850133812111
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.030626839580369936
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03160527324059418
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.030568591307587913
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02690627923638013
# Parameter: decoder.cls, Gradient: 3.6708167557070372
# Parameter: decoder.bias, Gradient: 0.7661590831464078
# Epoch: 0004 lr: [0.001, 0.001] train_loss: 0.690380 train_acc: 0.567114 train_f1: 0.723769 time: 1.1097s
# Epoch: 0004 val_loss: 0.698349 val_acc: 0.500000 val_f1: 0.666667
# Epoch 5, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.0810273533584949
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.035148068371527924
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02394592508852971
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021219577346627116
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03294694801751469
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.019438189308406028
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.032628514150732944
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023129657335623385
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03263510507747716
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.02254817279314904
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.0326045429123143
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02146074752019773
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03250725625486243
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.019109488302610673
# Parameter: decoder.cls, Gradient: 3.0618261291866853
# Parameter: decoder.bias, Gradient: 0.6395792726885877
# Epoch 5, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.07202308232403967
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.02892255041192844
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.024783653343076754
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02065359909308561
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.034420158521082336
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.019100850208743386
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.034074031817220275
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.022455212553298756
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.0340742627752958
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.021785304258577408
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03404256072441973
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.02076114030103476
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.033947682403250426
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.01904194826110125
# Parameter: decoder.cls, Gradient: 3.0602574313057267
# Parameter: decoder.bias, Gradient: 0.639394929169685
# Epoch 5, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.03938372973946059
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.016931898497989813
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.007744795138418739
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.004347607480888887
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.009825969530585291
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.004459496699290026
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.009705990533868026
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.004829602212401189
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.009723373225940518
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.004522478383064269
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.009689261042566073
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.004918805634750248
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.009696622547945021
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.00350999129043195
# Parameter: decoder.cls, Gradient: 0.6545796354081838
# Parameter: decoder.bias, Gradient: 0.13672043122589275
# Epoch 5, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.027539999767890525
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04126842471131207
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.035376340282405404
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.025871913365793246
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.04680136863059698
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.025755540430089072
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.046641827603635215
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.027761087646677486
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.04658229463792307
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.028214721741071425
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.046479268833906184
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.027072238387502875
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.046381020941260995
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02318511575278732
# Parameter: decoder.cls, Gradient: 3.6921373024512016
# Parameter: decoder.bias, Gradient: 0.7709891506902699
# Epoch 5, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.10864431289228758
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.051703872091959854
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.019187553013845775
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02919056350391832
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03208704806139944
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.029882943849385342
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.031890359888485154
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03172672300243233
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.0319006296267644
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.03342914718507196
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03181670403885061
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.031148083735112526
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03164320228505683
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02698214674758303
# Parameter: decoder.cls, Gradient: 3.6540011650779753
# Parameter: decoder.bias, Gradient: 0.763213710455167
# Epoch: 0005 lr: [0.001, 0.001] train_loss: 0.687973 train_acc: 0.567114 train_f1: 0.723769 time: 1.1168s
# Epoch: 0005 val_loss: 0.698108 val_acc: 0.500000 val_f1: 0.666667
# Epoch 6, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.07586195799685157
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03157771887435255
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02532150735312338
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.020233970152965183
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03487061631962159
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.02053390546457809
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03452026511427608
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023517041140386417
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03450842551390737
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.021419778423678235
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03444222375675584
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.020897074324083952
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.0343548720037828
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.0188774382177557
# Parameter: decoder.cls, Gradient: 3.0666185399823105
# Parameter: decoder.bias, Gradient: 0.6410489152856947
# Epoch 6, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.0634137411827888
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.029589599694929435
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.025358735531189926
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.020378885407023543
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03470332314359876
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.019884045806120236
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03439367953560245
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.02315184741941281
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03436571241117485
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.022141297702268976
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03429380463926544
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.020987799132280653
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03420211107315707
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.019379229792560265
# Parameter: decoder.cls, Gradient: 3.066259772666586
# Parameter: decoder.bias, Gradient: 0.6411120279564729
# Epoch 6, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.02932226200408451
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.014136153885473457
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.0061467630042161955
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.004794270663271749
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.00832445268969545
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.003666452767808186
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.008269930497848783
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.004847832648928367
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.008237014087079391
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.004059266239197106
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.008174576168380368
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.004412307413096336
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.00821312147816953
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.004333179265841113
# Parameter: decoder.cls, Gradient: 0.6323281554183602
# Parameter: decoder.bias, Gradient: 0.13216397114371192
# Epoch 6, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.10205240838606233
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04423851447371767
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.021239551070694935
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.030831709706548856
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03329755973500462
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.031016550810815374
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03321392022153842
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03376809530870401
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03314511801336109
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.032509193038086
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03297640431645802
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03388157566205934
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03291333441663862
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.027446917830539083
# Parameter: decoder.cls, Gradient: 3.657239384112766
# Parameter: decoder.bias, Gradient: 0.764353075688811
# Epoch 6, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.09674557369740247
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.04919558706001369
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.019406294496817196
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02979121144076564
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.032253229853791886
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.030505822683226526
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03213572160541161
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03170205126087513
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.032136628752257305
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.033307343431597296
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.0319728158696993
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03187956587682627
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03184786535994037
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02783135448934583
# Parameter: decoder.cls, Gradient: 3.63010900986715
# Parameter: decoder.bias, Gradient: 0.7588318103114553
# Epoch: 0006 lr: [0.001, 0.001] train_loss: 0.685170 train_acc: 0.567114 train_f1: 0.723769 time: 1.1239s
# Epoch: 0006 val_loss: 0.697786 val_acc: 0.500000 val_f1: 0.666667
# Epoch 7, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.07937255436945698
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03269659185508127
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.025134307908448998
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021040181484248376
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03446810215696987
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.020400607953260853
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.0341311399915815
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.0228893345797786
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.034106765685382824
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.02191100150584451
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03401912645857734
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.020849184847664265
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.0339393608725486
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.01899261450776754
# Parameter: decoder.cls, Gradient: 3.0734718106189813
# Parameter: decoder.bias, Gradient: 0.6429486413471379
# Epoch 7, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.04642311563040705
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03375181606939161
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.03241693394913226
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021359785458168076
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.04247262523226156
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.021392752734262107
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.042253889674631
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023315762439618002
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.04221177475526018
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.02321089353414025
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.04206970578256533
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.022567637365647084
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.041995252861417566
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.01928031020774372
# Parameter: decoder.cls, Gradient: 3.1117096566272915
# Parameter: decoder.bias, Gradient: 0.6510926839709116
# Epoch 7, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.05907006090022659
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.02610537882748303
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.006154401105730885
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.0054342155955156195
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.008821764186454042
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.004840096042253288
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.008813155513975534
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.005505989718125241
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.008789266383881307
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.00605408634327851
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.008728254912544947
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.005475299198123809
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.008714269765594838
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.004731185332693555
# Parameter: decoder.cls, Gradient: 0.6835046814990399
# Parameter: decoder.bias, Gradient: 0.1429803026156515
# Epoch 7, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 0.05856222767926496
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.051862128542739666
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.03694652309632229
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.025455070525409372
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.04858227825887462
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.024926639465069407
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.048402792403436645
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.028011563616365802
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.048375508890196206
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.028211911910020104
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.04815472578880029
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.027046671006136707
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.048085060378183525
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.0223694960668988
# Parameter: decoder.cls, Gradient: 3.654061456511464
# Parameter: decoder.bias, Gradient: 0.764289099748801
# Epoch 7, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 0.14639493005901474
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.05428261723084387
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02145956295879365
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.02941884933837531
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03595652569512127
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.030308405413385794
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.035791330533577546
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.03149534804947896
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03575960644236892
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.03346808598671526
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.035624831354074286
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.03162978000385575
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03537990025082146
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.02717870298400134
# Parameter: decoder.cls, Gradient: 3.608216496630393
# Parameter: decoder.bias, Gradient: 0.754850484608439
# Epoch: 0007 lr: [0.001, 0.001] train_loss: 0.687648 train_acc: 0.567114 train_f1: 0.723769 time: 1.1173s
# Epoch: 0007 val_loss: 0.697494 val_acc: 0.500000 val_f1: 0.666667
# Epoch 8, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.06615414829295128
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.030466400200295837
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02544647674370937
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021557642801330858
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03456430092306404
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.020572304383832864
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03421209918996243
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.023662235614823036
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.03417623306751389
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.0226464628933873
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03402606410284563
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.022052555565911448
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.033958272886443173
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.019869841152742252
# Parameter: decoder.cls, Gradient: 3.0812239253902374
# Parameter: decoder.bias, Gradient: 0.645021464411307
# Epoch 8, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.07517847215493734
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.03330682525032117
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.026414119742436598
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.021243657793764994
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03634302751093378
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.020102508099122604
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.0359880705369476
# ...
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.5586786686594893
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.027154558364750676
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.15326572388389376
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03496802151051145
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.10294802961928654
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03183146501387313
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.13038233659433784
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.0319756045982279
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.10119913816988343
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.031604244243150524
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.11963991745548119
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03178294816726841
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.12968752238382145
# Parameter: decoder.cls, Gradient: 2.685434518658258
# Parameter: decoder.bias, Gradient: 0.42321620954085504
# Epoch 354, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 5.897853452704393
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 2.1775496172627697
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.05614548328808203
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.12629516056672083
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.0690653093350705
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.18953137250519853
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.06337358365582199
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.1569292440634719
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.06406025830045406
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.17050482261744926
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.061287171281688264
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.1304941929950002
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.06378842887044173
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.19845088248279766
# Parameter: decoder.cls, Gradient: 4.550886770960007
# Parameter: decoder.bias, Gradient: 0.7165934150039993
# Epoch: 0354 lr: [0.001, 0.001] train_loss: 0.556819 train_acc: 0.741611 train_f1: 0.783099 time: 0.9924s
# Epoch: 0354 val_loss: 0.620135 val_acc: 0.687500 val_f1: 0.736842
# Epoch 355, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.4907287262969157
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.1616894877607439
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.022682433415554235
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.0635782647190579
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.028858908159991765
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.08295932394938701
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.02582496526050668
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.09480114906655983
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.026790905203476732
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.07251503140372333
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.025244053980445037
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.07752067256540633
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.026960973329104593
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.09940581607670451
# Parameter: decoder.cls, Gradient: 2.645643736217341
# Parameter: decoder.bias, Gradient: 0.4171917643154092
# Epoch 355, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.893317064256644
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.3173919110880699
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.054566385006855435
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.14095821220412993
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.0688558556622954
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.1618623878997443
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.06370978375003337
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.10507397749962849
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.06369459034275499
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.12672454971841943
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.06065964217627754
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.12559043962629912
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.06308137648685883
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.18654999051819804
# Parameter: decoder.cls, Gradient: 4.267935925834652
# Parameter: decoder.bias, Gradient: 0.6723643315676687
# Epoch 355, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.6416443984971241
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.15710494231260003
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.0159050524506913
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.12231656177149544
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.01994911045516394
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.09050928460126302
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.018158036705665407
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.04448117202858227
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.018215906114483545
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.04350833036660185
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.017384930446604708
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.10083045807119548
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.01814999536425411
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.08511510791987342
# Parameter: decoder.cls, Gradient: 1.1385123147973704
# Parameter: decoder.bias, Gradient: 0.1792281452680465
# Epoch 355, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 1.211155535678112
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.33446568265952004
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.052375804698966445
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.1199866142748666
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.0642257048733005
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.181200249068123
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.059814448045161006
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.1362470321088167
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.059829363133039784
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.12219990535635603
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.05733833219366119
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.11675434350044436
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.059445725142825416
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.2347367788594352
# Parameter: decoder.cls, Gradient: 4.255200365314463
# Parameter: decoder.bias, Gradient: 0.6699882370832677
# Epoch 355, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 1.131407008335633
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.2616112191855851
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.027602988603877956
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.1895592533235701
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.034944428686457765
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.16087360498735187
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03280626550578942
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.15737643362260054
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.032431499708026106
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.12913006447287212
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.03053315053213022
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.1730604283131486
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.03146477963672936
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.13558934478717063
# Parameter: decoder.cls, Gradient: 2.575725883527069
# Parameter: decoder.bias, Gradient: 0.4057121901968471
# Epoch: 0355 lr: [0.001, 0.001] train_loss: 0.545465 train_acc: 0.724832 train_f1: 0.761628 time: 1.0038s
# Epoch: 0355 val_loss: 0.619851 val_acc: 0.687500 val_f1: 0.736842
# Epoch 356, Batch 1:
# Parameter: encoder.linear_before.bias, Gradient: 0.6518073814817543
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.18202840236066264
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.020005157422716857
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.06888836925563548
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.025976633372152332
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.08627393812624093
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.02332964351053686
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.06532455353222735
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.02342845965976362
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.08292485292075204
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.021849467235423255
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.0720247879346712
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.024307714310273218
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.10928382576314331
# Parameter: decoder.cls, Gradient: 2.5923176802325187
# Parameter: decoder.bias, Gradient: 0.40821096849985433
# Epoch 356, Batch 2:
# Parameter: encoder.linear_before.bias, Gradient: 0.6792678232212579
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.18415386075263748
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.018886863025270224
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.0807967071960794
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.024306190429327298
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.10530506431532051
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.02198679485049448
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.06891546934333738
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.022494266003543154
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.0911432138547166
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.02143043990049369
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.05910435363548826
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.023295869429673276
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.13416643676874035
# Parameter: decoder.cls, Gradient: 2.539052001814795
# Parameter: decoder.bias, Gradient: 0.3998879929377081
# Epoch 356, Batch 3:
# Parameter: encoder.linear_before.bias, Gradient: 0.7403216431981611
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.17412296019447254
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.014595203103481844
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.09305212051483125
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.017133770841049306
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.0633642580928602
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.016169715101551792
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.10272828412870653
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.01592094566767875
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.08084451262905075
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.015404643387350536
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.10077992267261032
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.016096597041330128
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.15741243817680106
# Parameter: decoder.cls, Gradient: 1.1996814188389466
# Parameter: decoder.bias, Gradient: 0.18876810505651853
# Epoch 356, Batch 4:
# Parameter: encoder.linear_before.bias, Gradient: 1.356953973944076
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.31828660601596975
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.02535204955645855
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.14249706845875923
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.03241015220190609
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.08784448555286539
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.03023985878585978
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.05421433652588124
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.030197392445851193
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.09312286140447545
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.028481249415021767
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.09782857403530225
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.02961715129180914
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.1284907035944593
# Parameter: decoder.cls, Gradient: 2.550916760377084
# Parameter: decoder.bias, Gradient: 0.40158133922099665
# Epoch 356, Batch 5:
# Parameter: encoder.linear_before.bias, Gradient: 1.6214118233186496
# Parameter: encoder.linear_before.E_linear.weight, Gradient: 0.4429213335427442
# Parameter: encoder.layers.0.net.linears.0.bias, Gradient: 0.024083916698927024
# Parameter: encoder.layers.0.net.linears.0.E_linear.weight, Gradient: 0.17426981531991362
# Parameter: encoder.layers.0.net.linears.1.bias, Gradient: 0.028983471862976846
# Parameter: encoder.layers.0.net.linears.1.E_linear.weight, Gradient: 0.11556369377790236
# Parameter: encoder.layers.0.net.linears.2.bias, Gradient: 0.02761686280873359
# Parameter: encoder.layers.0.net.linears.2.E_linear.weight, Gradient: 0.11597180244827936
# Parameter: encoder.layers.0.net.linears.3.bias, Gradient: 0.02935144844049611
# Parameter: encoder.layers.0.net.linears.3.E_linear.weight, Gradient: 0.10001702010844876
# Parameter: encoder.layers.0.net.linears.4.bias, Gradient: 0.026727024035865125
# Parameter: encoder.layers.0.net.linears.4.E_linear.weight, Gradient: 0.17852741664738606
# Parameter: encoder.layers.0.net.linears.5.bias, Gradient: 0.02703650680303677
# Parameter: encoder.layers.0.net.linears.5.E_linear.weight, Gradient: 0.13216353238767886
# Parameter: decoder.cls, Gradient: 2.3757528824988525
# Parameter: decoder.bias, Gradient: 0.37388894605117823
# Epoch: 0356 lr: [0.001, 0.001] train_loss: 0.404399 train_acc: 0.899329 train_f1: 0.909639 time: 0.9976s
# Epoch: 0356 val_loss: 0.619744 val_acc: 0.687500 val_f1: 0.736842
# Early stopping
# Optimization Finished!
# Total time elapsed: 385.7713s
# Val set results: val_loss: 1.312919 val_acc: 0.750000 val_f1: 0.777778
# Test set results: test_loss: 0.000000 test_acc: 0.433333 test_f1: 0.413793
