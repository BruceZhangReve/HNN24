# %% [markdown]
# # Node Classification

# %%
import argparse
from types import SimpleNamespace
import sys
sys.path.append('/data/lige/HKN')# Please change accordingly!

from __future__ import division
from __future__ import print_function

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter

import datetime
import json
import logging
from optim import RiemannianAdam, RiemannianSGD
import os
import pickle
import time

import numpy as np
import torch
from config import parser
from models.base_models import NCModel, LPModel, GCModel
from utils.data_utils import load_data, get_nei, GCDataset, split_batch
from utils.train_utils import get_dir_name, format_metrics
from utils.eval_utils import acc_f1

from geoopt import ManifoldParameter as geoopt_ManifoldParameter
from manifolds.base import ManifoldParameter as base_ManifoldParameter


os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:128'
torch.cuda.empty_cache()



config_args = {
    'training_config': {
        'lr': (1e-3, 'learning rate'),
        'dropout': (0.3, 'dropout probability'),
        'cuda': (1, 'which cuda device to use (-1 for cpu training)'),
        'epochs': (1000, 'maximum number of epochs to train for'),
        'weight_decay': (1e-3, 'l2 regularization strength'),
        'optimizer': ('radam', 'which optimizer to use, can be any of [rsgd, radam]'),
        'momentum': (0.999, 'momentum in optimizer'),
        'patience': (15, 'patience for early stopping'),
        'seed': (18, 'seed for training'),
        'log_freq': (1, 'how often to compute print train/val metrics (in epochs)'),
        'eval_freq': (1, 'how often to compute val metrics (in epochs)'),
        'save': (0, '1 to save model and logs and 0 otherwise'),
        'save_dir': (None, 'path to save training logs and model weights (defaults to logs/task/date/run/)'),
        'sweep_c': (0, ''),
        'lr_reduce_freq': (None, 'reduce lr every lr-reduce-freq or None to keep lr constant'),
        'gamma': (0.5, 'gamma for lr scheduler'),
        'print_epoch': (True, ''),
        'grad_clip': (None, 'max norm for gradient clipping, or None for no gradient clipping'),
        'min_epochs': (300, 'do not early stop before min-epochs')
    },
    'model_config': {
        'use_geoopt': (False, "which manifold class to use, if false then use basd.manifold"),
        'AggKlein':(True, "if false, then use hyperboloid centorid for aggregation"),
        'corr': (1,'0: d(x_i ominus x, x_k), 1: d(x_ik,x_k)'),
        'task': ('nc', 'which tasks to train on, can be any of [lp, nc]'),
        'model': ('BKNet', 'which encoder to use, can be any of [Shallow, MLP, HNN, GCN, GAT, HyperGCN, HyboNet,BKNet,BMLP]'),
        #'dim': (32, 'embedding dimension'), #The final dimension as the embedded vector
        'dim': (64, 'embedding dimension'),
        'manifold': ('PoincareBall', 'which manifold to use, can be any of [Euclidean, Hyperboloid, PoincareBall, Lorentz]'),
        'c': (1.0, 'hyperbolic radius, set to None for trainable curvature'),
        'r': (2., 'fermi-dirac decoder parameter for lp'),
        't': (1., 'fermi-dirac decoder parameter for lp'),
        'margin': (2., 'margin of MarginLoss'),
        'pretrained_embeddings': (None, 'path to pretrained embeddings (.npy file) for Shallow node classification'),
        'pos_weight': (0, 'whether to upweight positive class in node classification tasks'),
        'num_layers': (2, 'number of hidden layers in encoder'),
        'bias': (1, 'whether to use bias (1) or not (0)'),
        'act': ('relu', 'which activation function to use (or None for no activation)'),
        'n_heads': (4, 'number of attention heads for graph attention networks, must be a divisor dim'),
        'alpha': (0.2, 'alpha for leakyrelu in graph attention networks'),
        'double_precision': ('1', 'whether to use double precision'),
        'use_att': (0, 'whether to use hyperbolic attention or not'),
        'local_agg': (0, 'whether to local tangent space aggregation or not'),
        'kernel_size': (6, 'number of kernels'),
        'KP_extent': (0.66, 'influence radius of each kernel point'),
        'radius': (1, 'radius used for kernel point init'),
        'deformable': (False, 'deformable kernel'),
        'linear_before': (64, 'dim of linear before gcn')#The dimension after linear_before(dimensionality reduction if you would)
        #'linear_before': (32, 'dim of linear before gcn')#64
    },
    'data_config': {
        'dataset': ('wisconsin', 'which dataset to use(cornell,wisconsin,squirrel,cora)'),
        'batch_size': (32, 'batch size for gc'),
        'val_prop': (0.05, 'proportion of validation edges for link prediction'),
        'test_prop': (0.1, 'proportion of test edges for link prediction'),
        'use_feats': (1, 'whether to use node features or not'),
        'normalize_feats': (1, 'whether to normalize input node features'),
        'normalize_adj': (1, 'whether to row-normalize the adjacency matrix'),
        'split_seed': (18, 'seed for data splits (train/test/val)'),
        'split_graph': (False, 'whether to split the graph')
    }
}

# 将所有参数转换为 SimpleNamespace
args = SimpleNamespace(
    **{k: v[0] for config in config_args.values() for k, v in config.items()}
)

#choose which manifold class to follow 
if args.use_geoopt == False:
    ManifoldParameter = base_ManifoldParameter
else:
    ManifoldParameter = geoopt_ManifoldParameter
np.random.seed(args.seed)#args.seed
torch.manual_seed(args.seed)#args.seed
if int(args.cuda):#args.double_precision
    torch.set_default_dtype(torch.float64)
if int(args.cuda) >= 0:#args.cuda
    torch.cuda.manual_seed(args.seed)#args.seed
args.device = 'cuda:' + str(args.cuda) if int(args.cuda) >= 0 else 'cpu' #args.device actually,<-args.cuda
args.patience = args.epochs if not args.patience else args.patience #args.patience<-args.epochs|args.patience

print(f'Using: {args.device}')
print("Using seed {}.".format(args.seed))
print(f"Dataset: {args.dataset}")

# Load data
data = load_data(args, os.path.join('data', args.dataset))
if args.task == 'gc':
    args.n_nodes, args.feat_dim = data['features'][0].shape
else:
    args.n_nodes, args.feat_dim = data['features'].shape
if args.task == 'nc':
    Model = NCModel
    args.n_classes = int(data['labels'].max() + 1)
    args.data = data
    print(f'Num classes: {args.n_classes}')
elif args.task == 'gc':
    Model = GCModel
    args.n_classes = int(data['labels'].max() + 1)
    print(f'Num classes: {args.n_classes}')
else:
    args.nb_false_edges = len(data['train_edges_false'])
    args.nb_edges = len(data['train_edges'])
    if args.task == 'lp':
        Model = LPModel
        args.n_classes = 2

if not args.lr_reduce_freq:
    args.lr_reduce_freq = args.epochs


###A simple check on data
print(data.keys())
print(data['adj_train'].todense().shape)
print(data['features'].shape)
###A simple check on data

# Model and optimizer
model = Model(args)
print(str(model))
no_decay = ['bias', 'scale']
optimizer_grouped_parameters = [{
    'params': [
        p for n, p in model.named_parameters()
        if p.requires_grad and not any(
            nd in n
            for nd in no_decay) and not isinstance(p, ManifoldParameter)
    ],
    'weight_decay':
    args.weight_decay
}, {
    'params': [
        p for n, p in model.named_parameters() if p.requires_grad and any(
            nd in n
            for nd in no_decay) or isinstance(p, ManifoldParameter)
    ],
    'weight_descay':
    0.0
}]
if args.optimizer == 'radam':
    optimizer = RiemannianAdam(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
elif args.optimizer == 'rsgd':
    optimizer = RiemannianSGD(params=optimizer_grouped_parameters,
                                lr=args.lr,
                                stabilize=10)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=int(
                                                args.lr_reduce_freq),
                                                gamma=float(args.gamma))
tot_params = sum([np.prod(p.size()) for p in model.parameters()])
model = model.to(args.device)
for x, val in data.items():
    if torch.is_tensor(data[x]):
        data[x] = data[x].to(args.device)
print(f"Total number of parameters: {tot_params}")

# Train model for nc:
t_total = time.time()
counter = 0
best_val_metrics = model.init_metric_dict()
best_test_metrics = None
best_emb = None
if args.n_classes > 2:
    f1_average = 'micro'
else:
    f1_average = 'binary'

if args.model == 'HKPNet':
    nei, nei_mask = get_nei(data['adj_train'])
    nei = nei.to(args.device)
    nei_mask = nei_mask.to(args.device)
elif args.model == 'BKNet':
    nei, nei_mask = get_nei(data['adj_train'])
    nei = nei.to(args.device)
    nei_mask = nei_mask.to(args.device) #nei/nei_mask on cuda now
# Out:
# Using: cuda:1
# Using seed 18.
# Dataset: wisconsin
# Num classes: 5
# dict_keys(['adj_train', 'features', 'labels', 'idx_train', 'idx_val', 'idx_test', 'adj_train_norm'])
# (251, 251)
# torch.Size([251, 1703])
# NCModel(
#   (encoder): BKNet(
#     (linear_before): BLinear(
#       in_features=1703, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#       (dropout): Dropout(p=0.3, inplace=False)
#       (E_linear): Linear(in_features=1703, out_features=64, bias=False)
#     )
#     (layers): Sequential(
#       (0): KPGraphConvolution(
#         (net): KernelPointAggregation(
#           (linears): ModuleList(
#             (0): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#             (1): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#             (2): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#             (3): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#             (4): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#             (5): BLinear(
#               in_features=64, out_features=64, c=tensor([1.], device='cuda:1'), use_bias=1, act=None, dropout_rate=0.3
#               (dropout): Dropout(p=0.3, inplace=False)
#               (E_linear): Linear(in_features=64, out_features=64, bias=False)
#             )
#           )
#           (act): BAct(c=tensor([1.], device='cuda:1'), act=<function relu at 0x7f6f03d4f400>)
#         )
#       )
#     )
#   )
#   (decoder): PoincareDecoder()
# )
# Total number of parameters: 134789
# /data/lige/HKN/utils/data_utils.py:347: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj = nx.adjacency_matrix(G, sorted(G.nodes()))

# %%
decoded_values=[]
embedded_values=[]
model_linear_weight=[]

# 检查权重更新
def check_weights(model, epoch):
    print(f"Epoch {epoch + 1} - Model Linear Weight:")
    for name, param in model.named_parameters():
        if 'weight' in name:
            print(f"{name}: {param.data}")

for epoch in range(args.epochs):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    if args.model == 'HKPNet':
        embeddings = model.encode(data['features'], (nei, nei_mask))
    elif args.model == 'BKNet':
        embeddings = model.encode(data['features'], (nei, nei_mask))
    else:
        embeddings = model.encode(data['features'], data['adj_train_norm'])

    idx=data[f'idx_train']
    output=model.decode(embeddings, data['adj_train_norm'], idx)
    train_metrics = model.compute_metrics(embeddings, data, 'train')
    
    # 检查 decoded_values 和 embeddings
    embedded_values.append(embeddings)
    decoded_values.append(output)
    model_linear_weight.append(model.encoder.layers[0].net.linears[0].E_linear.weight.clone())
    
    # 检查梯度是否被正确计算
    train_metrics['loss'].backward()
    #loss = F.cross_entropy(output, data['labels'][idx])
    #loss.backward()

    for name, param in model.named_parameters():
        if param.grad is not None:
            print(f"Grad of {name}: {param.grad.abs().mean()}")
        else:
            print(f"Grad of {name}: None")  # 检查梯度是否为 None
    
    if args.grad_clip is not None:
        torch.nn.utils.clip_grad_norm_(model.parameters(), args.grad_clip)
        
    optimizer.step()
    lr_scheduler.step()
    
    # 打印和检查权重是否被更新
    check_weights(model, epoch)
    
    if (epoch + 1) % args.log_freq == 0:
        print(" ".join([
            'Epoch: {:04d}'.format(epoch + 1),
            'lr: {}'.format(lr_scheduler.get_last_lr()),
            format_metrics(train_metrics, 'train'),
            'time: {:.4f}s'.format(time.time() - t)
        ]))
    
    with torch.no_grad():
        if (epoch + 1) % args.eval_freq == 0:
            model.eval()
            if args.model == 'HKPNet':
                embeddings = model.encode(data['features'], (nei, nei_mask))
            elif args.model == 'BKNet':
                embeddings = model.encode(data['features'], (nei, nei_mask))
            else:
                embeddings = model.encode(data['features'],
                                        data['adj_train_norm'])
            val_metrics = model.compute_metrics(embeddings, data, 'val')
            if (epoch + 1) % args.log_freq == 0:
                print(" ".join([
                    'Epoch: {:04d}'.format(epoch + 1),
                    format_metrics(val_metrics, 'val')
                ]))
            if model.has_improved(best_val_metrics, val_metrics):
                best_test_metrics = model.compute_metrics(
                    embeddings, data, 'test')
                best_emb = embeddings.cpu()
                if args.save:
                    np.save(os.path.join(save_dir, 'embeddings.npy'),
                            best_emb.detach().numpy())
                best_val_metrics = val_metrics
                counter = 0
            else:
                counter += 1
                if counter == args.patience and epoch > args.min_epochs:
                    print("Early stopping")
                    break

print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
if not best_test_metrics:
    model.eval()
    best_emb = model.encode(data['features'], data['adj_train_norm'])
    best_test_metrics = model.compute_metrics(best_emb, data, 'test')
print(" ".join(
    ["Val set results:",
    format_metrics(best_val_metrics, 'val')]))
print(" ".join(
    ["Test set results:",
    format_metrics(best_test_metrics, 'test')]))
if args.save:
    np.save(os.path.join(save_dir, 'embeddings.npy'),
            best_emb.cpu().detach().numpy())
    if hasattr(model.encoder, 'att_adj'):
        filename = os.path.join(save_dir, args.dataset + '_att_adj.p')
        pickle.dump(model.encoder.att_adj.cpu().to_dense(),
                    open(filename, 'wb'))
        print('Dumped attention adj: ' + filename)

    torch.save(model.state_dict(), os.path.join(save_dir, 'model.pth'))
    json.dump(vars(args), open(os.path.join(save_dir, 'config.json'), 'w'))
    logging.info(f"Saved model in {save_dir}")
# Out:
# Grad of encoder.linear_before.bias: 6.0265350909773807e-05
# Grad of encoder.linear_before.E_linear.weight: 1.5422591700594136e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.006382210627506941
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.402471062920244e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.006398856906975532
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.4047632172059603e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.006420681531547377
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.4114953861863186e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.006415926011919039
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.4139431412606174e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.006376922722962745
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.389921234270634e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.006398064935335032
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.3948413074765286e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.07209265217999698
# Grad of decoder.bias: 0.1503274846326683
# Epoch 1 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0589, -0.0050, -0.0376,  ...,  0.0668, -0.0305, -0.0672],
#         [-0.0307, -0.0066,  0.0152,  ...,  0.0644, -0.0659, -0.0209],
#         [-0.0154,  0.0048,  0.0066,  ..., -0.0516,  0.0148,  0.0399],
#         ...,
#         [ 0.0284, -0.0636,  0.0592,  ...,  0.0582, -0.0123,  0.0624],
#         [ 0.0292, -0.0649,  0.0015,  ...,  0.0324, -0.0217,  0.0765],
#         [-0.0175, -0.0227,  0.0287,  ..., -0.0691,  0.0319, -0.0338]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0056,  0.1980,  0.1754,  ...,  0.0116, -0.0500, -0.2517],
#         [ 0.0008,  0.1391,  0.2970,  ...,  0.0864,  0.0187, -0.2848],
#         [ 0.0884, -0.0892, -0.0029,  ...,  0.2134, -0.0760, -0.0082],
#         ...,
#         [-0.0740, -0.2902, -0.2509,  ..., -0.2800,  0.0560,  0.2823],
#         [ 0.2910, -0.1474,  0.2544,  ...,  0.0474,  0.1293, -0.1705],
#         [ 0.2187, -0.1039, -0.0875,  ...,  0.1231,  0.1898,  0.1353]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2598, -0.1237,  0.0200,  ...,  0.2092,  0.0515, -0.0539],
#         [-0.1646, -0.1847,  0.2323,  ...,  0.1072,  0.1269,  0.2490],
#         [ 0.1264,  0.1722, -0.1053,  ...,  0.2828, -0.2226,  0.1807],
#         ...,
#         [-0.2158,  0.2300,  0.1940,  ...,  0.2323, -0.0246,  0.2440],
#         [ 0.2564,  0.0084, -0.0362,  ..., -0.2479,  0.2760, -0.1622],
#         [-0.2016,  0.0939,  0.2564,  ..., -0.3046, -0.3007,  0.2281]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0208,  0.2312, -0.0419,  ...,  0.1009, -0.0038, -0.0595],
#         [ 0.2485, -0.0762, -0.0206,  ...,  0.0792,  0.1269,  0.2637],
#         [-0.1693, -0.0750, -0.1947,  ..., -0.0772, -0.2674,  0.2567],
#         ...,
#         [-0.1087, -0.1489, -0.0428,  ...,  0.0298, -0.0028,  0.2164],
#         [-0.0316, -0.1787, -0.0211,  ...,  0.2837,  0.1396, -0.2611],
#         [-0.0976,  0.2407,  0.0542,  ...,  0.2727, -0.2032, -0.2892]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1277,  0.2496, -0.0192,  ..., -0.1997, -0.1157,  0.0977],
#         [ 0.0403, -0.0245, -0.1055,  ..., -0.0160, -0.2590, -0.0682],
#         [-0.1194, -0.1243,  0.2437,  ..., -0.2833, -0.1366,  0.1948],
#         ...,
#         [-0.3056, -0.1821, -0.2114,  ...,  0.1203, -0.1714,  0.1384],
#         [-0.2656,  0.2552, -0.2953,  ..., -0.2266, -0.0145, -0.0125],
#         [ 0.0066, -0.2234,  0.0600,  ...,  0.3003, -0.1490, -0.1408]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1874,  0.0947, -0.0997,  ...,  0.0931, -0.1976,  0.1491],
#         [-0.1657, -0.2032, -0.0526,  ...,  0.0738, -0.0111,  0.0839],
#         [-0.0784,  0.1408,  0.1233,  ...,  0.0073,  0.2490,  0.1504],
#         ...,
#         [-0.0246, -0.0598,  0.2986,  ..., -0.1211, -0.2015,  0.1355],
#         [ 0.2507, -0.1255, -0.0441,  ...,  0.2542, -0.2538,  0.2694],
#         [-0.2745, -0.1265,  0.1260,  ...,  0.2185,  0.0658, -0.2704]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1432, -0.1906,  0.1730,  ..., -0.2522, -0.0131, -0.0004],
#         [-0.2303, -0.2610, -0.2497,  ...,  0.2656, -0.1339,  0.1824],
#         [ 0.2849, -0.1421,  0.2633,  ...,  0.1489, -0.1904, -0.2027],
#         ...,
#         [-0.0509,  0.1218,  0.2931,  ..., -0.0039, -0.0473, -0.2024],
#         [ 0.0604, -0.2887, -0.0380,  ...,  0.3001, -0.2901,  0.2599],
#         [-0.1701, -0.2948,  0.2729,  ..., -0.1271, -0.2423, -0.1198]],
#        device='cuda:1')
# Epoch: 0001 lr: [0.001, 0.001] train_loss: 1.607862 train_acc: 0.439490 train_f1: 0.439490 time: 0.1066s
# Epoch: 0001 val_loss: 1.585413 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 6.454147275040578e-05
# Grad of encoder.linear_before.E_linear.weight: 1.3966452646184808e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.005885656320635259
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.195957142383052e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.005920237860772739
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.207625498509042e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.005917859438787378
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.2125703038814447e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.005911192487935569
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.207509505630651e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.005874456173396086
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.1948070936640985e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.005911695061577633
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.2113029618294447e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.06985089039208396
# Grad of decoder.bias: 0.14561356065972553
# Epoch 2 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0583, -0.0055, -0.0378,  ...,  0.0661, -0.0296, -0.0679],
#         [-0.0312, -0.0074,  0.0162,  ...,  0.0636, -0.0663, -0.0218],
#         [-0.0147,  0.0038,  0.0073,  ..., -0.0524,  0.0138,  0.0407],
#         ...,
#         [ 0.0277, -0.0646,  0.0583,  ...,  0.0591, -0.0131,  0.0617],
#         [ 0.0299, -0.0659,  0.0022,  ...,  0.0331, -0.0227,  0.0771],
#         [-0.0181, -0.0225,  0.0280,  ..., -0.0697,  0.0328, -0.0347]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0058,  0.1990,  0.1753,  ...,  0.0126, -0.0508, -0.2519],
#         [ 0.0018,  0.1399,  0.2971,  ...,  0.0854,  0.0177, -0.2856],
#         [ 0.0874, -0.0902, -0.0038,  ...,  0.2124, -0.0768, -0.0089],
#         ...,
#         [-0.0748, -0.2911, -0.2519,  ..., -0.2809,  0.0552,  0.2815],
#         [ 0.2900, -0.1484,  0.2534,  ...,  0.0464,  0.1285, -0.1712],
#         [ 0.2197, -0.1029, -0.0865,  ...,  0.1240,  0.1903,  0.1359]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2599, -0.1228,  0.0192,  ...,  0.2102,  0.0508, -0.0538],
#         [-0.1636, -0.1838,  0.2322,  ...,  0.1062,  0.1260,  0.2483],
#         [ 0.1254,  0.1712, -0.1063,  ...,  0.2818, -0.2233,  0.1800],
#         ...,
#         [-0.2166,  0.2291,  0.1930,  ...,  0.2315, -0.0253,  0.2433],
#         [ 0.2554,  0.0074, -0.0372,  ..., -0.2489,  0.2751, -0.1629],
#         [-0.2006,  0.0949,  0.2574,  ..., -0.3036, -0.3001,  0.2287]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0207,  0.2322, -0.0424,  ...,  0.1019, -0.0046, -0.0596],
#         [ 0.2495, -0.0754, -0.0204,  ...,  0.0782,  0.1260,  0.2629],
#         [-0.1703, -0.0760, -0.1956,  ..., -0.0782, -0.2681,  0.2560],
#         ...,
#         [-0.1095, -0.1498, -0.0438,  ...,  0.0289, -0.0036,  0.2157],
#         [-0.0326, -0.1797, -0.0221,  ...,  0.2827,  0.1388, -0.2619],
#         [-0.0966,  0.2417,  0.0552,  ...,  0.2737, -0.2027, -0.2886]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1274,  0.2505, -0.0196,  ..., -0.1987, -0.1165,  0.0976],
#         [ 0.0413, -0.0236, -0.1052,  ..., -0.0170, -0.2600, -0.0689],
#         [-0.1204, -0.1253,  0.2428,  ..., -0.2843, -0.1374,  0.1941],
#         ...,
#         [-0.3064, -0.1830, -0.2124,  ...,  0.1194, -0.1721,  0.1377],
#         [-0.2665,  0.2542, -0.2963,  ..., -0.2276, -0.0154, -0.0132],
#         [ 0.0076, -0.2224,  0.0610,  ...,  0.3013, -0.1485, -0.1402]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1877,  0.0957, -0.1004,  ...,  0.0941, -0.1983,  0.1490],
#         [-0.1647, -0.2023, -0.0526,  ...,  0.0728, -0.0120,  0.0831],
#         [-0.0794,  0.1398,  0.1224,  ...,  0.0063,  0.2483,  0.1497],
#         ...,
#         [-0.0254, -0.0607,  0.2976,  ..., -0.1220, -0.2022,  0.1348],
#         [ 0.2497, -0.1264, -0.0451,  ...,  0.2532, -0.2546,  0.2687],
#         [-0.2735, -0.1255,  0.1270,  ...,  0.2195,  0.0663, -0.2698]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1430, -0.1896,  0.1725,  ..., -0.2512, -0.0139, -0.0009],
#         [-0.2293, -0.2601, -0.2496,  ...,  0.2646, -0.1348,  0.1817],
#         [ 0.2839, -0.1431,  0.2623,  ...,  0.1479, -0.1912, -0.2034],
#         ...,
#         [-0.0517,  0.1209,  0.2921,  ..., -0.0048, -0.0480, -0.2031],
#         [ 0.0594, -0.2897, -0.0390,  ...,  0.2991, -0.2909,  0.2592],
#         [-0.1691, -0.2938,  0.2739,  ..., -0.1261, -0.2418, -0.1192]],
#        device='cuda:1')
# Epoch: 0002 lr: [0.001, 0.001] train_loss: 1.580162 train_acc: 0.576433 train_f1: 0.576433 time: 0.0823s
# Epoch: 0002 val_loss: 1.563431 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.00012224870414779353
# Grad of encoder.linear_before.E_linear.weight: 1.6264908585767714e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.006156143280567034
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.4799874638547563e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.006222795117795786
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.5078704029816842e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.006201332139787831
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.5152049406177126e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.006186666198106839
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.4965599285466923e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.006176354848020394
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.486470502119602e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.006213005221418801
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.5114318376333188e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.06763968871400848
# Grad of decoder.bias: 0.14060195941001183
# Epoch 3 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0589, -0.0057, -0.0380,  ...,  0.0655, -0.0288, -0.0685],
#         [-0.0307, -0.0082,  0.0172,  ...,  0.0628, -0.0667, -0.0225],
#         [-0.0139,  0.0028,  0.0079,  ..., -0.0519,  0.0128,  0.0413],
#         ...,
#         [ 0.0269, -0.0653,  0.0574,  ...,  0.0601, -0.0140,  0.0611],
#         [ 0.0306, -0.0665,  0.0030,  ...,  0.0324, -0.0225,  0.0776],
#         [-0.0190, -0.0221,  0.0273,  ..., -0.0705,  0.0336, -0.0354]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0064,  0.1999,  0.1759,  ...,  0.0134, -0.0503, -0.2514],
#         [ 0.0027,  0.1405,  0.2967,  ...,  0.0845,  0.0169, -0.2864],
#         [ 0.0866, -0.0912, -0.0048,  ...,  0.2114, -0.0776, -0.0097],
#         ...,
#         [-0.0756, -0.2920, -0.2529,  ..., -0.2818,  0.0544,  0.2807],
#         [ 0.2891, -0.1492,  0.2526,  ...,  0.0456,  0.1276, -0.1718],
#         [ 0.2207, -0.1019, -0.0855,  ...,  0.1250,  0.1910,  0.1367]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2593, -0.1219,  0.0198,  ...,  0.2110,  0.0513, -0.0532],
#         [-0.1628, -0.1832,  0.2318,  ...,  0.1052,  0.1251,  0.2475],
#         [ 0.1246,  0.1702, -0.1073,  ...,  0.2808, -0.2242,  0.1792],
#         ...,
#         [-0.2174,  0.2282,  0.1920,  ...,  0.2306, -0.0261,  0.2425],
#         [ 0.2544,  0.0066, -0.0381,  ..., -0.2498,  0.2743, -0.1635],
#         [-0.1997,  0.0959,  0.2584,  ..., -0.3026, -0.2994,  0.2295]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0201,  0.2330, -0.0418,  ...,  0.1028, -0.0040, -0.0590],
#         [ 0.2504, -0.0748, -0.0206,  ...,  0.0773,  0.1251,  0.2621],
#         [-0.1712, -0.0770, -0.1966,  ..., -0.0792, -0.2690,  0.2552],
#         ...,
#         [-0.1103, -0.1507, -0.0448,  ...,  0.0280, -0.0044,  0.2149],
#         [-0.0335, -0.1805, -0.0229,  ...,  0.2819,  0.1379, -0.2625],
#         [-0.0957,  0.2427,  0.0562,  ...,  0.2747, -0.2020, -0.2878]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1267,  0.2514, -0.0191,  ..., -0.1979, -0.1160,  0.0982],
#         [ 0.0421, -0.0230, -0.1054,  ..., -0.0180, -0.2608, -0.0697],
#         [-0.1213, -0.1263,  0.2418,  ..., -0.2853, -0.1382,  0.1933],
#         ...,
#         [-0.3072, -0.1839, -0.2134,  ...,  0.1185, -0.1729,  0.1369],
#         [-0.2675,  0.2534, -0.2971,  ..., -0.2285, -0.0162, -0.0138],
#         [ 0.0086, -0.2214,  0.0619,  ...,  0.3023, -0.1478, -0.1394]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1883,  0.0965, -0.0998,  ...,  0.0949, -0.1978,  0.1495],
#         [-0.1637, -0.2016, -0.0529,  ...,  0.0719, -0.0129,  0.0823],
#         [-0.0803,  0.1388,  0.1214,  ...,  0.0053,  0.2474,  0.1489],
#         ...,
#         [-0.0262, -0.0616,  0.2966,  ..., -0.1229, -0.2030,  0.1340],
#         [ 0.2487, -0.1272, -0.0459,  ...,  0.2523, -0.2555,  0.2681],
#         [-0.2726, -0.1245,  0.1280,  ...,  0.2205,  0.0670, -0.2691]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1423, -0.1888,  0.1731,  ..., -0.2504, -0.0133, -0.0004],
#         [-0.2285, -0.2595, -0.2499,  ...,  0.2636, -0.1357,  0.1809],
#         [ 0.2831, -0.1441,  0.2613,  ...,  0.1469, -0.1920, -0.2042],
#         ...,
#         [-0.0525,  0.1200,  0.2911,  ..., -0.0057, -0.0488, -0.2039],
#         [ 0.0585, -0.2905, -0.0398,  ...,  0.2982, -0.2918,  0.2586],
#         [-0.1682, -0.2928,  0.2748,  ..., -0.1252, -0.2411, -0.1184]],
#        device='cuda:1')
# Epoch: 0003 lr: [0.001, 0.001] train_loss: 1.553048 train_acc: 0.576433 train_f1: 0.576433 time: 0.0781s
# Epoch: 0003 val_loss: 1.542282 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.00014716418459907575
# Grad of encoder.linear_before.E_linear.weight: 1.633234780513352e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.0058719909481512594
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.6697360269622788e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.005921836722820063
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.689901066002746e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.0059092541215621484
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.7007184463381795e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.005868741777628303
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.6713877652279783e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.005871687395460186
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.6632886238775744e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.005905308222259202
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.6984882875115366e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.06552729088913299
# Grad of decoder.bias: 0.13568862059095818
# Epoch 4 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0594, -0.0053, -0.0382,  ...,  0.0651, -0.0281, -0.0689],
#         [-0.0302, -0.0089,  0.0180,  ...,  0.0619, -0.0674, -0.0232],
#         [-0.0133,  0.0019,  0.0086,  ..., -0.0513,  0.0119,  0.0410],
#         ...,
#         [ 0.0261, -0.0658,  0.0565,  ...,  0.0611, -0.0143,  0.0606],
#         [ 0.0315, -0.0673,  0.0038,  ...,  0.0317, -0.0219,  0.0773],
#         [-0.0198, -0.0226,  0.0265,  ..., -0.0712,  0.0345, -0.0361]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0069,  0.2007,  0.1767,  ...,  0.0143, -0.0496, -0.2507],
#         [ 0.0034,  0.1409,  0.2960,  ...,  0.0837,  0.0160, -0.2870],
#         [ 0.0859, -0.0921, -0.0057,  ...,  0.2106, -0.0784, -0.0104],
#         ...,
#         [-0.0763, -0.2927, -0.2538,  ..., -0.2826,  0.0538,  0.2800],
#         [ 0.2883, -0.1499,  0.2519,  ...,  0.0449,  0.1268, -0.1723],
#         [ 0.2214, -0.1009, -0.0846,  ...,  0.1260,  0.1918,  0.1376]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2589, -0.1211,  0.0205,  ...,  0.2118,  0.0519, -0.0525],
#         [-0.1621, -0.1828,  0.2311,  ...,  0.1044,  0.1242,  0.2468],
#         [ 0.1239,  0.1694, -0.1082,  ...,  0.2800, -0.2249,  0.1785],
#         ...,
#         [-0.2181,  0.2275,  0.1911,  ...,  0.2298, -0.0268,  0.2418],
#         [ 0.2537,  0.0059, -0.0388,  ..., -0.2505,  0.2734, -0.1640],
#         [-0.1989,  0.0969,  0.2593,  ..., -0.3016, -0.2986,  0.2303]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0198,  0.2339, -0.0410,  ...,  0.1036, -0.0034, -0.0584],
#         [ 0.2511, -0.0743, -0.0212,  ...,  0.0766,  0.1242,  0.2615],
#         [-0.1719, -0.0778, -0.1975,  ..., -0.0800, -0.2697,  0.2546],
#         ...,
#         [-0.1109, -0.1514, -0.0457,  ...,  0.0273, -0.0050,  0.2142],
#         [-0.0343, -0.1812, -0.0236,  ...,  0.2811,  0.1371, -0.2630],
#         [-0.0949,  0.2436,  0.0571,  ...,  0.2757, -0.2012, -0.2870]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1263,  0.2522, -0.0183,  ..., -0.1970, -0.1153,  0.0988],
#         [ 0.0428, -0.0226, -0.1060,  ..., -0.0188, -0.2618, -0.0704],
#         [-0.1220, -0.1271,  0.2409,  ..., -0.2862, -0.1390,  0.1926],
#         ...,
#         [-0.3078, -0.1846, -0.2143,  ...,  0.1178, -0.1735,  0.1362],
#         [-0.2682,  0.2527, -0.2978,  ..., -0.2292, -0.0171, -0.0143],
#         [ 0.0093, -0.2204,  0.0628,  ...,  0.3033, -0.1470, -0.1386]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1887,  0.0974, -0.0991,  ...,  0.0958, -0.1972,  0.1501],
#         [-0.1629, -0.2010, -0.0536,  ...,  0.0711, -0.0138,  0.0816],
#         [-0.0810,  0.1380,  0.1205,  ...,  0.0044,  0.2467,  0.1482],
#         ...,
#         [-0.0269, -0.0623,  0.2957,  ..., -0.1236, -0.2037,  0.1333],
#         [ 0.2480, -0.1279, -0.0467,  ...,  0.2516, -0.2563,  0.2676],
#         [-0.2718, -0.1236,  0.1289,  ...,  0.2215,  0.0678, -0.2683]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-1.4198e-01, -1.8795e-01,  1.7379e-01,  ..., -2.4958e-01,
#          -1.2649e-02,  2.0620e-04],
#         [-2.2772e-01, -2.5905e-01, -2.5058e-01,  ...,  2.6288e-01,
#          -1.3661e-01,  1.8017e-01],
#         [ 2.8235e-01, -1.4489e-01,  2.6044e-01,  ...,  1.4610e-01,
#          -1.9277e-01, -2.0491e-01],
#         ...,
#         [-5.3161e-02,  1.1927e-01,  2.9023e-01,  ..., -6.4578e-03,
#          -4.9476e-02, -2.0462e-01],
#         [ 5.7806e-02, -2.9111e-01, -4.0485e-02,  ...,  2.9749e-01,
#          -2.9264e-01,  2.5805e-01],
#         [-1.6744e-01, -2.9187e-01,  2.7570e-01,  ..., -1.2416e-01,
#          -2.4025e-01, -1.1753e-01]], device='cuda:1')
# Epoch: 0004 lr: [0.001, 0.001] train_loss: 1.528060 train_acc: 0.576433 train_f1: 0.576433 time: 0.0776s
# Epoch: 0004 val_loss: 1.521966 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.0001721123277509981
# Grad of encoder.linear_before.E_linear.weight: 1.623424883337135e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.0058316796438962785
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.3952480977758876e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.005907908065011945
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.41912939964568e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.005875152893514181
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.4091593123923643e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.005851815661016006
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.403954932589165e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.00585304253041213
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.400959612928198e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.005868710466462581
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.410075886710928e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.0632167406412613
# Grad of decoder.bias: 0.13020486449890034
# Epoch 5 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0598, -0.0050, -0.0384,  ...,  0.0648, -0.0273, -0.0692],
#         [-0.0297, -0.0095,  0.0186,  ...,  0.0610, -0.0681, -0.0239],
#         [-0.0127,  0.0009,  0.0092,  ..., -0.0506,  0.0109,  0.0406],
#         ...,
#         [ 0.0253, -0.0661,  0.0556,  ...,  0.0619, -0.0148,  0.0599],
#         [ 0.0323, -0.0682,  0.0045,  ...,  0.0309, -0.0212,  0.0771],
#         [-0.0206, -0.0231,  0.0258,  ..., -0.0717,  0.0353, -0.0369]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0074,  0.2016,  0.1774,  ...,  0.0151, -0.0488, -0.2506],
#         [ 0.0040,  0.1413,  0.2953,  ...,  0.0829,  0.0151, -0.2877],
#         [ 0.0852, -0.0928, -0.0065,  ...,  0.2098, -0.0790, -0.0110],
#         ...,
#         [-0.0768, -0.2934, -0.2545,  ..., -0.2832,  0.0532,  0.2795],
#         [ 0.2877, -0.1505,  0.2512,  ...,  0.0442,  0.1260, -0.1728],
#         [ 0.2222, -0.0999, -0.0838,  ...,  0.1270,  0.1926,  0.1383]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2586, -0.1202,  0.0212,  ...,  0.2126,  0.0526, -0.0525],
#         [-0.1615, -0.1824,  0.2304,  ...,  0.1036,  0.1233,  0.2460],
#         [ 0.1232,  0.1686, -0.1090,  ...,  0.2792, -0.2256,  0.1779],
#         ...,
#         [-0.2186,  0.2268,  0.1903,  ...,  0.2291, -0.0274,  0.2412],
#         [ 0.2531,  0.0054, -0.0394,  ..., -0.2511,  0.2727, -0.1644],
#         [-0.1982,  0.0979,  0.2601,  ..., -0.3006, -0.2978,  0.2311]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0195,  0.2347, -0.0403,  ...,  0.1044, -0.0026, -0.0583],
#         [ 0.2517, -0.0739, -0.0218,  ...,  0.0758,  0.1233,  0.2607],
#         [-0.1725, -0.0785, -0.1982,  ..., -0.0808, -0.2704,  0.2540],
#         ...,
#         [-0.1115, -0.1521, -0.0465,  ...,  0.0266, -0.0056,  0.2136],
#         [-0.0349, -0.1818, -0.0242,  ...,  0.2805,  0.1364, -0.2634],
#         [-0.0942,  0.2446,  0.0579,  ...,  0.2767, -0.2003, -0.2862]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1259,  0.2531, -0.0176,  ..., -0.1962, -0.1145,  0.0989],
#         [ 0.0434, -0.0222, -0.1067,  ..., -0.0196, -0.2627, -0.0712],
#         [-0.1226, -0.1279,  0.2401,  ..., -0.2870, -0.1397,  0.1920],
#         ...,
#         [-0.3083, -0.1852, -0.2150,  ...,  0.1171, -0.1740,  0.1357],
#         [-0.2688,  0.2522, -0.2985,  ..., -0.2298, -0.0177, -0.0147],
#         [ 0.0101, -0.2195,  0.0637,  ...,  0.3043, -0.1462, -0.1378]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1891,  0.0982, -0.0984,  ...,  0.0966, -0.1964,  0.1502],
#         [-0.1623, -0.2004, -0.0543,  ...,  0.0703, -0.0147,  0.0808],
#         [-0.0817,  0.1372,  0.1197,  ...,  0.0036,  0.2460,  0.1476],
#         ...,
#         [-0.0274, -0.0629,  0.2949,  ..., -0.1243, -0.2042,  0.1327],
#         [ 0.2473, -0.1285, -0.0473,  ...,  0.2510, -0.2570,  0.2672],
#         [-0.2711, -0.1226,  0.1297,  ...,  0.2225,  0.0687, -0.2675]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-1.4158e-01, -1.8709e-01,  1.7453e-01,  ..., -2.4877e-01,
#          -1.1866e-02,  2.6756e-04],
#         [-2.2707e-01, -2.5861e-01, -2.5127e-01,  ...,  2.6204e-01,
#          -1.3755e-01,  1.7945e-01],
#         [ 2.8169e-01, -1.4567e-01,  2.5962e-01,  ...,  1.4530e-01,
#          -1.9347e-01, -2.0551e-01],
#         ...,
#         [-5.3713e-02,  1.1863e-01,  2.8948e-01,  ..., -7.1058e-03,
#          -5.0040e-02, -2.0519e-01],
#         [ 5.7199e-02, -2.9165e-01, -4.1092e-02,  ...,  2.9689e-01,
#          -2.9328e-01,  2.5762e-01],
#         [-1.6670e-01, -2.9089e-01,  2.7657e-01,  ..., -1.2316e-01,
#          -2.3941e-01, -1.1676e-01]], device='cuda:1')
# Epoch: 0005 lr: [0.001, 0.001] train_loss: 1.503005 train_acc: 0.576433 train_f1: 0.576433 time: 0.0783s
# Epoch: 0005 val_loss: 1.502520 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.00020476355552313322
# Grad of encoder.linear_before.E_linear.weight: 1.7223529868301607e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.005326839767595926
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.392047316034984e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.0053963371217194975
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.4240405066465747e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.005348531981816736
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.4218923916602083e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.0053350815755328
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.4167183517994e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.005300556152921139
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.387807712023438e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.005362033728346066
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.4275105174890234e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.06100515709206486
# Grad of decoder.bias: 0.12477347782811186
# Epoch 6 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-6.0465e-02, -4.5624e-03, -3.8501e-02,  ...,  6.5093e-02,
#          -2.6436e-02, -6.9814e-02],
#         [-2.9195e-02, -1.0061e-02,  1.9214e-02,  ...,  6.0223e-02,
#          -6.8854e-02, -2.4747e-02],
#         [-1.2075e-02, -2.0714e-05,  9.9120e-03,  ..., -5.0390e-02,
#           9.8798e-03,  4.0111e-02],
#         ...,
#         [ 2.4504e-02, -6.6298e-02,  5.4801e-02,  ...,  6.2679e-02,
#          -1.5161e-02,  5.9151e-02],
#         [ 3.3109e-02, -6.9045e-02,  5.3563e-03,  ...,  2.9988e-02,
#          -2.0436e-02,  7.6534e-02],
#         [-2.1433e-02, -2.3796e-02,  2.5156e-02,  ..., -7.2351e-02,
#           3.6230e-02, -3.7671e-02]], device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0080,  0.2025,  0.1782,  ...,  0.0159, -0.0480, -0.2501],
#         [ 0.0046,  0.1416,  0.2947,  ...,  0.0822,  0.0143, -0.2883],
#         [ 0.0846, -0.0935, -0.0073,  ...,  0.2091, -0.0797, -0.0115],
#         ...,
#         [-0.0774, -0.2940, -0.2553,  ..., -0.2838,  0.0526,  0.2789],
#         [ 0.2871, -0.1510,  0.2506,  ...,  0.0437,  0.1253, -0.1731],
#         [ 0.2230, -0.0989, -0.0828,  ...,  0.1280,  0.1935,  0.1392]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2580, -0.1194,  0.0220,  ...,  0.2134,  0.0535, -0.0520],
#         [-0.1610, -0.1821,  0.2297,  ...,  0.1028,  0.1225,  0.2454],
#         [ 0.1226,  0.1679, -0.1098,  ...,  0.2785, -0.2263,  0.1773],
#         ...,
#         [-0.2192,  0.2262,  0.1895,  ...,  0.2285, -0.0280,  0.2407],
#         [ 0.2525,  0.0049, -0.0400,  ..., -0.2517,  0.2719, -0.1648],
#         [-0.1974,  0.0988,  0.2611,  ..., -0.2996, -0.2969,  0.2319]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0189,  0.2356, -0.0395,  ...,  0.1052, -0.0018, -0.0578],
#         [ 0.2523, -0.0735, -0.0224,  ...,  0.0751,  0.1225,  0.2601],
#         [-0.1731, -0.0792, -0.1989,  ..., -0.0815, -0.2710,  0.2535],
#         ...,
#         [-0.1119, -0.1527, -0.0472,  ...,  0.0260, -0.0062,  0.2131],
#         [-0.0354, -0.1822, -0.0248,  ...,  0.2800,  0.1357, -0.2637],
#         [-0.0934,  0.2456,  0.0589,  ...,  0.2777, -0.1994, -0.2854]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1253,  0.2540, -0.0168,  ..., -0.1954, -0.1137,  0.0993],
#         [ 0.0439, -0.0218, -0.1072,  ..., -0.0204, -0.2635, -0.0718],
#         [-0.1232, -0.1286,  0.2393,  ..., -0.2877, -0.1403,  0.1915],
#         ...,
#         [-0.3088, -0.1858, -0.2158,  ...,  0.1166, -0.1745,  0.1352],
#         [-0.2694,  0.2517, -0.2991,  ..., -0.2303, -0.0184, -0.0151],
#         [ 0.0109, -0.2185,  0.0646,  ...,  0.3053, -0.1453, -0.1370]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1897,  0.0991, -0.0976,  ...,  0.0974, -0.1955,  0.1507],
#         [-0.1617, -0.1999, -0.0548,  ...,  0.0695, -0.0155,  0.0802],
#         [-0.0823,  0.1364,  0.1188,  ...,  0.0029,  0.2453,  0.1471],
#         ...,
#         [-0.0280, -0.0635,  0.2941,  ..., -0.1249, -0.2048,  0.1322],
#         [ 0.2468, -0.1290, -0.0479,  ...,  0.2505, -0.2577,  0.2668],
#         [-0.2703, -0.1216,  0.1307,  ...,  0.2235,  0.0695, -0.2667]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1410, -0.1862,  0.1753,  ..., -0.2480, -0.0110,  0.0007],
#         [-0.2265, -0.2582, -0.2518,  ...,  0.2613, -0.1383,  0.1788],
#         [ 0.2811, -0.1464,  0.2588,  ...,  0.1446, -0.1941, -0.2060],
#         ...,
#         [-0.0543,  0.1180,  0.2887,  ..., -0.0077, -0.0507, -0.2057],
#         [ 0.0567, -0.2921, -0.0416,  ...,  0.2964, -0.2940,  0.2573],
#         [-0.1659, -0.2899,  0.2775,  ..., -0.1222, -0.2385, -0.1159]],
#        device='cuda:1')
# Epoch: 0006 lr: [0.001, 0.001] train_loss: 1.478719 train_acc: 0.576433 train_f1: 0.576433 time: 0.0779s
# Epoch: 0006 val_loss: 1.483995 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.00023544816289899627
# Grad of encoder.linear_before.E_linear.weight: 1.688150973220264e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.0050291065580872416
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.718088757341125e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.0051371299306802835
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.7747380323464193e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.005107496871050147
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.7761067884942643e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.005061010207937944
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.737627888913462e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.005059867116919539
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.7334037450763342e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.0051153505839004595
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.7893463529558855e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.05879218898835973
# Grad of decoder.bias: 0.11923034786725402
# Epoch 7 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0611, -0.0040, -0.0386,  ...,  0.0653, -0.0257, -0.0703],
#         [-0.0287, -0.0107,  0.0197,  ...,  0.0596, -0.0697, -0.0256],
#         [-0.0115, -0.0010,  0.0105,  ..., -0.0500,  0.0089,  0.0396],
#         ...,
#         [ 0.0238, -0.0664,  0.0541,  ...,  0.0635, -0.0152,  0.0583],
#         [ 0.0338, -0.0698,  0.0061,  ...,  0.0292, -0.0196,  0.0759],
#         [-0.0221, -0.0244,  0.0246,  ..., -0.0729,  0.0370, -0.0384]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0087,  0.2034,  0.1790,  ...,  0.0168, -0.0473, -0.2498],
#         [ 0.0050,  0.1419,  0.2941,  ...,  0.0816,  0.0136, -0.2888],
#         [ 0.0841, -0.0941, -0.0079,  ...,  0.2084, -0.0803, -0.0120],
#         ...,
#         [-0.0779, -0.2945, -0.2560,  ..., -0.2843,  0.0520,  0.2784],
#         [ 0.2866, -0.1515,  0.2500,  ...,  0.0432,  0.1245, -0.1735],
#         [ 0.2236, -0.0980, -0.0819,  ...,  0.1290,  0.1943,  0.1399]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2575, -0.1185,  0.0228,  ...,  0.2143,  0.0542, -0.0518],
#         [-0.1605, -0.1818,  0.2291,  ...,  0.1022,  0.1218,  0.2449],
#         [ 0.1221,  0.1672, -0.1105,  ...,  0.2778, -0.2268,  0.1769],
#         ...,
#         [-0.2197,  0.2257,  0.1888,  ...,  0.2280, -0.0286,  0.2402],
#         [ 0.2521,  0.0044, -0.0406,  ..., -0.2521,  0.2712, -0.1651],
#         [-0.1968,  0.0998,  0.2620,  ..., -0.2987, -0.2961,  0.2327]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0185,  0.2365, -0.0387,  ...,  0.1061, -0.0010, -0.0576],
#         [ 0.2527, -0.0732, -0.0228,  ...,  0.0745,  0.1218,  0.2596],
#         [-0.1735, -0.0798, -0.1995,  ..., -0.0821, -0.2715,  0.2530],
#         ...,
#         [-0.1124, -0.1531, -0.0478,  ...,  0.0255, -0.0067,  0.2127],
#         [-0.0358, -0.1826, -0.0253,  ...,  0.2795,  0.1351, -0.2640],
#         [-0.0929,  0.2466,  0.0598,  ...,  0.2786, -0.1987, -0.2846]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1248,  0.2549, -0.0160,  ..., -0.1946, -0.1130,  0.0995],
#         [ 0.0444, -0.0215, -0.1077,  ..., -0.0210, -0.2642, -0.0723],
#         [-0.1237, -0.1292,  0.2386,  ..., -0.2883, -0.1409,  0.1910],
#         ...,
#         [-0.3092, -0.1863, -0.2164,  ...,  0.1161, -0.1750,  0.1348],
#         [-0.2698,  0.2512, -0.2996,  ..., -0.2308, -0.0191, -0.0154],
#         [ 0.0115, -0.2175,  0.0655,  ...,  0.3062, -0.1445, -0.1362]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1901,  0.1000, -0.0968,  ...,  0.0982, -0.1948,  0.1509],
#         [-0.1612, -0.1993, -0.0551,  ...,  0.0689, -0.0162,  0.0797],
#         [-0.0828,  0.1357,  0.1181,  ...,  0.0023,  0.2447,  0.1466],
#         ...,
#         [-0.0284, -0.0640,  0.2935,  ..., -0.1254, -0.2053,  0.1317],
#         [ 0.2464, -0.1294, -0.0484,  ...,  0.2500, -0.2584,  0.2665],
#         [-0.2698, -0.1206,  0.1316,  ...,  0.2245,  0.0703, -0.2659]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1405, -0.1853,  0.1761,  ..., -0.2471, -0.0103,  0.0009],
#         [-0.2260, -0.2579, -0.2523,  ...,  0.2606, -0.1390,  0.1783],
#         [ 0.2806, -0.1470,  0.2582,  ...,  0.1440, -0.1947, -0.2065],
#         ...,
#         [-0.0547,  0.1175,  0.2880,  ..., -0.0082, -0.0512, -0.2062],
#         [ 0.0563, -0.2925, -0.0421,  ...,  0.2959, -0.2946,  0.2569],
#         [-0.1653, -0.2889,  0.2784,  ..., -0.1212, -0.2378, -0.1152]],
#        device='cuda:1')
# Epoch: 0007 lr: [0.001, 0.001] train_loss: 1.456755 train_acc: 0.576433 train_f1: 0.576433 time: 0.0779s
# Epoch: 0007 val_loss: 1.466401 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.0003395789462799549
# Grad of encoder.linear_before.E_linear.weight: 1.7214629393473925e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.004784777473876052
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.6766499041623947e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.004898895610192576
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.7316050280393328e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.004858552541954423
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.7325296446813346e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.0048474254378756115
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.71161922053809e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.004823353176181035
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.6762868444776733e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.004877674438184734
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.7281679814306816e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.05630635373053622
# Grad of decoder.bias: 0.11294934686847498
# Epoch 8 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0617, -0.0035, -0.0387,  ...,  0.0656, -0.0251, -0.0708],
#         [-0.0280, -0.0114,  0.0204,  ...,  0.0591, -0.0704, -0.0264],
#         [-0.0109, -0.0019,  0.0112,  ..., -0.0495,  0.0080,  0.0393],
#         ...,
#         [ 0.0231, -0.0666,  0.0533,  ...,  0.0642, -0.0150,  0.0575],
#         [ 0.0346, -0.0706,  0.0068,  ...,  0.0285, -0.0187,  0.0752],
#         [-0.0228, -0.0251,  0.0240,  ..., -0.0733,  0.0379, -0.0391]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0092,  0.2043,  0.1798,  ...,  0.0176, -0.0465, -0.2494],
#         [ 0.0054,  0.1421,  0.2935,  ...,  0.0810,  0.0130, -0.2892],
#         [ 0.0837, -0.0947, -0.0085,  ...,  0.2079, -0.0808, -0.0124],
#         ...,
#         [-0.0783, -0.2949, -0.2566,  ..., -0.2847,  0.0515,  0.2780],
#         [ 0.2862, -0.1519,  0.2494,  ...,  0.0428,  0.1238, -0.1738],
#         [ 0.2241, -0.0969, -0.0810,  ...,  0.1299,  0.1951,  0.1407]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2573, -0.1175,  0.0236,  ...,  0.2152,  0.0549, -0.0514],
#         [-0.1601, -0.1816,  0.2286,  ...,  0.1016,  0.1212,  0.2444],
#         [ 0.1217,  0.1666, -0.1112,  ...,  0.2772, -0.2274,  0.1764],
#         ...,
#         [-0.2201,  0.2252,  0.1882,  ...,  0.2275, -0.0291,  0.2398],
#         [ 0.2517,  0.0040, -0.0410,  ..., -0.2526,  0.2706, -0.1654],
#         [-0.1964,  0.1008,  0.2629,  ..., -0.2977, -0.2953,  0.2335]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0182,  0.2374, -0.0379,  ...,  0.1070, -0.0003, -0.0572],
#         [ 0.2531, -0.0729, -0.0231,  ...,  0.0740,  0.1212,  0.2591],
#         [-0.1739, -0.0802, -0.1999,  ..., -0.0826, -0.2719,  0.2526],
#         ...,
#         [-0.1127, -0.1535, -0.0483,  ...,  0.0251, -0.0071,  0.2123],
#         [-0.0362, -0.1830, -0.0257,  ...,  0.2791,  0.1345, -0.2643],
#         [-0.0925,  0.2476,  0.0607,  ...,  0.2796, -0.1978, -0.2838]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1245,  0.2558, -0.0152,  ..., -0.1937, -0.1122,  0.1000],
#         [ 0.0448, -0.0213, -0.1080,  ..., -0.0216, -0.2648, -0.0728],
#         [-0.1242, -0.1297,  0.2379,  ..., -0.2888, -0.1414,  0.1906],
#         ...,
#         [-0.3096, -0.1867, -0.2169,  ...,  0.1156, -0.1753,  0.1344],
#         [-0.2701,  0.2508, -0.3000,  ..., -0.2312, -0.0196, -0.0157],
#         [ 0.0118, -0.2165,  0.0664,  ...,  0.3072, -0.1437, -0.1354]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1904,  0.1009, -0.0960,  ...,  0.0991, -0.1941,  0.1513],
#         [-0.1608, -0.1988, -0.0553,  ...,  0.0683, -0.0168,  0.0792],
#         [-0.0833,  0.1351,  0.1174,  ...,  0.0017,  0.2442,  0.1462],
#         ...,
#         [-0.0288, -0.0644,  0.2929,  ..., -0.1258, -0.2058,  0.1313],
#         [ 0.2460, -0.1297, -0.0488,  ...,  0.2496, -0.2590,  0.2662],
#         [-0.2694, -0.1196,  0.1325,  ...,  0.2254,  0.0711, -0.2651]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1402, -0.1843,  0.1770,  ..., -0.2462, -0.0096,  0.0014],
#         [-0.2255, -0.2575, -0.2525,  ...,  0.2601, -0.1396,  0.1778],
#         [ 0.2801, -0.1475,  0.2575,  ...,  0.1435, -0.1952, -0.2069],
#         ...,
#         [-0.0552,  0.1170,  0.2874,  ..., -0.0087, -0.0517, -0.2066],
#         [ 0.0559, -0.2928, -0.0425,  ...,  0.2955, -0.2950,  0.2567],
#         [-0.1649, -0.2879,  0.2794,  ..., -0.1203, -0.2369, -0.1144]],
#        device='cuda:1')
# Epoch: 0008 lr: [0.001, 0.001] train_loss: 1.432754 train_acc: 0.576433 train_f1: 0.576433 time: 0.0772s
# Epoch: 0008 val_loss: 1.449744 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.0003773364499602622
# Grad of encoder.linear_before.E_linear.weight: 1.7870472397605778e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.004487206763859331
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.8714397734240484e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.004590537155505981
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.9436982031933153e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.004566984756832872
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.950140513775323e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.004548995140053244
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.919425180525264e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.004536388810681942
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.887148086983645e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.004571359845225437
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.9618685952612596e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.053778486336842374
# Grad of decoder.bias: 0.10653529293606244
# Epoch 9 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0623, -0.0030, -0.0388,  ...,  0.0658, -0.0246, -0.0712],
#         [-0.0273, -0.0121,  0.0211,  ...,  0.0585, -0.0712, -0.0272],
#         [-0.0103, -0.0027,  0.0119,  ..., -0.0491,  0.0070,  0.0388],
#         ...,
#         [ 0.0225, -0.0668,  0.0525,  ...,  0.0648, -0.0147,  0.0566],
#         [ 0.0353, -0.0714,  0.0076,  ...,  0.0276, -0.0178,  0.0744],
#         [-0.0235, -0.0257,  0.0233,  ..., -0.0738,  0.0388, -0.0399]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0094,  0.2053,  0.1807,  ...,  0.0185, -0.0457, -0.2487],
#         [ 0.0058,  0.1422,  0.2930,  ...,  0.0805,  0.0124, -0.2896],
#         [ 0.0833, -0.0951, -0.0090,  ...,  0.2074, -0.0812, -0.0128],
#         ...,
#         [-0.0787, -0.2953, -0.2571,  ..., -0.2851,  0.0511,  0.2776],
#         [ 0.2859, -0.1524,  0.2489,  ...,  0.0424,  0.1231, -0.1741],
#         [ 0.2243, -0.0959, -0.0800,  ...,  0.1308,  0.1960,  0.1416]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2573, -0.1166,  0.0245,  ...,  0.2160,  0.0557, -0.0508],
#         [-0.1598, -0.1814,  0.2281,  ...,  0.1011,  0.1207,  0.2439],
#         [ 0.1213,  0.1661, -0.1117,  ...,  0.2767, -0.2278,  0.1760],
#         ...,
#         [-0.2205,  0.2247,  0.1875,  ...,  0.2270, -0.0296,  0.2394],
#         [ 0.2513,  0.0036, -0.0415,  ..., -0.2529,  0.2699, -0.1657],
#         [-0.1962,  0.1018,  0.2639,  ..., -0.2968, -0.2944,  0.2343]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0183,  0.2384, -0.0370,  ...,  0.1078,  0.0005, -0.0565],
#         [ 0.2535, -0.0725, -0.0233,  ...,  0.0735,  0.1207,  0.2587],
#         [-0.1743, -0.0805, -0.2001,  ..., -0.0830, -0.2722,  0.2523],
#         ...,
#         [-0.1131, -0.1538, -0.0487,  ...,  0.0247, -0.0074,  0.2120],
#         [-0.0365, -0.1833, -0.0260,  ...,  0.2787,  0.1342, -0.2645],
#         [-0.0923,  0.2486,  0.0617,  ...,  0.2805, -0.1970, -0.2830]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1244,  0.2568, -0.0143,  ..., -0.1928, -0.1114,  0.1005],
#         [ 0.0452, -0.0211, -0.1084,  ..., -0.0221, -0.2653, -0.0732],
#         [-0.1246, -0.1302,  0.2373,  ..., -0.2893, -0.1419,  0.1902],
#         ...,
#         [-0.3099, -0.1871, -0.2173,  ...,  0.1153, -0.1754,  0.1342],
#         [-0.2704,  0.2505, -0.3004,  ..., -0.2315, -0.0200, -0.0159],
#         [ 0.0120, -0.2155,  0.0674,  ...,  0.3081, -0.1428, -0.1346]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1903,  0.1019, -0.0951,  ...,  0.1000, -0.1933,  0.1519],
#         [-0.1604, -0.1982, -0.0554,  ...,  0.0678, -0.0174,  0.0788],
#         [-0.0837,  0.1345,  0.1167,  ...,  0.0012,  0.2436,  0.1458],
#         ...,
#         [-0.0292, -0.0647,  0.2924,  ..., -0.1262, -0.2061,  0.1310],
#         [ 0.2456, -0.1301, -0.0493,  ...,  0.2492, -0.2595,  0.2659],
#         [-0.2693, -0.1186,  0.1335,  ...,  0.2263,  0.0720, -0.2643]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.1402, -0.1834,  0.1779,  ..., -0.2454, -0.0087,  0.0019],
#         [-0.2251, -0.2572, -0.2527,  ...,  0.2596, -0.1402,  0.1774],
#         [ 0.2797, -0.1479,  0.2570,  ...,  0.1430, -0.1956, -0.2073],
#         ...,
#         [-0.0555,  0.1166,  0.2868,  ..., -0.0091, -0.0522, -0.2070],
#         [ 0.0556, -0.2930, -0.0428,  ...,  0.2952, -0.2952,  0.2564],
#         [-0.1647, -0.2869,  0.2803,  ..., -0.1193, -0.2360, -0.1135]],
#        device='cuda:1')
# Epoch: 0009 lr: [0.001, 0.001] train_loss: 1.411633 train_acc: 0.576433 train_f1: 0.576433 time: 0.0771s
# Epoch: 0009 val_loss: 1.434101 val_acc: 0.518519 val_f1: 0.518519
# Grad of encoder.linear_before.bias: 0.00042054001296272563
# Grad of encoder.linear_before.E_linear.weight: 1.8538740499520244e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 0.004271678536648212
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.832413698036644e-05
# Grad of encoder.layers.0.net.linears.1.bias: 0.004397844587896925
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.9235432900132916e-05
# Grad of encoder.layers.0.net.linears.2.bias: 0.0043389877534521365
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 2.9061847809698102e-05
# Grad of encoder.layers.0.net.linears.3.bias: 0.004324514487357122
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 2.8760435186808287e-05
# Grad of encoder.layers.0.net.linears.4.bias: 0.004356688163505238
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 2.8784988267741795e-05
# Grad of encoder.layers.0.net.linears.5.bias: 0.0043270899727595276
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.8935395780089884e-05
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.05137226405451154
# Grad of decoder.bias: 0.10030314015316705
# Epoch 10 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-0.0629, -0.0026, -0.0393,  ...,  0.0663, -0.0243, -0.0718],
#         [-0.0265, -0.0127,  0.0218,  ...,  0.0578, -0.0720, -0.0280],
#         [-0.0096, -0.0035,  0.0126,  ..., -0.0491,  0.0060,  0.0382],
#         ...,
#         [ 0.0218, -0.0669,  0.0517,  ...,  0.0654, -0.0144,  0.0556],
#         [ 0.0361, -0.0720,  0.0084,  ...,  0.0268, -0.0170,  0.0736],
#         [-0.0241, -0.0263,  0.0227,  ..., -0.0744,  0.0398, -0.0406]],
#        device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0099,  0.2063,  0.1816,  ...,  0.0194, -0.0449, -0.2485],
#         [ 0.0062,  0.1424,  0.2925,  ...,  0.0801,  0.0120, -0.2900],
#         [ 0.0829, -0.0956, -0.0096,  ...,  0.2069, -0.0817, -0.0131],
#         ...,
#         [-0.0790, -0.2957, -0.2576,  ..., -0.2855,  0.0507,  0.2773],
#         [ 0.2855, -0.1527,  0.2484,  ...,  0.0420,  0.1223, -0.1743],
#         [ 0.2249, -0.0949, -0.0790,  ...,  0.1318,  0.1969,  0.1424]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.2568, -0.1156,  0.0254,  ...,  0.2170,  0.0565, -0.0506],
#         [-0.1595, -0.1813,  0.2276,  ...,  0.1007,  0.1202,  0.2436],
#         [ 0.1208,  0.1656, -0.1124,  ...,  0.2762, -0.2283,  0.1757],
#         ...,
#         [-0.2208,  0.2243,  0.1869,  ...,  0.2266, -0.0301,  0.2390],
#         [ 0.2510,  0.0033, -0.0419,  ..., -0.2533,  0.2693, -0.1659],
#         [-0.1958,  0.1028,  0.2649,  ..., -0.2959, -0.2935,  0.2352]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[-0.0178,  0.2394, -0.0360,  ...,  0.1087,  0.0013, -0.0564],
#         [ 0.2539, -0.0722, -0.0234,  ...,  0.0731,  0.1202,  0.2583],
#         [-0.1746, -0.0807, -0.2003,  ..., -0.0834, -0.2725,  0.2519],
#         ...,
#         [-0.1133, -0.1541, -0.0489,  ...,  0.0244, -0.0076,  0.2117],
#         [-0.0367, -0.1835, -0.0263,  ...,  0.2784,  0.1338, -0.2647],
#         [-0.0919,  0.2496,  0.0627,  ...,  0.2815, -0.1961, -0.2822]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[-0.1240,  0.2578, -0.0134,  ..., -0.1919, -0.1106,  0.1007],
# ...
#         [ 0.1839, -0.0915,  0.1377,  ...,  0.1254, -0.1788, -0.0649],
#         ...,
#         [ 0.0254,  0.0357,  0.1713,  ..., -0.0520, -0.0273, -0.0825],
#         [ 0.1622, -0.1602,  0.0253,  ...,  0.2299, -0.1185,  0.2271],
#         [-0.0636, -0.1892,  0.3021,  ..., -0.0293, -0.1229, -0.0183]],
#        device='cuda:1')
# Epoch: 0357 lr: [0.001, 0.001] train_loss: 0.546557 train_acc: 0.866242 train_f1: 0.866242 time: 0.0819s
# Epoch: 0357 val_loss: 0.805597 val_acc: 0.796296 val_f1: 0.796296
# Grad of encoder.linear_before.bias: 0.0006668593844361304
# Grad of encoder.linear_before.E_linear.weight: 5.381598780268308e-06
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 2.9898380301526643e-05
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.2689712461613275e-06
# Grad of encoder.layers.0.net.linears.1.bias: 5.8359490604953786e-05
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.1798028065961776e-05
# Grad of encoder.layers.0.net.linears.2.bias: 2.9782635009793796e-05
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 6.216291409530911e-06
# Grad of encoder.layers.0.net.linears.3.bias: 2.2214278622583868e-05
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 3.6891484197878804e-06
# Grad of encoder.layers.0.net.linears.4.bias: 6.424726121698524e-05
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 8.050905437326719e-06
# Grad of encoder.layers.0.net.linears.5.bias: 1.733102534830573e-05
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 1.8183420143124425e-06
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.023824956511722534
# Grad of decoder.bias: 0.0034748452049706714
# Epoch 358 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-2.0164e-01,  4.3398e-02, -9.8305e-02,  ...,  7.2594e-02,
#           1.8139e-02, -9.6325e-02],
#         [ 1.3105e-01, -1.3782e-01,  5.3111e-02,  ..., -3.9703e-02,
#          -1.0795e-01, -1.0897e-01],
#         [ 1.5474e-01, -6.9799e-02,  7.4345e-02,  ..., -8.4296e-02,
#          -2.1370e-02, -3.2906e-02],
#         ...,
#         [ 2.7818e-02, -1.4422e-01, -8.0508e-05,  ...,  8.1724e-02,
#          -2.0582e-02, -1.4068e-02],
#         [ 1.7787e-01, -1.3860e-01,  8.8967e-02,  ..., -6.3355e-02,
#          -2.6832e-03,  4.7146e-02],
#         [-2.3037e-01,  7.5397e-02, -1.3956e-01,  ...,  4.9049e-03,
#           9.3219e-02, -3.2033e-02]], device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0469,  0.2735,  0.2572,  ...,  0.0963,  0.0027, -0.2574],
#         [ 0.1370,  0.0040,  0.1429,  ...,  0.0913, -0.0886, -0.1478],
#         [ 0.1068, -0.0591,  0.0012,  ...,  0.1317, -0.1097,  0.0705],
#         ...,
#         [-0.0297, -0.1717, -0.1415,  ..., -0.2431,  0.0619,  0.2540],
#         [ 0.3263, -0.1078,  0.1303,  ...,  0.0293,  0.1322, -0.0692],
#         [ 0.1405, -0.0031,  0.0076,  ...,  0.2100,  0.1115,  0.0925]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.1244,  0.2247,  0.2817,  ...,  0.3921,  0.2314, -0.1042],
#         [ 0.0020, -0.0157,  0.0218,  ..., -0.0031, -0.0401,  0.1447],
#         [ 0.0970, -0.0140, -0.0107,  ...,  0.0500, -0.1139,  0.2128],
#         ...,
#         [-0.0644, -0.0095,  0.0108,  ...,  0.0426,  0.0134,  0.1929],
#         [ 0.3042, -0.0281, -0.0205,  ..., -0.0975,  0.1581, -0.0519],
#         [-0.1119,  0.2262,  0.2043,  ..., -0.0247, -0.0842,  0.2126]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[ 0.0190,  0.2884,  0.0532,  ...,  0.1682,  0.0287, -0.1572],
#         [ 0.1480, -0.0782, -0.0308,  ...,  0.0820, -0.0013,  0.1651],
#         [ 0.0389, -0.0349, -0.0958,  ...,  0.0695, -0.1848,  0.3608],
#         ...,
#         [-0.0303, -0.0871, -0.0087,  ..., -0.0152,  0.0961,  0.2488],
#         [ 0.1143, -0.1307, -0.0268,  ...,  0.2145,  0.2129, -0.1072],
#         [-0.0181,  0.1694,  0.0249,  ...,  0.3420, -0.2031, -0.1475]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[ 0.0076,  0.2923,  0.0690,  ..., -0.1364, -0.0167, -0.0286],
#         [ 0.0323, -0.0303, -0.0140,  ...,  0.0027, -0.2110, -0.0313],
#         [-0.0383, -0.0887,  0.1063,  ..., -0.1471, -0.1034,  0.2154],
#         ...,
#         [-0.1075, -0.1900, -0.2038,  ...,  0.0674,  0.0228,  0.2601],
#         [-0.1274,  0.1238, -0.2158,  ..., -0.1702,  0.0662,  0.1529],
#         [-0.0163, -0.0973,  0.1053,  ...,  0.3767, -0.1627, -0.0600]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1367,  0.1639,  0.0255,  ...,  0.1437, -0.1162, -0.0135],
#         [-0.0160, -0.1123, -0.0103,  ...,  0.0666, -0.1039,  0.0879],
#         [ 0.0944,  0.0261, -0.0052,  ...,  0.1545, -0.0081,  0.3646],
#         ...,
#         [ 0.1074, -0.0556,  0.1831,  ..., -0.0840, -0.0982,  0.2575],
#         [ 0.2501, -0.0773, -0.0156,  ...,  0.1848, -0.1710,  0.2905],
#         [-0.1427, -0.0593,  0.0984,  ...,  0.3089, -0.0066, -0.0727]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.0888, -0.0623,  0.3001,  ..., -0.1369,  0.0464, -0.0216],
#         [-0.0666, -0.1607, -0.1513,  ...,  0.2163, -0.1438,  0.1656],
#         [ 0.1838, -0.0912,  0.1376,  ...,  0.1254, -0.1786, -0.0649],
#         ...,
#         [ 0.0255,  0.0356,  0.1712,  ..., -0.0519, -0.0273, -0.0824],
#         [ 0.1623, -0.1598,  0.0254,  ...,  0.2299, -0.1184,  0.2271],
#         [-0.0636, -0.1891,  0.3021,  ..., -0.0293, -0.1228, -0.0183]],
#        device='cuda:1')
# Epoch: 0358 lr: [0.001, 0.001] train_loss: 0.546289 train_acc: 0.866242 train_f1: 0.866242 time: 0.0817s
# Epoch: 0358 val_loss: 0.803242 val_acc: 0.814815 val_f1: 0.814815
# Grad of encoder.linear_before.bias: 0.0005253573264984983
# Grad of encoder.linear_before.E_linear.weight: 4.3201155872961145e-06
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 2.8686835073870767e-05
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 2.1946648460835667e-06
# Grad of encoder.layers.0.net.linears.1.bias: 4.379599978735987e-05
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.1124165482064937e-05
# Grad of encoder.layers.0.net.linears.2.bias: 2.9206936381837413e-05
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 6.253245302994474e-06
# Grad of encoder.layers.0.net.linears.3.bias: 2.127265280645632e-05
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 4.083486388654623e-06
# Grad of encoder.layers.0.net.linears.4.bias: 4.713600647501439e-05
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 6.417263288063904e-06
# Grad of encoder.layers.0.net.linears.5.bias: 1.8088111997098587e-05
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 1.4867294698966656e-06
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.011581719202102518
# Grad of decoder.bias: 0.0019356212597387854
# Epoch 359 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-2.0180e-01,  4.3540e-02, -9.8486e-02,  ...,  7.2626e-02,
#           1.8234e-02, -9.6518e-02],
#         [ 1.3104e-01, -1.3796e-01,  5.3172e-02,  ..., -3.9841e-02,
#          -1.0780e-01, -1.0872e-01],
#         [ 1.5474e-01, -6.9705e-02,  7.4369e-02,  ..., -8.4349e-02,
#          -2.1183e-02, -3.2859e-02],
#         ...,
#         [ 2.7763e-02, -1.4429e-01, -2.7534e-05,  ...,  8.1592e-02,
#          -2.0409e-02, -1.3924e-02],
#         [ 1.7787e-01, -1.3863e-01,  8.8969e-02,  ..., -6.3326e-02,
#          -2.5311e-03,  4.7237e-02],
#         [-2.3053e-01,  7.5506e-02, -1.3972e-01,  ...,  4.8458e-03,
#           9.3357e-02, -3.2124e-02]], device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0469,  0.2733,  0.2571,  ...,  0.0963,  0.0027, -0.2574],
#         [ 0.1369,  0.0040,  0.1428,  ...,  0.0912, -0.0886, -0.1478],
#         [ 0.1067, -0.0589,  0.0012,  ...,  0.1316, -0.1096,  0.0706],
#         ...,
#         [-0.0296, -0.1714, -0.1414,  ..., -0.2429,  0.0620,  0.2540],
#         [ 0.3263, -0.1074,  0.1303,  ...,  0.0295,  0.1322, -0.0692],
#         [ 0.1404, -0.0031,  0.0077,  ...,  0.2099,  0.1115,  0.0923]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.1243,  0.2259,  0.2821,  ...,  0.3921,  0.2316, -0.1043],
#         [ 0.0019, -0.0153,  0.0214,  ..., -0.0031, -0.0400,  0.1445],
#         [ 0.0968, -0.0138, -0.0105,  ...,  0.0495, -0.1132,  0.2128],
#         ...,
#         [-0.0642, -0.0096,  0.0105,  ...,  0.0424,  0.0134,  0.1929],
#         [ 0.3040, -0.0278, -0.0204,  ..., -0.0967,  0.1575, -0.0519],
#         [-0.1119,  0.2262,  0.2039,  ..., -0.0238, -0.0837,  0.2123]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[ 0.0190,  0.2883,  0.0531,  ...,  0.1681,  0.0287, -0.1572],
#         [ 0.1475, -0.0781, -0.0309,  ...,  0.0818, -0.0012,  0.1647],
#         [ 0.0388, -0.0347, -0.0958,  ...,  0.0695, -0.1845,  0.3607],
#         ...,
#         [-0.0299, -0.0867, -0.0086,  ..., -0.0151,  0.0965,  0.2489],
#         [ 0.1144, -0.1302, -0.0268,  ...,  0.2146,  0.2131, -0.1071],
#         [-0.0181,  0.1692,  0.0249,  ...,  0.3418, -0.2030, -0.1475]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[ 0.0076,  0.2921,  0.0689,  ..., -0.1365, -0.0167, -0.0287],
#         [ 0.0321, -0.0301, -0.0140,  ...,  0.0028, -0.2108, -0.0315],
#         [-0.0382, -0.0883,  0.1063,  ..., -0.1470, -0.1031,  0.2155],
#         ...,
#         [-0.1073, -0.1898, -0.2037,  ...,  0.0675,  0.0231,  0.2601],
#         [-0.1272,  0.1238, -0.2156,  ..., -0.1700,  0.0664,  0.1529],
#         [-0.0163, -0.0972,  0.1053,  ...,  0.3766, -0.1625, -0.0601]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1365,  0.1636,  0.0254,  ...,  0.1435, -0.1162, -0.0137],
#         [-0.0163, -0.1120, -0.0102,  ...,  0.0663, -0.1038,  0.0872],
#         [ 0.0947,  0.0264, -0.0052,  ...,  0.1549, -0.0081,  0.3650],
#         ...,
#         [ 0.1076, -0.0552,  0.1830,  ..., -0.0836, -0.0982,  0.2578],
#         [ 0.2502, -0.0768, -0.0157,  ...,  0.1851, -0.1710,  0.2907],
#         [-0.1427, -0.0592,  0.0984,  ...,  0.3088, -0.0066, -0.0726]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.0889, -0.0623,  0.3000,  ..., -0.1369,  0.0463, -0.0216],
#         [-0.0666, -0.1602, -0.1512,  ...,  0.2162, -0.1436,  0.1655],
#         [ 0.1838, -0.0909,  0.1375,  ...,  0.1255, -0.1784, -0.0648],
#         ...,
#         [ 0.0256,  0.0356,  0.1711,  ..., -0.0519, -0.0273, -0.0824],
#         [ 0.1623, -0.1595,  0.0255,  ...,  0.2300, -0.1183,  0.2271],
#         [-0.0636, -0.1890,  0.3021,  ..., -0.0293, -0.1228, -0.0184]],
#        device='cuda:1')
# Epoch: 0359 lr: [0.001, 0.001] train_loss: 0.545413 train_acc: 0.866242 train_f1: 0.866242 time: 0.0822s
# Epoch: 0359 val_loss: 0.796381 val_acc: 0.833333 val_f1: 0.833333
# Grad of encoder.linear_before.bias: 0.0021279233176413285
# Grad of encoder.linear_before.E_linear.weight: 1.0448955466437422e-05
# Grad of encoder.layers.0.net.kernel_tangents: None
# Grad of encoder.layers.0.net.linears.0.bias: 3.627623565291579e-05
# Grad of encoder.layers.0.net.linears.0.E_linear.weight: 3.8566254430069394e-06
# Grad of encoder.layers.0.net.linears.1.bias: 0.00016058123525639973
# Grad of encoder.layers.0.net.linears.1.E_linear.weight: 2.319398435934291e-05
# Grad of encoder.layers.0.net.linears.2.bias: 3.195512780269959e-05
# Grad of encoder.layers.0.net.linears.2.E_linear.weight: 8.141434606213828e-06
# Grad of encoder.layers.0.net.linears.3.bias: 2.5154512903598896e-05
# Grad of encoder.layers.0.net.linears.3.E_linear.weight: 5.320463496748174e-06
# Grad of encoder.layers.0.net.linears.4.bias: 0.00010064710453082872
# Grad of encoder.layers.0.net.linears.4.E_linear.weight: 1.2387693730580812e-05
# Grad of encoder.layers.0.net.linears.5.bias: 2.1787855383524547e-05
# Grad of encoder.layers.0.net.linears.5.E_linear.weight: 2.4585463481749803e-06
# Grad of decoder.origin: None
# Grad of decoder.cls: 0.025501811756375267
# Grad of decoder.bias: 0.004132648628009306
# Epoch 360 - Model Linear Weight:
# encoder.linear_before.E_linear.weight: tensor([[-2.0199e-01,  4.3662e-02, -9.8719e-02,  ...,  7.2910e-02,
#           1.8216e-02, -9.6722e-02],
#         [ 1.3104e-01, -1.3815e-01,  5.3272e-02,  ..., -4.0185e-02,
#          -1.0751e-01, -1.0848e-01],
#         [ 1.5475e-01, -6.9628e-02,  7.4390e-02,  ..., -8.4576e-02,
#          -2.0890e-02, -3.2811e-02],
#         ...,
#         [ 2.7718e-02, -1.4436e-01,  3.8047e-05,  ...,  8.1469e-02,
#          -2.0202e-02, -1.3775e-02],
#         [ 1.7787e-01, -1.3868e-01,  8.8969e-02,  ..., -6.3189e-02,
#          -2.3857e-03,  4.7302e-02],
#         [-2.3072e-01,  7.5605e-02, -1.3989e-01,  ...,  4.7645e-03,
#           9.3383e-02, -3.2224e-02]], device='cuda:1')
# encoder.layers.0.net.linears.0.E_linear.weight: tensor([[ 0.0469,  0.2731,  0.2570,  ...,  0.0962,  0.0026, -0.2574],
#         [ 0.1367,  0.0039,  0.1426,  ...,  0.0911, -0.0886, -0.1479],
#         [ 0.1067, -0.0587,  0.0012,  ...,  0.1316, -0.1096,  0.0707],
#         ...,
#         [-0.0295, -0.1711, -0.1413,  ..., -0.2427,  0.0621,  0.2540],
#         [ 0.3262, -0.1070,  0.1303,  ...,  0.0296,  0.1323, -0.0692],
#         [ 0.1403, -0.0031,  0.0077,  ...,  0.2099,  0.1115,  0.0921]],
#        device='cuda:1')
# encoder.layers.0.net.linears.1.E_linear.weight: tensor([[-0.1243,  0.2270,  0.2825,  ...,  0.3922,  0.2319, -0.1045],
#         [ 0.0018, -0.0149,  0.0210,  ..., -0.0032, -0.0399,  0.1442],
#         [ 0.0967, -0.0136, -0.0102,  ...,  0.0491, -0.1125,  0.2127],
#         ...,
#         [-0.0639, -0.0097,  0.0102,  ...,  0.0423,  0.0134,  0.1929],
#         [ 0.3039, -0.0275, -0.0203,  ..., -0.0959,  0.1569, -0.0519],
#         [-0.1119,  0.2261,  0.2034,  ..., -0.0230, -0.0832,  0.2118]],
#        device='cuda:1')
# encoder.layers.0.net.linears.2.E_linear.weight: tensor([[ 0.0189,  0.2881,  0.0531,  ...,  0.1680,  0.0286, -0.1573],
#         [ 0.1471, -0.0779, -0.0309,  ...,  0.0817, -0.0011,  0.1643],
#         [ 0.0388, -0.0344, -0.0957,  ...,  0.0696, -0.1843,  0.3607],
#         ...,
#         [-0.0295, -0.0863, -0.0085,  ..., -0.0149,  0.0970,  0.2489],
#         [ 0.1146, -0.1295, -0.0268,  ...,  0.2147,  0.2134, -0.1070],
#         [-0.0181,  0.1690,  0.0249,  ...,  0.3417, -0.2028, -0.1475]],
#        device='cuda:1')
# encoder.layers.0.net.linears.3.E_linear.weight: tensor([[ 0.0075,  0.2919,  0.0688,  ..., -0.1365, -0.0168, -0.0287],
#         [ 0.0320, -0.0299, -0.0141,  ...,  0.0028, -0.2106, -0.0316],
#         [-0.0381, -0.0879,  0.1062,  ..., -0.1468, -0.1028,  0.2155],
#         ...,
#         [-0.1070, -0.1896, -0.2036,  ...,  0.0675,  0.0234,  0.2602],
#         [-0.1270,  0.1238, -0.2155,  ..., -0.1699,  0.0666,  0.1530],
#         [-0.0164, -0.0970,  0.1053,  ...,  0.3765, -0.1624, -0.0602]],
#        device='cuda:1')
# encoder.layers.0.net.linears.4.E_linear.weight: tensor([[ 0.1363,  0.1634,  0.0254,  ...,  0.1434, -0.1162, -0.0140],
#         [-0.0166, -0.1116, -0.0101,  ...,  0.0660, -0.1036,  0.0865],
#         [ 0.0950,  0.0271, -0.0051,  ...,  0.1553, -0.0080,  0.3655],
#         ...,
#         [ 0.1079, -0.0548,  0.1830,  ..., -0.0831, -0.0982,  0.2581],
#         [ 0.2503, -0.0763, -0.0157,  ...,  0.1854, -0.1711,  0.2910],
#         [-0.1426, -0.0589,  0.0985,  ...,  0.3087, -0.0065, -0.0725]],
#        device='cuda:1')
# encoder.layers.0.net.linears.5.E_linear.weight: tensor([[-0.0889, -0.0623,  0.3000,  ..., -0.1369,  0.0463, -0.0217],
#         [-0.0667, -0.1597, -0.1510,  ...,  0.2161, -0.1434,  0.1653],
#         [ 0.1837, -0.0906,  0.1375,  ...,  0.1255, -0.1782, -0.0647],
#         ...,
#         [ 0.0256,  0.0356,  0.1710,  ..., -0.0518, -0.0272, -0.0823],
#         [ 0.1623, -0.1591,  0.0255,  ...,  0.2300, -0.1182,  0.2271],
#         [-0.0636, -0.1889,  0.3021,  ..., -0.0293, -0.1227, -0.0185]],
#        device='cuda:1')
# Epoch: 0360 lr: [0.001, 0.001] train_loss: 0.546225 train_acc: 0.866242 train_f1: 0.866242 time: 0.0822s
# Epoch: 0360 val_loss: 0.803599 val_acc: 0.796296 val_f1: 0.796296
# Early stopping
# Optimization Finished!
# Total time elapsed: 37.0383s
# Val set results: val_loss: 0.804182 val_acc: 0.833333 val_f1: 0.833333
# Test set results: test_loss: 0.708528 test_acc: 0.870370 test_f1: 0.870370

# %% [markdown]
# # Graph Classification
